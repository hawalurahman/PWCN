# %%
import xmltodict

# Import spaCy and load a language model
import spacy
nlp = spacy.load("en_core_web_sm")

data = 'ABSA14_Restaurants_Test_Gold.xml'

with open(data) as fd:
    xml_source = xmltodict.parse(fd.read())

# %%
xml_source
# Out:
# OrderedDict([('sentences',
#               OrderedDict([('sentence',
#                             [OrderedDict([('@id', '32897564#894393#2'),
#                                           ('text',
#                                            'The bread is top notch as well.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'bread'),
#                                                                       ('@polarity',
#                                                                        'positive'),
#                                                                       ('@from',
#                                                                        '4'),
#                                                                       ('@to',
#                                                                        '9')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '33070600#670328#0'),
#                                           ('text',
#                                            'I have to say they have one of the fastest delivery times in the city.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'delivery times'),
#                                                                       ('@polarity',
#                                                                        'positive'),
#                                                                       ('@from',
#                                                                        '43'),
#                                                                       ('@to',
#                                                                        '57')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'service'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '33070600#670328#2'),
#                                           ('text',
#                                            'Food is always fresh and hot- ready to eat!'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'Food'),
#                                                                       ('@polarity',
#                                                                        'positive'),
#                                                                       ('@from',
#                                                                        '0'),
#                                                                       ('@to',
#                                                                        '4')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '36244464#949326#5'),
#                                           ('text',
#                                            'Did I mention that the coffee is OUTSTANDING?'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'coffee'),
#                                                                       ('@polarity',
#                                                                        'positive'),
#                                                                       ('@from',
#                                                                        '23'),
#                                                                       ('@to',
#                                                                        '29')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '32894246#870052#0'),
#                                           ('text',
#                                            'Certainly not the best sushi in New York, however, it is always fresh, and the place is very clean, sterile.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'sushi'),
#                                                                        ('@polarity',
#                                                                         'conflict'),
#                                                                        ('@from',
#                                                                         '23'),
#                                                                        ('@to',
#                                                                         '28')]),
#                                                           OrderedDict([('@term',
#                                                                         'place'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '79'),
#                                                                        ('@to',
#                                                                         '84')])])])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          [OrderedDict([('@category',
#                                                                         'food'),
#                                                                        ('@polarity',
#                                                                         'conflict')]),
#                                                           OrderedDict([('@category',
#                                                                         'ambience'),
#                                                                        ('@polarity',
#                                                                         'positive')])])]))]),
#                              OrderedDict([('@id', '32894246#870052#1'),
#                                           ('text',
#                                            'I trust the people at Go Sushi, it never disappoints.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'people'),
#                                                                       ('@polarity',
#                                                                        'positive'),
#                                                                       ('@from',
#                                                                        '12'),
#                                                                       ('@to',
#                                                                        '18')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'anecdotes/miscellaneous'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '32894246#870052#2'),
#                                           ('text',
#                                            'Straight-forward, no surprises, very decent Japanese food.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'Japanese food'),
#                                                                       ('@polarity',
#                                                                        'positive'),
#                                                                       ('@from',
#                                                                        '44'),
#                                                                       ('@to',
#                                                                        '57')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '35390182#756337#4'),
#                                           ('text',
#                                            'BEST spicy tuna roll, great asian salad.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'asian salad'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '28'),
#                                                                        ('@to',
#                                                                         '39')]),
#                                                           OrderedDict([('@term',
#                                                                         'spicy tuna roll'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '5'),
#                                                                        ('@to',
#                                                                         '20')])])])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '35390182#756337#5'),
#                                           ('text',
#                                            'Try the rose roll (not on menu).'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'rose roll'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '8'),
#                                                                        ('@to',
#                                                                         '17')]),
#                                                           OrderedDict([('@term',
#                                                                         'menu'),
#                                                                        ('@polarity',
#                                                                         'neutral'),
#                                                                        ('@from',
#                                                                         '26'),
#                                                                        ('@to',
#                                                                         '30')])])])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '11447227#436718#3'),
#                                           ('text',
#                                            'I love the drinks, esp lychee martini, and the food is also VERY good.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'drinks'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '11'),
#                                                                        ('@to',
#                                                                         '17')]),
#                                                           OrderedDict([('@term',
#                                                                         'lychee martini'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '23'),
#                                                                        ('@to',
#                                                                         '37')]),
#                                                           OrderedDict([('@term',
#                                                                         'food'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '47'),
#                                                                        ('@to',
#                                                                         '51')])])])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '33071731#1007204#3'),
#                                           ('text',
#                                            'In fact, this was not a Nicoise salad and was barely eatable.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'Nicoise salad'),
#                                                                       ('@polarity',
#                                                                        'negative'),
#                                                                       ('@from',
#                                                                        '24'),
#                                                                       ('@to',
#                                                                        '37')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'negative')]))]))]),
#                              OrderedDict([('@id', '33085939#758010#0'),
#                                           ('text',
#                                            "While there's a decent menu, it shouldn't take ten minutes to get your drinks and 45 for a dessert pizza."),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'menu'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '23'),
#                                                                        ('@to',
#                                                                         '27')]),
#                                                           OrderedDict([('@term',
#                                                                         'drinks'),
#                                                                        ('@polarity',
#                                                                         'neutral'),
#                                                                        ('@from',
#                                                                         '71'),
#                                                                        ('@to',
#                                                                         '77')]),
#                                                           OrderedDict([('@term',
#                                                                         'dessert pizza'),
#                                                                        ('@polarity',
#                                                                         'neutral'),
#                                                                        ('@from',
#                                                                         '91'),
#                                                                        ('@to',
#                                                                         '104')])])])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          [OrderedDict([('@category',
#                                                                         'food'),
#                                                                        ('@polarity',
#                                                                         'positive')]),
#                                                           OrderedDict([('@category',
#                                                                         'service'),
#                                                                        ('@polarity',
#                                                                         'negative')])])]))]),
#                              OrderedDict([('@id', '11313431#524365#3'),
#                                           ('text',
#                                            'Once we sailed, the top-notch food and live entertainment sold us on a unforgettable evening.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'food'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '30'),
#                                                                        ('@to',
#                                                                         '34')]),
#                                                           OrderedDict([('@term',
#                                                                         'live entertainment'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '39'),
#                                                                        ('@to',
#                                                                         '57')])])])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          [OrderedDict([('@category',
#                                                                         'food'),
#                                                                        ('@polarity',
#                                                                         'positive')]),
#                                                           OrderedDict([('@category',
#                                                                         'ambience'),
#                                                                        ('@polarity',
#                                                                         'positive')])])]))]),
#                              OrderedDict([('@id', '11359717#1138929#1'),
#                                           ('text',
#                                            'Our waiter was horrible; so rude and disinterested.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'waiter'),
#                                                                       ('@polarity',
#                                                                        'negative'),
#                                                                       ('@from',
#                                                                        '4'),
#                                                                       ('@to',
#                                                                        '10')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'service'),
#                                                                       ('@polarity',
#                                                                        'negative')]))]))]),
#                              OrderedDict([('@id', '11359717#1138929#3'),
#                                           ('text',
#                                            "The sangria's - watered down."),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'sangria'),
#                                                                       ('@polarity',
#                                                                        'negative'),
#                                                                       ('@from',
#                                                                        '4'),
#                                                                       ('@to',
#                                                                        '11')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'negative')]))]))]),
#                              OrderedDict([('@id', '11359717#1138929#4'),
#                                           ('text',
#                                            'menu - uneventful, small.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'menu'),
#                                                                       ('@polarity',
#                                                                        'negative'),
#                                                                       ('@from',
#                                                                        '0'),
#                                                                       ('@to',
#                                                                        '4')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'negative')]))]))]),
#                              OrderedDict([('@id', '11313439#692431#0'),
#                                           ('text',
#                                            'Anytime and everytime I find myself in the neighborhood I will go to Sushi Rose for fresh sushi and great portions all at a reasonable price.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'sushi'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '90'),
#                                                                        ('@to',
#                                                                         '95')]),
#                                                           OrderedDict([('@term',
#                                                                         'portions'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '106'),
#                                                                        ('@to',
#                                                                         '114')]),
#                                                           OrderedDict([('@term',
#                                                                         'price'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '135'),
#                                                                        ('@to',
#                                                                         '140')])])])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          [OrderedDict([('@category',
#                                                                         'food'),
#                                                                        ('@polarity',
#                                                                         'positive')]),
#                                                           OrderedDict([('@category',
#                                                                         'price'),
#                                                                        ('@polarity',
#                                                                         'positive')])])]))]),
#                              OrderedDict([('@id', '11351513#832512#0'),
#                                           ('text',
#                                            'Great food but the service was dreadful!'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'food'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '6'),
#                                                                        ('@to',
#                                                                         '10')]),
#                                                           OrderedDict([('@term',
#                                                                         'service'),
#                                                                        ('@polarity',
#                                                                         'negative'),
#                                                                        ('@from',
#                                                                         '19'),
#                                                                        ('@to',
#                                                                         '26')])])])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          [OrderedDict([('@category',
#                                                                         'food'),
#                                                                        ('@polarity',
#                                                                         'positive')]),
#                                                           OrderedDict([('@category',
#                                                                         'service'),
#                                                                        ('@polarity',
#                                                                         'negative')])])]))]),
#                              OrderedDict([('@id', '35390148#588852#2'),
#                                           ('text',
#                                            'The portions of the food that came out were mediocre.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'portions of the food'),
#                                                                       ('@polarity',
#                                                                        'neutral'),
#                                                                       ('@from',
#                                                                        '4'),
#                                                                       ('@to',
#                                                                        '24')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'neutral')]))]))]),
#                              OrderedDict([('@id', '11351513#832512#1'),
#                                           ('text',
#                                            "the two waitress's looked like they had been sucking on lemons."),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        "waitress's"),
#                                                                       ('@polarity',
#                                                                        'negative'),
#                                                                       ('@from',
#                                                                        '8'),
#                                                                       ('@to',
#                                                                        '18')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'service'),
#                                                                       ('@polarity',
#                                                                        'negative')]))]))]),
#                              OrderedDict([('@id', '11313431#524365#2'),
#                                           ('text',
#                                            'From the beginning, we were met by friendly staff memebers, and the convienent parking at Chelsea Piers made it easy for us to get to the boat.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'staff memebers'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '44'),
#                                                                        ('@to',
#                                                                         '58')]),
#                                                           OrderedDict([('@term',
#                                                                         'parking'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '79'),
#                                                                        ('@to',
#                                                                         '86')])])])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          [OrderedDict([('@category',
#                                                                         'service'),
#                                                                        ('@polarity',
#                                                                         'positive')]),
#                                                           OrderedDict([('@category',
#                                                                         'anecdotes/miscellaneous'),
#                                                                        ('@polarity',
#                                                                         'positive')])])]))]),
#                              OrderedDict([('@id', '35196520#758440#4'),
#                                           ('text',
#                                            'We enjoyed ourselves thoroughly and will be going back for the desserts ....'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'desserts'),
#                                                                       ('@polarity',
#                                                                        'positive'),
#                                                                       ('@from',
#                                                                        '63'),
#                                                                       ('@to',
#                                                                        '71')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          [OrderedDict([('@category',
#                                                                         'food'),
#                                                                        ('@polarity',
#                                                                         'positive')]),
#                                                           OrderedDict([('@category',
#                                                                         'anecdotes/miscellaneous'),
#                                                                        ('@polarity',
#                                                                         'positive')])])]))]),
#                              OrderedDict([('@id', '35196527#481646#2'),
#                                           ('text',
#                                            'Desserts are almost incredible: my personal favorite is their Tart of the Day.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'Desserts'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '0'),
#                                                                        ('@to',
#                                                                         '8')]),
#                                                           OrderedDict([('@term',
#                                                                         'Tart of the Day'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '62'),
#                                                                        ('@to',
#                                                                         '77')])])])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '35668126#536759#0'),
#                                           ('text',
#                                            'I am surprised at the lower reviews because it is definitely better than other places I have tried with higher ratings.'),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'anecdotes/miscellaneous'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '35668126#536759#1'),
#                                           ('text',
#                                            'Maybe the secret was that we went on a Sunday night and everything was great.'),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'anecdotes/miscellaneous'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '35668126#536759#2'),
#                                           ('text',
#                                            'The food was extremely tasty, creatively presented and the wine excellent.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'food'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '4'),
# ...
#                                                                        '12'),
#                                                                       ('@to',
#                                                                        '21')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'service'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '15069510#648179#5'),
#                                           ('text',
#                                            'I always find myself sitting next to someone in the theatre industry- interesting to hear ideas hashed out while having a quick bite to eat.'),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'anecdotes/miscellaneous'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '32443281#959917#4'),
#                                           ('text',
#                                            "Its good to go there for drinks if you don't want to get drunk because you'll be lucky if you can get one drink an hour the service is so bad."),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'service'),
#                                                                        ('@polarity',
#                                                                         'negative'),
#                                                                        ('@from',
#                                                                         '124'),
#                                                                        ('@to',
#                                                                         '131')]),
#                                                           OrderedDict([('@term',
#                                                                         'drink'),
#                                                                        ('@polarity',
#                                                                         'neutral'),
#                                                                        ('@from',
#                                                                         '106'),
#                                                                        ('@to',
#                                                                         '111')]),
#                                                           OrderedDict([('@term',
#                                                                         'drinks'),
#                                                                        ('@polarity',
#                                                                         'neutral'),
#                                                                        ('@from',
#                                                                         '25'),
#                                                                        ('@to',
#                                                                         '31')])])])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'service'),
#                                                                       ('@polarity',
#                                                                        'negative')]))]))]),
#                              OrderedDict([('@id', '11661949#1709112#8'),
#                                           ('text',
#                                            'Anyway, the owner was fake.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'owner'),
#                                                                       ('@polarity',
#                                                                        'negative'),
#                                                                       ('@from',
#                                                                        '12'),
#                                                                       ('@to',
#                                                                        '17')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'service'),
#                                                                       ('@polarity',
#                                                                        'negative')]))]))]),
#                              OrderedDict([('@id', '35698240#574381#2'),
#                                           ('text',
#                                            'Owner is pleasant and entertaining.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'Owner'),
#                                                                       ('@polarity',
#                                                                        'positive'),
#                                                                       ('@from',
#                                                                        '0'),
#                                                                       ('@to',
#                                                                        '5')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'service'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))]),
#                              OrderedDict([('@id', '11350390#802808#3'),
#                                           ('text',
#                                            'I have never in my life sent back food before, but I simply had to, and the waiter argued with me over this.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'food'),
#                                                                        ('@polarity',
#                                                                         'negative'),
#                                                                        ('@from',
#                                                                         '34'),
#                                                                        ('@to',
#                                                                         '38')]),
#                                                           OrderedDict([('@term',
#                                                                         'waiter'),
#                                                                        ('@polarity',
#                                                                         'negative'),
#                                                                        ('@from',
#                                                                         '76'),
#                                                                        ('@to',
#                                                                         '82')])])])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          [OrderedDict([('@category',
#                                                                         'food'),
#                                                                        ('@polarity',
#                                                                         'negative')]),
#                                                           OrderedDict([('@category',
#                                                                         'service'),
#                                                                        ('@polarity',
#                                                                         'negative')])])]))]),
#                              OrderedDict([('@id', '11482070#503858#3'),
#                                           ('text',
#                                            'Although the restaurant itself is nice, I prefer not to go for the food.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          OrderedDict([('@term',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'negative'),
#                                                                       ('@from',
#                                                                        '67'),
#                                                                       ('@to',
#                                                                        '71')]))])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          [OrderedDict([('@category',
#                                                                         'ambience'),
#                                                                        ('@polarity',
#                                                                         'positive')]),
#                                                           OrderedDict([('@category',
#                                                                         'food'),
#                                                                        ('@polarity',
#                                                                         'negative')])])]))]),
#                              OrderedDict([('@id', '11351628#404492#3'),
#                                           ('text',
#                                            'Creamy appetizers--taramasalata, eggplant salad, and Greek yogurt (with cuccumber, dill, and garlic) taste excellent when on warm pitas.'),
#                                           ('aspectTerms',
#                                            OrderedDict([('aspectTerm',
#                                                          [OrderedDict([('@term',
#                                                                         'Creamy appetizers'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '0'),
#                                                                        ('@to',
#                                                                         '17')]),
#                                                           OrderedDict([('@term',
#                                                                         'warm pitas'),
#                                                                        ('@polarity',
#                                                                         'neutral'),
#                                                                        ('@from',
#                                                                         '125'),
#                                                                        ('@to',
#                                                                         '135')]),
#                                                           OrderedDict([('@term',
#                                                                         'taramasalata'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '19'),
#                                                                        ('@to',
#                                                                         '31')]),
#                                                           OrderedDict([('@term',
#                                                                         'eggplant salad'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '33'),
#                                                                        ('@to',
#                                                                         '47')]),
#                                                           OrderedDict([('@term',
#                                                                         'Greek yogurt (with cuccumber, dill, and garlic)'),
#                                                                        ('@polarity',
#                                                                         'positive'),
#                                                                        ('@from',
#                                                                         '53'),
#                                                                        ('@to',
#                                                                         '100')])])])),
#                                           ('aspectCategories',
#                                            OrderedDict([('aspectCategory',
#                                                          OrderedDict([('@category',
#                                                                        'food'),
#                                                                       ('@polarity',
#                                                                        'positive')]))]))])])]))])

# %%
# Extracting text, term, and polarity values
sentences = xml_source['sentences']['sentence']
extracted_info = []

for sentence in sentences:
    text = sentence['text']
    
    # Check if 'aspectTerms' exist in the sentence
    aspect_terms = sentence.get('aspectTerms')
    
    if aspect_terms:
        aspect_term = aspect_terms['aspectTerm']
        
        # If there are multiple aspectTerms in a sentence
        if isinstance(aspect_term, list):
            for term in aspect_term:
                term_value = term['@term']
                polarity = term['@polarity']
                extracted_info.append({'text': text, 'term': term_value, 'polarity': polarity})
        else:  # Only one aspectTerm in a sentence
            term_value = aspect_term['@term']
            polarity = aspect_term['@polarity']
            extracted_info.append({'text': text, 'term': term_value, 'polarity': polarity})

# Print or process extracted information
for item in extracted_info:
    print(item)
# Out:
# {'text': 'The bread is top notch as well.', 'term': 'bread', 'polarity': 'positive'}
# {'text': 'I have to say they have one of the fastest delivery times in the city.', 'term': 'delivery times', 'polarity': 'positive'}
# {'text': 'Food is always fresh and hot- ready to eat!', 'term': 'Food', 'polarity': 'positive'}
# {'text': 'Did I mention that the coffee is OUTSTANDING?', 'term': 'coffee', 'polarity': 'positive'}
# {'text': 'Certainly not the best sushi in New York, however, it is always fresh, and the place is very clean, sterile.', 'term': 'sushi', 'polarity': 'conflict'}
# {'text': 'Certainly not the best sushi in New York, however, it is always fresh, and the place is very clean, sterile.', 'term': 'place', 'polarity': 'positive'}
# {'text': 'I trust the people at Go Sushi, it never disappoints.', 'term': 'people', 'polarity': 'positive'}
# {'text': 'Straight-forward, no surprises, very decent Japanese food.', 'term': 'Japanese food', 'polarity': 'positive'}
# {'text': 'BEST spicy tuna roll, great asian salad.', 'term': 'asian salad', 'polarity': 'positive'}
# {'text': 'BEST spicy tuna roll, great asian salad.', 'term': 'spicy tuna roll', 'polarity': 'positive'}
# {'text': 'Try the rose roll (not on menu).', 'term': 'rose roll', 'polarity': 'positive'}
# {'text': 'Try the rose roll (not on menu).', 'term': 'menu', 'polarity': 'neutral'}
# {'text': 'I love the drinks, esp lychee martini, and the food is also VERY good.', 'term': 'drinks', 'polarity': 'positive'}
# {'text': 'I love the drinks, esp lychee martini, and the food is also VERY good.', 'term': 'lychee martini', 'polarity': 'positive'}
# {'text': 'I love the drinks, esp lychee martini, and the food is also VERY good.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'In fact, this was not a Nicoise salad and was barely eatable.', 'term': 'Nicoise salad', 'polarity': 'negative'}
# {'text': "While there's a decent menu, it shouldn't take ten minutes to get your drinks and 45 for a dessert pizza.", 'term': 'menu', 'polarity': 'positive'}
# {'text': "While there's a decent menu, it shouldn't take ten minutes to get your drinks and 45 for a dessert pizza.", 'term': 'drinks', 'polarity': 'neutral'}
# {'text': "While there's a decent menu, it shouldn't take ten minutes to get your drinks and 45 for a dessert pizza.", 'term': 'dessert pizza', 'polarity': 'neutral'}
# {'text': 'Once we sailed, the top-notch food and live entertainment sold us on a unforgettable evening.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'Once we sailed, the top-notch food and live entertainment sold us on a unforgettable evening.', 'term': 'live entertainment', 'polarity': 'positive'}
# {'text': 'Our waiter was horrible; so rude and disinterested.', 'term': 'waiter', 'polarity': 'negative'}
# {'text': "The sangria's - watered down.", 'term': 'sangria', 'polarity': 'negative'}
# {'text': 'menu - uneventful, small.', 'term': 'menu', 'polarity': 'negative'}
# {'text': 'Anytime and everytime I find myself in the neighborhood I will go to Sushi Rose for fresh sushi and great portions all at a reasonable price.', 'term': 'sushi', 'polarity': 'positive'}
# {'text': 'Anytime and everytime I find myself in the neighborhood I will go to Sushi Rose for fresh sushi and great portions all at a reasonable price.', 'term': 'portions', 'polarity': 'positive'}
# {'text': 'Anytime and everytime I find myself in the neighborhood I will go to Sushi Rose for fresh sushi and great portions all at a reasonable price.', 'term': 'price', 'polarity': 'positive'}
# {'text': 'Great food but the service was dreadful!', 'term': 'food', 'polarity': 'positive'}
# {'text': 'Great food but the service was dreadful!', 'term': 'service', 'polarity': 'negative'}
# {'text': 'The portions of the food that came out were mediocre.', 'term': 'portions of the food', 'polarity': 'neutral'}
# {'text': "the two waitress's looked like they had been sucking on lemons.", 'term': "waitress's", 'polarity': 'negative'}
# {'text': 'From the beginning, we were met by friendly staff memebers, and the convienent parking at Chelsea Piers made it easy for us to get to the boat.', 'term': 'staff memebers', 'polarity': 'positive'}
# {'text': 'From the beginning, we were met by friendly staff memebers, and the convienent parking at Chelsea Piers made it easy for us to get to the boat.', 'term': 'parking', 'polarity': 'positive'}
# {'text': 'We enjoyed ourselves thoroughly and will be going back for the desserts ....', 'term': 'desserts', 'polarity': 'positive'}
# {'text': 'Desserts are almost incredible: my personal favorite is their Tart of the Day.', 'term': 'Desserts', 'polarity': 'positive'}
# {'text': 'Desserts are almost incredible: my personal favorite is their Tart of the Day.', 'term': 'Tart of the Day', 'polarity': 'positive'}
# {'text': 'The food was extremely tasty, creatively presented and the wine excellent.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'The food was extremely tasty, creatively presented and the wine excellent.', 'term': 'wine', 'polarity': 'positive'}
# {'text': 'THE LASAGNA WAS PROBABLY THE BEST I HAVE TASTED.', 'term': 'LASAGNA', 'polarity': 'positive'}
# {'text': 'Harumi Sushi has the freshest and most delicious array of sushi in NYC.', 'term': 'array of sushi', 'polarity': 'positive'}
# {'text': 'I highly recommend it for not just its superb cuisine, but also for its friendly owners and staff.', 'term': 'cuisine', 'polarity': 'positive'}
# {'text': 'I highly recommend it for not just its superb cuisine, but also for its friendly owners and staff.', 'term': 'owners', 'polarity': 'positive'}
# {'text': 'I highly recommend it for not just its superb cuisine, but also for its friendly owners and staff.', 'term': 'staff', 'polarity': 'positive'}
# {'text': "If you're craving some serious indian food and desire a cozy ambiance, this is quite and exquisite choice.", 'term': 'indian food', 'polarity': 'positive'}
# {'text': "If you're craving some serious indian food and desire a cozy ambiance, this is quite and exquisite choice.", 'term': 'ambiance', 'polarity': 'positive'}
# {'text': 'I definitely enjoyed the food as well.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'It was pleasantly uncrowded, the service was delightful, the garden adorable, the food (from appetizers to entrees) was delectable.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'It was pleasantly uncrowded, the service was delightful, the garden adorable, the food (from appetizers to entrees) was delectable.', 'term': 'garden', 'polarity': 'positive'}
# {'text': 'It was pleasantly uncrowded, the service was delightful, the garden adorable, the food (from appetizers to entrees) was delectable.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'It was pleasantly uncrowded, the service was delightful, the garden adorable, the food (from appetizers to entrees) was delectable.', 'term': 'appetizers', 'polarity': 'positive'}
# {'text': 'It was pleasantly uncrowded, the service was delightful, the garden adorable, the food (from appetizers to entrees) was delectable.', 'term': 'entrees', 'polarity': 'positive'}
# {'text': 'The food is surprisingly good, and the decor is nice.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'The food is surprisingly good, and the decor is nice.', 'term': 'decor', 'polarity': 'positive'}
# {'text': 'How pretentious and inappropriate for MJ Grill to claim that it provides power lunch and dinners!', 'term': 'lunch', 'polarity': 'negative'}
# {'text': 'How pretentious and inappropriate for MJ Grill to claim that it provides power lunch and dinners!', 'term': 'dinners', 'polarity': 'negative'}
# {'text': 'Two wasted steaks -- what a crime!', 'term': 'steaks', 'polarity': 'negative'}
# {'text': 'The staff should be a bit more friendly.', 'term': 'staff', 'polarity': 'negative'}
# {'text': 'I think the meatball parm is good.', 'term': 'meatball parm', 'polarity': 'positive'}
# {'text': "If you want good tasting, well seasoned latin food eat at Cabana and you can't go wrong.", 'term': 'latin food', 'polarity': 'positive'}
# {'text': 'Definitely try the taglierini with truffles - it was incredible.', 'term': 'taglierini with truffles', 'polarity': 'positive'}
# {'text': 'Also, the staff is very attentive and really personable.', 'term': 'staff', 'polarity': 'positive'}
# {'text': 'The gnocchi literally melts in your mouth!', 'term': 'gnocchi', 'polarity': 'positive'}
# {'text': 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.', 'term': 'staff', 'polarity': 'positive'}
# {'text': 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.', 'term': 'portion size', 'polarity': 'positive'}
# {'text': 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.', 'term': 'portobello/gorgonzola/sausage appetizer', 'polarity': 'positive'}
# {'text': 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.', 'term': 'lobster risotto', 'polarity': 'positive'}
# {'text': 'Entrees include classics like lasagna, fettuccine Alfredo and chicken parmigiana.', 'term': 'Entrees', 'polarity': 'neutral'}
# {'text': 'Entrees include classics like lasagna, fettuccine Alfredo and chicken parmigiana.', 'term': 'lasagna', 'polarity': 'neutral'}
# {'text': 'Entrees include classics like lasagna, fettuccine Alfredo and chicken parmigiana.', 'term': 'fettuccine Alfredo', 'polarity': 'neutral'}
# {'text': 'Entrees include classics like lasagna, fettuccine Alfredo and chicken parmigiana.', 'term': 'chicken parmigiana', 'polarity': 'neutral'}
# {'text': 'The food is good, the teriyaki I recommend.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'The food is good, the teriyaki I recommend.', 'term': 'teriyaki', 'polarity': 'positive'}
# {'text': 'Meal was very expensive for what you get.', 'term': 'Meal', 'polarity': 'negative'}
# {'text': 'Try the Peanut Butter Sorbet and the pizza with soy cheese!', 'term': 'Peanut Butter Sorbet', 'polarity': 'positive'}
# {'text': 'Try the Peanut Butter Sorbet and the pizza with soy cheese!', 'term': 'pizza with soy cheese', 'polarity': 'positive'}
# {'text': 'Good food at the right price, what more can you ask for.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'Good food at the right price, what more can you ask for.', 'term': 'price', 'polarity': 'positive'}
# {'text': 'The food is top notch, the service is attentive, and the atmosphere is great.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'The food is top notch, the service is attentive, and the atmosphere is great.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'The food is top notch, the service is attentive, and the atmosphere is great.', 'term': 'atmosphere', 'polarity': 'positive'}
# {'text': 'Great food, great waitstaff, great atmosphere, and best of all GREAT beer!', 'term': 'food', 'polarity': 'positive'}
# {'text': 'Great food, great waitstaff, great atmosphere, and best of all GREAT beer!', 'term': 'waitstaff', 'polarity': 'positive'}
# {'text': 'Great food, great waitstaff, great atmosphere, and best of all GREAT beer!', 'term': 'atmosphere', 'polarity': 'positive'}
# {'text': 'Great food, great waitstaff, great atmosphere, and best of all GREAT beer!', 'term': 'beer', 'polarity': 'positive'}
# {'text': 'this is still one of my most favorite restaurants in the area the food is inexpensive but very good (kimono shrimp special was excellent) and has a great atmosphere.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'this is still one of my most favorite restaurants in the area the food is inexpensive but very good (kimono shrimp special was excellent) and has a great atmosphere.', 'term': 'kimono shrimp special', 'polarity': 'positive'}
# {'text': 'this is still one of my most favorite restaurants in the area the food is inexpensive but very good (kimono shrimp special was excellent) and has a great atmosphere.', 'term': 'atmosphere', 'polarity': 'positive'}
# {'text': 'The menu is interesting and quite reasonably priced.', 'term': 'menu', 'polarity': 'positive'}
# {'text': 'The menu is interesting and quite reasonably priced.', 'term': 'priced', 'polarity': 'positive'}
# {'text': 'The food was delicious and clearly fresh ingredients were used.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'The food was delicious and clearly fresh ingredients were used.', 'term': 'ingredients', 'polarity': 'positive'}
# {'text': "This made it obvious that the food wasn't cooked fresh; it was obviously made before hand and then reheated.", 'term': 'food', 'polarity': 'negative'}
# {'text': 'Appetizer are excellent here; you can make a great (and inexpensive) meal out of them.', 'term': 'Appetizer', 'polarity': 'positive'}
# {'text': 'Appetizer are excellent here; you can make a great (and inexpensive) meal out of them.', 'term': 'meal', 'polarity': 'positive'}
# {'text': 'The spicy mussels are a highlight.', 'term': 'spicy mussels', 'polarity': 'positive'}
# {'text': "Also get the Onion Rings -- best we've ever had.", 'term': 'Onion Rings', 'polarity': 'positive'}
# {'text': 'However, being foodies, we were utterly disappointed with the food.', 'term': 'food', 'polarity': 'negative'}
# {'text': 'Huge portions, great and attentive service, and pretty good prices.', 'term': 'portions', 'polarity': 'positive'}
# {'text': 'Huge portions, great and attentive service, and pretty good prices.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'Huge portions, great and attentive service, and pretty good prices.', 'term': 'prices', 'polarity': 'positive'}
# {'text': 'I was highly disappointed by their service and food.', 'term': 'service', 'polarity': 'negative'}
# {'text': 'I was highly disappointed by their service and food.', 'term': 'food', 'polarity': 'negative'}
# {'text': 'I complained to the waiter and then to the manager, but the intensity of rudeness from them just went up.', 'term': 'waiter', 'polarity': 'negative'}
# {'text': 'I complained to the waiter and then to the manager, but the intensity of rudeness from them just went up.', 'term': 'manager', 'polarity': 'negative'}
# {'text': 'The food is great and the milkshakes are even better!', 'term': 'food', 'polarity': 'positive'}
# {'text': 'The food is great and the milkshakes are even better!', 'term': 'milkshakes', 'polarity': 'positive'}
# {'text': 'the mushroom barley soup is amazing.', 'term': 'mushroom barley soup', 'polarity': 'positive'}
# {'text': "I'm glad I did as the food was very good and the staff was friendly, courteous and efficient.", 'term': 'food', 'polarity': 'positive'}
# {'text': "I'm glad I did as the food was very good and the staff was friendly, courteous and efficient.", 'term': 'staff', 'polarity': 'positive'}
# {'text': 'Their duck here is also absolutely delicious.', 'term': 'duck', 'polarity': 'positive'}
# {'text': 'While it was large and a bit noisy, the drinks were fantastic, and the food was superb.', 'term': 'drinks', 'polarity': 'positive'}
# {'text': 'While it was large and a bit noisy, the drinks were fantastic, and the food was superb.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'One caveat: Some of the curried casseroles can be a trifle harsh.', 'term': 'curried casseroles', 'polarity': 'negative'}
# {'text': 'The food was almost always EXCELLENT.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'I was pleasently surprised at the taste.', 'term': 'taste', 'polarity': 'positive'}
# {'text': "A nice space, as long as it doesn't get too crowded and a singleminded devotion to its chosen cuisine make Mare a great choice for seafood lovers.", 'term': 'seafood', 'polarity': 'positive'}
# {'text': "A nice space, as long as it doesn't get too crowded and a singleminded devotion to its chosen cuisine make Mare a great choice for seafood lovers.", 'term': 'space', 'polarity': 'conflict'}
# {'text': "A nice space, as long as it doesn't get too crowded and a singleminded devotion to its chosen cuisine make Mare a great choice for seafood lovers.", 'term': 'cuisine', 'polarity': 'positive'}
# {'text': 'I never had an orange donut before so I gave it a shot.', 'term': 'orange donut', 'polarity': 'neutral'}
# {'text': 'they really provide a relaxing, laid-back atmosphere.', 'term': 'atmosphere', 'polarity': 'positive'}
# {'text': 'This particular location certainly uses substandard meats.', 'term': 'meats', 'polarity': 'negative'}
# {'text': 'The Management was less than accomodating.', 'term': 'Management', 'polarity': 'negative'}
# {'text': 'The ambience is also more laid-back and relaxed.', 'term': 'ambience', 'polarity': 'positive'}
# {'text': 'the teas are great and all the sweets are homemade.', 'term': 'teas', 'polarity': 'positive'}
# {'text': 'the teas are great and all the sweets are homemade.', 'term': 'sweets', 'polarity': 'positive'}
# {'text': 'mojitos and the service are the best part in there', 'term': 'mojitos', 'polarity': 'positive'}
# {'text': 'mojitos and the service are the best part in there', 'term': 'service', 'polarity': 'positive'}
# {'text': 'Sandwiches, burgers and salads, like the lemon-dressed cobb, are classic successes.', 'term': 'Sandwiches', 'polarity': 'positive'}
# {'text': 'Sandwiches, burgers and salads, like the lemon-dressed cobb, are classic successes.', 'term': 'burgers', 'polarity': 'positive'}
# {'text': 'Sandwiches, burgers and salads, like the lemon-dressed cobb, are classic successes.', 'term': 'salads', 'polarity': 'positive'}
# {'text': 'Sandwiches, burgers and salads, like the lemon-dressed cobb, are classic successes.', 'term': 'lemon-dressed cobb', 'polarity': 'positive'}
# {'text': 'The design is very intimate and romantic.', 'term': 'design', 'polarity': 'positive'}
# {'text': 'The food was wonderful and imaginative.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'The staff is very sharp and they look good too.', 'term': 'staff', 'polarity': 'positive'}
# {'text': 'The worst though was the taste.', 'term': 'taste', 'polarity': 'negative'}
# {'text': 'The fajita we tried was tasteless and burned and the mole sauce was way too sweet.', 'term': 'fajita', 'polarity': 'negative'}
# {'text': 'The fajita we tried was tasteless and burned and the mole sauce was way too sweet.', 'term': 'mole sauce', 'polarity': 'negative'}
# {'text': "Stay with the roasted chickens and you'll be fine.", 'term': 'roasted chickens', 'polarity': 'positive'}
# {'text': 'The atmosphere is warm, comfortable, artsy and sexy.', 'term': 'atmosphere', 'polarity': 'positive'}
# {'text': 'The food is great (big selection, reasonable prices) and the drinks are really good.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'The food is great (big selection, reasonable prices) and the drinks are really good.', 'term': 'selection', 'polarity': 'positive'}
# {'text': 'The food is great (big selection, reasonable prices) and the drinks are really good.', 'term': 'prices', 'polarity': 'positive'}
# {'text': 'The food is great (big selection, reasonable prices) and the drinks are really good.', 'term': 'drinks', 'polarity': 'positive'}
# {'text': 'The steak melted in my mouth.', 'term': 'steak', 'polarity': 'positive'}
# {'text': "The food did take a few extra minutes to come, but the cute waiters' jokes and friendliness made up for it.", 'term': 'waiters', 'polarity': 'positive'}
# {'text': "The food did take a few extra minutes to come, but the cute waiters' jokes and friendliness made up for it.", 'term': 'food', 'polarity': 'neutral'}
# {'text': 'Most importantly, it is reasonably priced.', 'term': 'priced', 'polarity': 'positive'}
# {'text': "The selection of food is excellent (I'm not used to having much choice at restaurants), and the atmosphere is great.", 'term': 'selection of food', 'polarity': 'positive'}
# {'text': "The selection of food is excellent (I'm not used to having much choice at restaurants), and the atmosphere is great.", 'term': 'atmosphere', 'polarity': 'positive'}
# {'text': 'Only suggestion is that you skip the dessert, it was overpriced and fell short on taste.', 'term': 'dessert', 'polarity': 'negative'}
# {'text': 'Only suggestion is that you skip the dessert, it was overpriced and fell short on taste.', 'term': 'taste', 'polarity': 'negative'}
# {'text': 'Food was decent, but not great.', 'term': 'Food', 'polarity': 'positive'}
# {'text': 'i dont know what some people who rave about this hot dog are talking about.', 'term': 'hot dog', 'polarity': 'negative'}
# {'text': 'it is a hidden delight complete with a quaint bar and good food.', 'term': 'bar', 'polarity': 'positive'}
# {'text': 'it is a hidden delight complete with a quaint bar and good food.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'The waiters ALWAYS look angry and even ignore their high-tipping regulars.', 'term': 'waiters', 'polarity': 'negative'}
# {'text': 'the atmosphere is very nice, and a welcome escape from the rest of the SI mall.', 'term': 'atmosphere', 'polarity': 'positive'}
# {'text': "Yes, they're a bit more expensive then typical, but then again, so is their food.", 'term': 'food', 'polarity': 'positive'}
# {'text': 'I can say that the wraps, burgers and salads were all fresh, tasty and the mango margareta at $9 was WELL WORTH the money.', 'term': 'wraps', 'polarity': 'positive'}
# {'text': 'I can say that the wraps, burgers and salads were all fresh, tasty and the mango margareta at $9 was WELL WORTH the money.', 'term': 'burgers', 'polarity': 'positive'}
# {'text': 'I can say that the wraps, burgers and salads were all fresh, tasty and the mango margareta at $9 was WELL WORTH the money.', 'term': 'salads', 'polarity': 'positive'}
# {'text': 'I can say that the wraps, burgers and salads were all fresh, tasty and the mango margareta at $9 was WELL WORTH the money.', 'term': 'mango margareta', 'polarity': 'positive'}
# {'text': 'Anywhere else, the prices would be 3x as high!', 'term': 'prices', 'polarity': 'positive'}
# {'text': 'The service we experienced was friendly and good.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'Our waiter was friendly and it is a shame that he didnt have a supportive staff to work with.', 'term': 'waiter', 'polarity': 'positive'}
# {'text': 'Our waiter was friendly and it is a shame that he didnt have a supportive staff to work with.', 'term': 'staff', 'polarity': 'negative'}
# {'text': 'The folding chair I was seated at was uncomfortable.', 'term': 'folding chair', 'polarity': 'negative'}
# {'text': 'Service was among the best I have ever had in NYC.', 'term': 'Service', 'polarity': 'positive'}
# {'text': 'The fettucino alfredo was amazing.', 'term': 'fettucino alfredo', 'polarity': 'positive'}
# {'text': 'The food was very good and I was pleasantly surprised to see so many vegan options.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'The food was very good and I was pleasantly surprised to see so many vegan options.', 'term': 'vegan options', 'polarity': 'positive'}
# {'text': "I know real Indian food and this wasn't it.", 'term': 'Indian food', 'polarity': 'negative'}
# {'text': 'Be sure to try the Smoked Trout...Lamb Chops, Veal Chops, Rabbit, the potato gratin, on and on and on...', 'term': 'Smoked Trout', 'polarity': 'positive'}
# {'text': 'Be sure to try the Smoked Trout...Lamb Chops, Veal Chops, Rabbit, the potato gratin, on and on and on...', 'term': 'Lamb Chops', 'polarity': 'positive'}
# {'text': 'Be sure to try the Smoked Trout...Lamb Chops, Veal Chops, Rabbit, the potato gratin, on and on and on...', 'term': 'Veal Chops', 'polarity': 'positive'}
# {'text': 'Be sure to try the Smoked Trout...Lamb Chops, Veal Chops, Rabbit, the potato gratin, on and on and on...', 'term': 'Rabbit', 'polarity': 'positive'}
# {'text': 'Be sure to try the Smoked Trout...Lamb Chops, Veal Chops, Rabbit, the potato gratin, on and on and on...', 'term': 'potato gratin', 'polarity': 'positive'}
# {'text': 'Even when the chef is not in the house, the food and service are right on target.', 'term': 'chef', 'polarity': 'neutral'}
# {'text': 'Even when the chef is not in the house, the food and service are right on target.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'Even when the chef is not in the house, the food and service are right on target.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'Everything from the eggs benedict to the mussels and even the hamburger were done well and very tasty.', 'term': 'eggs benedict', 'polarity': 'positive'}
# {'text': 'Everything from the eggs benedict to the mussels and even the hamburger were done well and very tasty.', 'term': 'mussels', 'polarity': 'positive'}
# {'text': 'Everything from the eggs benedict to the mussels and even the hamburger were done well and very tasty.', 'term': 'hamburger', 'polarity': 'positive'}
# {'text': 'The waiters were very professional, courteous and attentive.', 'term': 'waiters', 'polarity': 'positive'}
# {'text': 'The falafal was rather over cooked and dried but the chicken was fine.', 'term': 'falafal', 'polarity': 'negative'}
# {'text': 'The falafal was rather over cooked and dried but the chicken was fine.', 'term': 'chicken', 'polarity': 'positive'}
# {'text': "I highly reccomend the grand marnier shrimp, it's insanely good.", 'term': 'grand marnier shrimp', 'polarity': 'positive'}
# {'text': 'We been there and we really enjoy the food, was areally great food, and the service was really good.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'We been there and we really enjoy the food, was areally great food, and the service was really good.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'We been there and we really enjoy the food, was areally great food, and the service was really good.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'Desserts include flan and sopaipillas.', 'term': 'Desserts', 'polarity': 'neutral'}
# {'text': 'Desserts include flan and sopaipillas.', 'term': 'flan', 'polarity': 'neutral'}
# {'text': 'Desserts include flan and sopaipillas.', 'term': 'sopaipillas', 'polarity': 'neutral'}
# {'text': 'I was starving and the small portions were driving me crazy!', 'term': 'portions', 'polarity': 'negative'}
# {'text': 'The wait staff was loud and inconsiderate.', 'term': 'wait staff', 'polarity': 'negative'}
# {'text': 'However, the food and service and dramatically lacking.', 'term': 'food', 'polarity': 'negative'}
# {'text': 'However, the food and service and dramatically lacking.', 'term': 'service', 'polarity': 'negative'}
# {'text': 'The sushi is cut in blocks bigger than my cell phone.', 'term': 'sushi', 'polarity': 'negative'}
# {'text': 'The service is great, my soup always arrives nice and hot.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'The service is great, my soup always arrives nice and hot.', 'term': 'soup', 'polarity': 'positive'}
# {'text': 'It had been awhile and I forgot just how delicious crepes can be.', 'term': 'crepes', 'polarity': 'positive'}
# {'text': "Montparnasse's desserts--especially the silken creme brulee and paper-thin apple tart--are good enough on their own to make the restaurant worth the trip.", 'term': 'desserts', 'polarity': 'positive'}
# {'text': "Montparnasse's desserts--especially the silken creme brulee and paper-thin apple tart--are good enough on their own to make the restaurant worth the trip.", 'term': 'creme brulee', 'polarity': 'positive'}
# {'text': "Montparnasse's desserts--especially the silken creme brulee and paper-thin apple tart--are good enough on their own to make the restaurant worth the trip.", 'term': 'apple tart', 'polarity': 'positive'}
# {'text': 'i had a delicious shrimp creole.', 'term': 'shrimp creole', 'polarity': 'positive'}
# {'text': 'The chicken dinner was real good.', 'term': 'chicken dinner', 'polarity': 'positive'}
# {'text': 'Beware of the chili signed food items not unless you want to call the fire department to douse the flames in your mouth.', 'term': 'chili signed food items', 'polarity': 'negative'}
# {'text': 'The decor is designed in a contemporary Japanese style restaurant.', 'term': 'decor', 'polarity': 'neutral'}
# {'text': 'but the food was delicious.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'Try the ribs, sizzling beef and couple it with coconut rice.', 'term': 'coconut rice', 'polarity': 'positive'}
# {'text': 'Try the ribs, sizzling beef and couple it with coconut rice.', 'term': 'ribs', 'polarity': 'positive'}
# {'text': 'Try the ribs, sizzling beef and couple it with coconut rice.', 'term': 'beef', 'polarity': 'positive'}
# {'text': 'The avocado salad is a personal fave.', 'term': 'avocado salad', 'polarity': 'positive'}
# {'text': 'And, the honey BBQ rib tips are yummy!', 'term': 'honey BBQ rib tips', 'polarity': 'positive'}
# {'text': 'The BEST Chinese food Uptown!', 'term': 'Chinese food', 'polarity': 'positive'}
# {'text': 'Service is known for bending over backwards to make everyone happy.', 'term': 'Service', 'polarity': 'positive'}
# {'text': 'The atmosphere is attractive, but a little uncomfortable.', 'term': 'atmosphere', 'polarity': 'conflict'}
# {'text': 'The staff is very friendly.', 'term': 'staff', 'polarity': 'positive'}
# {'text': 'Waiters are very friendly and the pasta is out of this world.', 'term': 'Waiters', 'polarity': 'positive'}
# {'text': 'Waiters are very friendly and the pasta is out of this world.', 'term': 'pasta', 'polarity': 'positive'}
# {'text': 'Great wine list and great cocktail menu.', 'term': 'wine list', 'polarity': 'positive'}
# {'text': 'Great wine list and great cocktail menu.', 'term': 'cocktail menu', 'polarity': 'positive'}
# {'text': 'The crab cakes are delicious and the BBQ rib was perfect.', 'term': 'crab cakes', 'polarity': 'positive'}
# {'text': 'The crab cakes are delicious and the BBQ rib was perfect.', 'term': 'BBQ rib', 'polarity': 'positive'}
# {'text': 'The food is wonderful, artfully done and simply delicious.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'Tiny restaurant with very fast service.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'The sauce may not be for everyone, since it is distintive.', 'term': 'sauce', 'polarity': 'conflict'}
# {'text': "My husband and I have been there at least 6 times and we've always been given the highest service and often free desserts.", 'term': 'service', 'polarity': 'positive'}
# {'text': "My husband and I have been there at least 6 times and we've always been given the highest service and often free desserts.", 'term': 'desserts', 'polarity': 'positive'}
# {'text': 'A beautiful atmosphere, perfect for drinks and/or appetizers.', 'term': 'atmosphere', 'polarity': 'positive'}
# {'text': 'A beautiful atmosphere, perfect for drinks and/or appetizers.', 'term': 'drinks', 'polarity': 'neutral'}
# {'text': 'A beautiful atmosphere, perfect for drinks and/or appetizers.', 'term': 'appetizers', 'polarity': 'neutral'}
# {'text': 'They make the best pizza in New Jersey.', 'term': 'pizza', 'polarity': 'positive'}
# {'text': 'What a difference, the service was very comforting and the food was better than average, but what really standed out was such a dynamic and extensive beer list.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'What a difference, the service was very comforting and the food was better than average, but what really standed out was such a dynamic and extensive beer list.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'What a difference, the service was very comforting and the food was better than average, but what really standed out was such a dynamic and extensive beer list.', 'term': 'beer list', 'polarity': 'positive'}
# {'text': 'Frankly, the chinese food here is something I can make better at home.', 'term': 'chinese food', 'polarity': 'negative'}
# {'text': 'There was only one waiter for the whole restaurant upstairs.', 'term': 'waiter', 'polarity': 'neutral'}
# {'text': 'We started with the scallops and asparagus and also had the soft shell crab as well as the cheese plate.', 'term': 'scallops', 'polarity': 'neutral'}
# {'text': 'We started with the scallops and asparagus and also had the soft shell crab as well as the cheese plate.', 'term': 'asparagus', 'polarity': 'neutral'}
# {'text': 'We started with the scallops and asparagus and also had the soft shell crab as well as the cheese plate.', 'term': 'soft shell crab', 'polarity': 'neutral'}
# {'text': 'We started with the scallops and asparagus and also had the soft shell crab as well as the cheese plate.', 'term': 'cheese plate', 'polarity': 'neutral'}
# {'text': 'Not to be overlooked, the service is excellent.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'this without question is one of the worst hotdogs i have ever had.', 'term': 'hotdogs', 'polarity': 'negative'}
# {'text': 'The staff is unbelievably friendly, and I dream about their Saag gosht...so good.', 'term': 'staff', 'polarity': 'positive'}
# {'text': 'The staff is unbelievably friendly, and I dream about their Saag gosht...so good.', 'term': 'Saag gosht', 'polarity': 'positive'}
# {'text': 'I also recommend the garlic knots.', 'term': 'garlic knots', 'polarity': 'positive'}
# {'text': 'Best Indian food I have ever eaten.', 'term': 'Indian food', 'polarity': 'positive'}
# {'text': 'This place has the best pizza.', 'term': 'pizza', 'polarity': 'positive'}
# {'text': 'The music which is sometimes a little too heavy for my taste.', 'term': 'music', 'polarity': 'negative'}
# {'text': 'The service is excellent and always informative without an air.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'The owner and staff go to great lengths to make you feel comfortable.', 'term': 'owner', 'polarity': 'positive'}
# {'text': 'The owner and staff go to great lengths to make you feel comfortable.', 'term': 'staff', 'polarity': 'positive'}
# {'text': 'The sushi is always fresh and yummy and the menu is pretty varied.', 'term': 'sushi', 'polarity': 'positive'}
# {'text': 'The sushi is always fresh and yummy and the menu is pretty varied.', 'term': 'menu', 'polarity': 'positive'}
# {'text': 'The food was great - sushi was good, but the cooked food amazed us.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'The food was great - sushi was good, but the cooked food amazed us.', 'term': 'sushi', 'polarity': 'positive'}
# {'text': 'The food was great - sushi was good, but the cooked food amazed us.', 'term': 'cooked food', 'polarity': 'positive'}
# {'text': 'their dinner specials are fantastic.', 'term': 'dinner specials', 'polarity': 'positive'}
# {'text': 'Great food, great drinks, nice dining atmosphere.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'Great food, great drinks, nice dining atmosphere.', 'term': 'drinks', 'polarity': 'positive'}
# {'text': 'Great food, great drinks, nice dining atmosphere.', 'term': 'dining atmosphere', 'polarity': 'positive'}
# {'text': "For the price you pay for the food here, you'd expect it to be at least on par with other Japanese restaurants.", 'term': 'price', 'polarity': 'negative'}
# {'text': "For the price you pay for the food here, you'd expect it to be at least on par with other Japanese restaurants.", 'term': 'food', 'polarity': 'negative'}
# {'text': 'Food portion was SMALL and below average.', 'term': 'Food portion', 'polarity': 'negative'}
# {'text': 'Sit back in one of those comfortable chairs.', 'term': 'chairs', 'polarity': 'positive'}
# {'text': 'My favs here are the Tacos Pastor and the Tostada de Tinga...', 'term': 'Tacos Pastor', 'polarity': 'positive'}
# {'text': 'My favs here are the Tacos Pastor and the Tostada de Tinga...', 'term': 'Tostada de Tinga', 'polarity': 'positive'}
# {'text': 'The bartenders and the managers are really nice and the decor is very comfy and laid-back, all the while being trendy.', 'term': 'bartenders', 'polarity': 'positive'}
# {'text': 'The bartenders and the managers are really nice and the decor is very comfy and laid-back, all the while being trendy.', 'term': 'managers', 'polarity': 'positive'}
# {'text': 'The bartenders and the managers are really nice and the decor is very comfy and laid-back, all the while being trendy.', 'term': 'decor', 'polarity': 'positive'}
# {'text': 'For a savory take on the soup and sandwich meal, try the hot and sour soup.', 'term': 'hot and sour soup', 'polarity': 'positive'}
# {'text': 'For a savory take on the soup and sandwich meal, try the hot and sour soup.', 'term': 'soup and sandwich meal', 'polarity': 'positive'}
# {'text': 'This bar has it all - great drinks, cool atmosphere, excellent service and delicious food.', 'term': 'drinks', 'polarity': 'positive'}
# {'text': 'This bar has it all - great drinks, cool atmosphere, excellent service and delicious food.', 'term': 'atmosphere', 'polarity': 'positive'}
# {'text': 'This bar has it all - great drinks, cool atmosphere, excellent service and delicious food.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'This bar has it all - great drinks, cool atmosphere, excellent service and delicious food.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'Also, the chick peas with shrimp (appetizer) is divine.', 'term': 'chick peas with shrimp (appetizer)', 'polarity': 'positive'}
# {'text': 'Finally, I got sick of the bad service, obnoxious smirks, and snotty back talk.', 'term': 'service', 'polarity': 'negative'}
# {'text': 'We ordered lamb which was perfectly cooked and tasted awesome.', 'term': 'lamb', 'polarity': 'positive'}
# {'text': 'i especially like their soft shell crab sandwich with fries.', 'term': 'soft shell crab sandwich with fries', 'polarity': 'positive'}
# {'text': "if you're looking for authentic hong kong-style food, look no further.", 'term': 'hong kong-style food', 'polarity': 'positive'}
# {'text': "good food good wine that's it.", 'term': 'food', 'polarity': 'positive'}
# {'text': "good food good wine that's it.", 'term': 'wine', 'polarity': 'positive'}
# {'text': 'The staff was extremely friendly and pleasant.', 'term': 'staff', 'polarity': 'positive'}
# {'text': 'While their kitchen food is delicious, their Sushi is out of this world.', 'term': 'kitchen food', 'polarity': 'positive'}
# {'text': 'While their kitchen food is delicious, their Sushi is out of this world.', 'term': 'Sushi', 'polarity': 'positive'}
# {'text': 'everything is scrumptious, from the excellent service by cute waitresses, to the extremely lush atmosphere.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'everything is scrumptious, from the excellent service by cute waitresses, to the extremely lush atmosphere.', 'term': 'waitresses', 'polarity': 'positive'}
# {'text': 'everything is scrumptious, from the excellent service by cute waitresses, to the extremely lush atmosphere.', 'term': 'atmosphere', 'polarity': 'positive'}
# {'text': "It's traditional, simple italian food.", 'term': 'italian food', 'polarity': 'positive'}
# {'text': 'The food is all-around good, with the rolls usually excellent and the sushi/sashimi not quite on the same level.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'The food is all-around good, with the rolls usually excellent and the sushi/sashimi not quite on the same level.', 'term': 'rolls', 'polarity': 'positive'}
# {'text': 'The food is all-around good, with the rolls usually excellent and the sushi/sashimi not quite on the same level.', 'term': 'sushi/sashimi', 'polarity': 'neutral'}
# {'text': '(The sashimi is cut a little thinly.', 'term': 'sashimi', 'polarity': 'negative'}
# {'text': 'Could have had better for 1/3 the price in Chinatown.', 'term': 'price', 'polarity': 'negative'}
# {'text': 'In addition to great hot dogs, DOTP has wonderful breakfast sandwiches that feature, in addition to great things like tator tots and English muffins, a delicious NJ-based pork product know to us Jersey girls and boys as Taylor ham.', 'term': 'hot dogs', 'polarity': 'positive'}
# {'text': 'In addition to great hot dogs, DOTP has wonderful breakfast sandwiches that feature, in addition to great things like tator tots and English muffins, a delicious NJ-based pork product know to us Jersey girls and boys as Taylor ham.', 'term': 'breakfast sandwiches', 'polarity': 'positive'}
# {'text': 'In addition to great hot dogs, DOTP has wonderful breakfast sandwiches that feature, in addition to great things like tator tots and English muffins, a delicious NJ-based pork product know to us Jersey girls and boys as Taylor ham.', 'term': 'tator tots', 'polarity': 'positive'}
# {'text': 'In addition to great hot dogs, DOTP has wonderful breakfast sandwiches that feature, in addition to great things like tator tots and English muffins, a delicious NJ-based pork product know to us Jersey girls and boys as Taylor ham.', 'term': 'English muffins', 'polarity': 'positive'}
# {'text': 'In addition to great hot dogs, DOTP has wonderful breakfast sandwiches that feature, in addition to great things like tator tots and English muffins, a delicious NJ-based pork product know to us Jersey girls and boys as Taylor ham.', 'term': 'Taylor ham', 'polarity': 'positive'}
# {'text': 'In addition to great hot dogs, DOTP has wonderful breakfast sandwiches that feature, in addition to great things like tator tots and English muffins, a delicious NJ-based pork product know to us Jersey girls and boys as Taylor ham.', 'term': 'pork product', 'polarity': 'positive'}
# {'text': 'Well, it happened because of a graceless manager and a rude bartender who had us waiting 20 minutes for drinks, and then tells us to chill out.', 'term': 'manager', 'polarity': 'negative'}
# {'text': 'Well, it happened because of a graceless manager and a rude bartender who had us waiting 20 minutes for drinks, and then tells us to chill out.', 'term': 'bartender', 'polarity': 'negative'}
# {'text': 'Well, it happened because of a graceless manager and a rude bartender who had us waiting 20 minutes for drinks, and then tells us to chill out.', 'term': 'drinks', 'polarity': 'neutral'}
# {'text': 'Well, it happened because of a graceless manager and a rude bartender who had us waiting 20 minutes for drinks, and then tells us to chill out.', 'term': 'waiting', 'polarity': 'negative'}
# {'text': 'Not only is the service great, but forming conversation around a table is so easy beacuse the atmosphere can be both romantic and comfortable.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'Not only is the service great, but forming conversation around a table is so easy beacuse the atmosphere can be both romantic and comfortable.', 'term': 'atmosphere', 'polarity': 'positive'}
# {'text': 'When the dish arrived it was blazing with green chillis, definitely not edible by a human.', 'term': 'green chillis', 'polarity': 'negative'}
# {'text': 'When the dish arrived it was blazing with green chillis, definitely not edible by a human.', 'term': 'dish', 'polarity': 'negative'}
# {'text': "The absolute worst service I've ever experienced and the food was below average (when they actually gave people the meals they ordered).", 'term': 'service', 'polarity': 'negative'}
# {'text': "The absolute worst service I've ever experienced and the food was below average (when they actually gave people the meals they ordered).", 'term': 'food', 'polarity': 'negative'}
# {'text': "The absolute worst service I've ever experienced and the food was below average (when they actually gave people the meals they ordered).", 'term': 'meals', 'polarity': 'neutral'}
# {'text': "It's about $7 for lunch and they have take-out or dine-in.", 'term': 'lunch', 'polarity': 'neutral'}
# {'text': "It's about $7 for lunch and they have take-out or dine-in.", 'term': 'take-out', 'polarity': 'neutral'}
# {'text': "It's about $7 for lunch and they have take-out or dine-in.", 'term': 'dine-in', 'polarity': 'neutral'}
# {'text': 'Be sure to accompany your food with one of their fresh juice concoctions.', 'term': 'food', 'polarity': 'neutral'}
# {'text': 'Be sure to accompany your food with one of their fresh juice concoctions.', 'term': 'fresh juice concoctions', 'polarity': 'positive'}
# {'text': 'The food is great and the prices are reasonable.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'The food is great and the prices are reasonable.', 'term': 'prices', 'polarity': 'positive'}
# {'text': 'The place is clean, and if you like soul food, then this is the place to be!', 'term': 'place', 'polarity': 'positive'}
# {'text': 'The place is clean, and if you like soul food, then this is the place to be!', 'term': 'soul food', 'polarity': 'positive'}
# {'text': 'I had roast chicken and a salad.', 'term': 'roast chicken', 'polarity': 'neutral'}
# {'text': 'I had roast chicken and a salad.', 'term': 'salad', 'polarity': 'neutral'}
# {'text': 'They have a very good chicken with avocado and good tuna as well.', 'term': 'chicken with avocado', 'polarity': 'positive'}
# {'text': 'They have a very good chicken with avocado and good tuna as well.', 'term': 'tuna', 'polarity': 'positive'}
# {'text': 'But the meals were terrible.', 'term': 'meals', 'polarity': 'negative'}
# {'text': 'My chicken was completely dried out and on the cold side and the sauce was not very flavorful.', 'term': 'chicken', 'polarity': 'negative'}
# {'text': 'My chicken was completely dried out and on the cold side and the sauce was not very flavorful.', 'term': 'sauce', 'polarity': 'negative'}
# {'text': 'Malted Milk Ball Gelato - have you ever in your life heard of anything so ridiculously wonderful?', 'term': 'Malted Milk Ball Gelato', 'polarity': 'positive'}
# {'text': 'Way too much money for such a terrible meal.', 'term': 'meal', 'polarity': 'negative'}
# {'text': 'However, the service is absolutely horrible.', 'term': 'service', 'polarity': 'negative'}
# {'text': 'A con was the slow bar service.', 'term': 'bar service', 'polarity': 'negative'}
# {'text': 'Dessert was also to die for!', 'term': 'Dessert', 'polarity': 'positive'}
# {'text': 'BTW, the service is very good .', 'term': 'service', 'polarity': 'positive'}
# {'text': "It's eaten with black vinegar and shredded ginger.", 'term': 'black vinegar', 'polarity': 'neutral'}
# {'text': "It's eaten with black vinegar and shredded ginger.", 'term': 'shredded ginger', 'polarity': 'neutral'}
# {'text': 'The unattractive lighting made me want to gag, the food was overpriced, there was the most awful disco pop duo performing-and my escargot looked like it might crawl off the plate.', 'term': 'lighting', 'polarity': 'negative'}
# {'text': 'The unattractive lighting made me want to gag, the food was overpriced, there was the most awful disco pop duo performing-and my escargot looked like it might crawl off the plate.', 'term': 'food', 'polarity': 'negative'}
# {'text': 'The unattractive lighting made me want to gag, the food was overpriced, there was the most awful disco pop duo performing-and my escargot looked like it might crawl off the plate.', 'term': 'disco pop duo', 'polarity': 'negative'}
# {'text': 'The unattractive lighting made me want to gag, the food was overpriced, there was the most awful disco pop duo performing-and my escargot looked like it might crawl off the plate.', 'term': 'escargot', 'polarity': 'negative'}
# {'text': 'it is a cozy place to go with a couple of friends.', 'term': 'place', 'polarity': 'positive'}
# {'text': 'The service is always great, and the owner walks around to make sure you enjoy.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'The service is always great, and the owner walks around to make sure you enjoy.', 'term': 'owner', 'polarity': 'positive'}
# {'text': 'because the waiters need SEVERE ATTITUE ADJUSTMENTS.', 'term': 'waiters', 'polarity': 'negative'}
# {'text': 'the food is delicious and highly recommended.', 'term': 'food', 'polarity': 'positive'}
# ...
# {'text': 'However, there is just something so great about being outdoors, in great landscaping, enjoying a casual drink that makes going to this place worthwhile.', 'term': 'place', 'polarity': 'positive'}
# {'text': 'We were seated promptly in close proximity to the dance floor.', 'term': 'dance floor', 'polarity': 'neutral'}
# {'text': 'If you are here as a pre-show meal, hop in a cab and take the extra 10 minutes to go to the uptown location.', 'term': 'pre-show meal', 'polarity': 'neutral'}
# {'text': 'The comments about fried foods is correct (below) but the other dishes, including the lamb entree and many of the salads (avocado shrimp) were quite good.', 'term': 'fried foods', 'polarity': 'negative'}
# {'text': 'The comments about fried foods is correct (below) but the other dishes, including the lamb entree and many of the salads (avocado shrimp) were quite good.', 'term': 'dishes', 'polarity': 'positive'}
# {'text': 'The comments about fried foods is correct (below) but the other dishes, including the lamb entree and many of the salads (avocado shrimp) were quite good.', 'term': 'lamb entree', 'polarity': 'positive'}
# {'text': 'The comments about fried foods is correct (below) but the other dishes, including the lamb entree and many of the salads (avocado shrimp) were quite good.', 'term': 'salads (avocado shrimp)', 'polarity': 'positive'}
# {'text': "Slow service, but when you're hanging around with groups of 10 or 20, who really notices?", 'term': 'service', 'polarity': 'negative'}
# {'text': 'The sauce is excellent (very fresh) with dabs of real mozzarella.', 'term': 'dabs of real mozzarella', 'polarity': 'neutral'}
# {'text': 'The sauce is excellent (very fresh) with dabs of real mozzarella.', 'term': 'sauce', 'polarity': 'positive'}
# {'text': "Don't ever bother - the drinks were awful, but it was the people who work there that really made this the worst experience at dining.", 'term': 'drinks', 'polarity': 'negative'}
# {'text': "Don't ever bother - the drinks were awful, but it was the people who work there that really made this the worst experience at dining.", 'term': 'people', 'polarity': 'negative'}
# {'text': "Don't ever bother - the drinks were awful, but it was the people who work there that really made this the worst experience at dining.", 'term': 'dining', 'polarity': 'negative'}
# {'text': "The room is a little plain, but it's difficult to make such a small place exciting and I would not suggest that as a reason not to go.", 'term': 'room', 'polarity': 'negative'}
# {'text': "The room is a little plain, but it's difficult to make such a small place exciting and I would not suggest that as a reason not to go.", 'term': 'place', 'polarity': 'negative'}
# {'text': 'Prices even outside of restaurant week were great.', 'term': 'Prices', 'polarity': 'positive'}
# {'text': 'A small, outdoor eating area makes for a private, comfortable space to study alone or meet up with friends.', 'term': 'space', 'polarity': 'positive'}
# {'text': 'A small, outdoor eating area makes for a private, comfortable space to study alone or meet up with friends.', 'term': 'outdoor eating area', 'polarity': 'positive'}
# {'text': 'And all the [female] servers are cute too, which is always nice.', 'term': '[female] servers', 'polarity': 'positive'}
# {'text': "The best dessert, a chocolate and peanut butter tart, isn't particularly Hawaiian, but it's a small world when it comes to sweets.", 'term': 'dessert', 'polarity': 'positive'}
# {'text': "The best dessert, a chocolate and peanut butter tart, isn't particularly Hawaiian, but it's a small world when it comes to sweets.", 'term': 'chocolate and peanut butter tart', 'polarity': 'positive'}
# {'text': "The best dessert, a chocolate and peanut butter tart, isn't particularly Hawaiian, but it's a small world when it comes to sweets.", 'term': 'sweets', 'polarity': 'neutral'}
# {'text': 'for an appetizer, their calamari is a winner.', 'term': 'appetizer', 'polarity': 'neutral'}
# {'text': 'for an appetizer, their calamari is a winner.', 'term': 'calamari', 'polarity': 'positive'}
# {'text': 'Satay is one of those favorite haunts on Washington where the service and food is always on the money.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'Satay is one of those favorite haunts on Washington where the service and food is always on the money.', 'term': 'food', 'polarity': 'positive'}
# {'text': 'After dinner I heard music playing and discovered that there is a lounge downstairs.', 'term': 'dinner', 'polarity': 'neutral'}
# {'text': 'After dinner I heard music playing and discovered that there is a lounge downstairs.', 'term': 'music', 'polarity': 'neutral'}
# {'text': 'After dinner I heard music playing and discovered that there is a lounge downstairs.', 'term': 'lounge', 'polarity': 'neutral'}
# {'text': 'The room is a gorgeous, bi-level space and the long bar perfect for a drink.', 'term': 'room', 'polarity': 'positive'}
# {'text': 'The room is a gorgeous, bi-level space and the long bar perfect for a drink.', 'term': 'bi-level space', 'polarity': 'positive'}
# {'text': 'The room is a gorgeous, bi-level space and the long bar perfect for a drink.', 'term': 'long bar', 'polarity': 'positive'}
# {'text': 'The room is a gorgeous, bi-level space and the long bar perfect for a drink.', 'term': 'drink', 'polarity': 'neutral'}
# {'text': 'Two complaints- their appetizer selection stinks, it would be nice to get some mozzarella sticks on the menu.', 'term': 'appetizer selection', 'polarity': 'negative'}
# {'text': 'Two complaints- their appetizer selection stinks, it would be nice to get some mozzarella sticks on the menu.', 'term': 'mozzarella sticks', 'polarity': 'neutral'}
# {'text': 'Two complaints- their appetizer selection stinks, it would be nice to get some mozzarella sticks on the menu.', 'term': 'menu', 'polarity': 'negative'}
# {'text': 'I was especially impressed during the bday party when the waitstaff went above and beyond in helping me decorate and bring out a bday cake as well as offering prompt and friendly service to a 15 person party.', 'term': 'waitstaff', 'polarity': 'positive'}
# {'text': 'I was especially impressed during the bday party when the waitstaff went above and beyond in helping me decorate and bring out a bday cake as well as offering prompt and friendly service to a 15 person party.', 'term': 'service', 'polarity': 'positive'}
# {'text': 'The chicken and falafel platters were nondescript combinations with fresh leaf salad.', 'term': 'chicken and falafel platters', 'polarity': 'neutral'}
# {'text': 'The chicken and falafel platters were nondescript combinations with fresh leaf salad.', 'term': 'fresh leaf salad', 'polarity': 'neutral'}
# {'text': 'The atmosphere takes you to that place, the place many dream of.', 'term': 'atmosphere', 'polarity': 'positive'}
# {'text': "several times and put up with the waiters' bad manners, knowing that their job isn't easy.", 'term': 'waiters', 'polarity': 'negative'}
# {'text': 'The service is great (maybe even borderline nagging but at least you get attention), the desserts are excellent and the coffee is so very good...', 'term': 'service', 'polarity': 'conflict'}
# {'text': 'The service is great (maybe even borderline nagging but at least you get attention), the desserts are excellent and the coffee is so very good...', 'term': 'desserts', 'polarity': 'positive'}
# {'text': 'The service is great (maybe even borderline nagging but at least you get attention), the desserts are excellent and the coffee is so very good...', 'term': 'coffee', 'polarity': 'positive'}
# {'text': 'They are served on Focacchia bread and are to die for.', 'term': 'served', 'polarity': 'neutral'}
# {'text': 'They are served on Focacchia bread and are to die for.', 'term': 'Focacchia bread', 'polarity': 'neutral'}
# {'text': 'While the smoothies are a little big for me, the fresh juices are the best I have ever had!', 'term': 'smoothies', 'polarity': 'negative'}
# {'text': 'While the smoothies are a little big for me, the fresh juices are the best I have ever had!', 'term': 'fresh juices', 'polarity': 'positive'}
# {'text': "The food is just OKAY, and it's almost not worth going unless you're getting the pialla, which is the only dish that's really good.", 'term': 'food', 'polarity': 'conflict'}
# {'text': "The food is just OKAY, and it's almost not worth going unless you're getting the pialla, which is the only dish that's really good.", 'term': 'pialla', 'polarity': 'positive'}
# {'text': "The food is just OKAY, and it's almost not worth going unless you're getting the pialla, which is the only dish that's really good.", 'term': 'dish', 'polarity': 'positive'}
# {'text': 'The guac is fresh, yet lacking flavor, we like to add our fresh salsa into it.', 'term': 'guac', 'polarity': 'conflict'}
# {'text': 'The guac is fresh, yet lacking flavor, we like to add our fresh salsa into it.', 'term': 'fresh salsa', 'polarity': 'neutral'}
# {'text': 'The guac is fresh, yet lacking flavor, we like to add our fresh salsa into it.', 'term': 'flavor', 'polarity': 'negative'}
# {'text': "The new menu has a few creative items,they were smart enough to keep some of the old favorites (but they raised the prices), the staff is friendly most of the time, but I must agree with the person that wrote about their favorite words: No, can't, sorry..., boy, they won't bend the rules for anyone.", 'term': 'prices', 'polarity': 'negative'}
# {'text': "The new menu has a few creative items,they were smart enough to keep some of the old favorites (but they raised the prices), the staff is friendly most of the time, but I must agree with the person that wrote about their favorite words: No, can't, sorry..., boy, they won't bend the rules for anyone.", 'term': 'staff', 'polarity': 'conflict'}
# {'text': "The new menu has a few creative items,they were smart enough to keep some of the old favorites (but they raised the prices), the staff is friendly most of the time, but I must agree with the person that wrote about their favorite words: No, can't, sorry..., boy, they won't bend the rules for anyone.", 'term': 'new menu', 'polarity': 'positive'}
# {'text': "It' only open for lunch but the food is so good!", 'term': 'lunch', 'polarity': 'neutral'}
# {'text': "It' only open for lunch but the food is so good!", 'term': 'food', 'polarity': 'positive'}
# {'text': 'If you like seafood and/or Greek food you will love this place though it is not limited to just these things.', 'term': 'seafood', 'polarity': 'positive'}
# {'text': 'If you like seafood and/or Greek food you will love this place though it is not limited to just these things.', 'term': 'Greek food', 'polarity': 'positive'}
# {'text': '" The menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians.', 'term': 'menu', 'polarity': 'neutral'}
# {'text': '" The menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians.', 'term': 'burgers', 'polarity': 'neutral'}
# {'text': '" The menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians.', 'term': 'steaks', 'polarity': 'neutral'}
# {'text': '" The menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians.', 'term': 'shepherds pie', 'polarity': 'neutral'}
# {'text': '" The menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians.', 'term': 'portabella lasagna', 'polarity': 'neutral'}
# {'text': '" The menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians.', 'term': 'pub fare', 'polarity': 'neutral'}
# {'text': 'How can they survive serving mediocre food at exorbitant prices?!', 'term': 'food', 'polarity': 'neutral'}
# {'text': 'How can they survive serving mediocre food at exorbitant prices?!', 'term': 'prices', 'polarity': 'negative'}
# {'text': 'The food was mediocre and the service was severely slow.', 'term': 'service', 'polarity': 'negative'}
# {'text': 'The food was mediocre and the service was severely slow.', 'term': 'food', 'polarity': 'neutral'}
# {'text': 'i have eaten here on a different occasion - the food is mediocre for the prices.', 'term': 'food', 'polarity': 'neutral'}
# {'text': 'i have eaten here on a different occasion - the food is mediocre for the prices.', 'term': 'prices', 'polarity': 'negative'}
# {'text': "I'm looking forward to going back soon and eventually trying most everything on the menu!", 'term': 'menu', 'polarity': 'positive'}
# {'text': "I just had my first visit to this place and can't wait to go back and slowly work my way through the menu.", 'term': 'menu', 'polarity': 'neutral'}
# {'text': 'I asked repeatedly what the status of the meal was and was pretty much grunted at by the unbelievably rude waiter.', 'term': 'waiter', 'polarity': 'negative'}
# {'text': 'I asked repeatedly what the status of the meal was and was pretty much grunted at by the unbelievably rude waiter.', 'term': 'meal', 'polarity': 'neutral'}
# {'text': 'I stopped by for some brunch today and had the vegan cranberry pancakes and some rice milk.', 'term': 'brunch', 'polarity': 'neutral'}
# {'text': 'I stopped by for some brunch today and had the vegan cranberry pancakes and some rice milk.', 'term': 'vegan cranberry pancakes', 'polarity': 'neutral'}
# {'text': 'I stopped by for some brunch today and had the vegan cranberry pancakes and some rice milk.', 'term': 'rice milk', 'polarity': 'neutral'}
# {'text': 'Sweet Irish bartender is always happy and able to bring a smile to my friends a my face.', 'term': 'bartender', 'polarity': 'positive'}
# {'text': "Its good to go there for drinks if you don't want to get drunk because you'll be lucky if you can get one drink an hour the service is so bad.", 'term': 'service', 'polarity': 'negative'}
# {'text': "Its good to go there for drinks if you don't want to get drunk because you'll be lucky if you can get one drink an hour the service is so bad.", 'term': 'drink', 'polarity': 'neutral'}
# {'text': "Its good to go there for drinks if you don't want to get drunk because you'll be lucky if you can get one drink an hour the service is so bad.", 'term': 'drinks', 'polarity': 'neutral'}
# {'text': 'Anyway, the owner was fake.', 'term': 'owner', 'polarity': 'negative'}
# {'text': 'Owner is pleasant and entertaining.', 'term': 'Owner', 'polarity': 'positive'}
# {'text': 'I have never in my life sent back food before, but I simply had to, and the waiter argued with me over this.', 'term': 'food', 'polarity': 'negative'}
# {'text': 'I have never in my life sent back food before, but I simply had to, and the waiter argued with me over this.', 'term': 'waiter', 'polarity': 'negative'}
# {'text': 'Although the restaurant itself is nice, I prefer not to go for the food.', 'term': 'food', 'polarity': 'negative'}
# {'text': 'Creamy appetizers--taramasalata, eggplant salad, and Greek yogurt (with cuccumber, dill, and garlic) taste excellent when on warm pitas.', 'term': 'Creamy appetizers', 'polarity': 'positive'}
# {'text': 'Creamy appetizers--taramasalata, eggplant salad, and Greek yogurt (with cuccumber, dill, and garlic) taste excellent when on warm pitas.', 'term': 'warm pitas', 'polarity': 'neutral'}
# {'text': 'Creamy appetizers--taramasalata, eggplant salad, and Greek yogurt (with cuccumber, dill, and garlic) taste excellent when on warm pitas.', 'term': 'taramasalata', 'polarity': 'positive'}
# {'text': 'Creamy appetizers--taramasalata, eggplant salad, and Greek yogurt (with cuccumber, dill, and garlic) taste excellent when on warm pitas.', 'term': 'eggplant salad', 'polarity': 'positive'}
# {'text': 'Creamy appetizers--taramasalata, eggplant salad, and Greek yogurt (with cuccumber, dill, and garlic) taste excellent when on warm pitas.', 'term': 'Greek yogurt (with cuccumber, dill, and garlic)', 'polarity': 'positive'}

# %%
# -*- coding: utf-8 -*-


import os
import pickle
import torch
import torch.nn.functional as F
import argparse

from data_utils import ABSADatesetReader, ABSADataset, Tokenizer, build_embedding_matrix
from bucket_iterator import BucketIterator
from models import LSTM, PWCN_POS, PWCN_DEP
from dependency_dist import dependency_dist_func

class Inferer:
    """A simple inference example"""
    def __init__(self, opt):
        self.opt = opt
        print("loading {0} tokenizer...".format(opt.dataset))
        with open(opt.dataset+'_word2idx.pkl', 'rb') as f:
            word2idx = pickle.load(f)
            self.tokenizer = Tokenizer(word2idx=word2idx)
        embedding_matrix = build_embedding_matrix(self.tokenizer.word2idx, opt.embed_dim, opt.dataset)
        self.model = opt.model_class(embedding_matrix, opt)
        print('loading model {0} ...'.format(opt.model_name))
        self.model.load_state_dict(torch.load(opt.state_dict_path, map_location=lambda storage, loc: storage))
        # switch model to evaluation mode
        self.model.eval()
        torch.autograd.set_grad_enabled(False)

    def evaluate(self, raw_text, aspect):
        text_seqs = [self.tokenizer.text_to_sequence(raw_text.lower().strip())]
        aspect_seqs = [self.tokenizer.text_to_sequence(aspect.lower())]
        left_seqs = [self.tokenizer.text_to_sequence(raw_text.lower().split(aspect.lower())[0])]
        text_indices = torch.tensor(text_seqs, dtype=torch.int64)
        aspect_indices = torch.tensor(aspect_seqs, dtype=torch.int64)
        left_indices = torch.tensor(left_seqs, dtype=torch.int64)
        dependency_dist = torch.tensor([dependency_dist_func(raw_text, aspect)], dtype=torch.int64)
        data = {
            'text_indices':text_indices, 
            'aspect_indices':aspect_indices, 
            'left_indices':left_indices,
            'dependency_dist':dependency_dist,
        }
        t_inputs = [data[col] for col in self.opt.inputs_cols]
        t_outputs = self.model(t_inputs)

        t_probs = F.softmax(t_outputs, dim=-1).cpu().numpy()
        return t_probs

if __name__ == '__main__':
    model_classes = {
        'lstm': LSTM,
        'pwcn_pos': PWCN_POS,
        'pwcn_dep': PWCN_DEP,
    }
    dataset = 'restaurant'
    # set your trained models here
    model_state_dict_paths = {
        'lstm': 'state_dict/lstm_'+dataset+'.pkl',
        'pwcn_pos': 'state_dict/pwcn_pos_'+dataset+'.pkl',
        'pwcn_dep': 'state_dict/pwcn_dep_'+dataset+'.pkl',
    }
    input_colses = {
        'lstm': ['text_indices'],
        'pwcn_pos': ['text_indices', 'aspect_indices', 'left_indices'], 
        'pwcn_dep': ['text_indices', 'aspect_indices', 'left_indices', 'dependency_dist'],
    }
    class Option(object): pass
    opt = Option()
    opt.model_name = 'pwcn_dep'
    opt.model_class = model_classes[opt.model_name]
    opt.inputs_cols = input_colses[opt.model_name]
    opt.dataset = dataset
    opt.state_dict_path = model_state_dict_paths[opt.model_name]
    opt.embed_dim = 300
    opt.hidden_dim = 300
    opt.polarities_dim = 3
    opt.device = torch.device('cpu')

    inf = Inferer(opt)

    wrong_count = 0
    wrong_items = []
    for item in extracted_info:    
        

        sentence = item['text'].lower()
        aspect = item['term'].lower()
        polarity = item['polarity']
        t_probs = inf.evaluate(sentence, aspect)
        result_polarity = t_probs.argmax(axis=-1) 

        if result_polarity[0] == 2:
            sentiment_result = "positive"
        elif result_polarity[0] == 1:
            sentiment_result = "neutral"
        else:
            sentiment_result = "negative"

        # print(sentiment_result, polarity)

        if sentiment_result != polarity:
            print('WRONG!!', 'expected: ', polarity, 'result: ', sentiment_result)
            print(sentence, aspect, result_polarity[0])
            wrong_count = wrong_count+1
            wrong_items.append({'text': sentence, 'aspect': aspect, 'expected': polarity, 'result': sentiment_result})

            
    print(wrong_count, ' out of ', len(extracted_info))   

        # print(t_probs.argmax(axis=-1))
# Out:
# loading restaurant tokenizer...
# loading embedding_matrix: 300_restaurant_embedding_matrix.pkl
# loading model pwcn_dep ...
# WRONG!! expected:  positive result:  negative
# i have to say they have one of the fastest delivery times in the city. delivery times 0
# WRONG!! expected:  conflict result:  negative
# certainly not the best sushi in new york, however, it is always fresh, and the place is very clean, sterile. sushi 0
# WRONG!! expected:  neutral result:  positive
# try the rose roll (not on menu). menu 2
# WRONG!! expected:  negative result:  neutral
# in fact, this was not a nicoise salad and was barely eatable. nicoise salad 1
# WRONG!! expected:  negative result:  neutral
# the sangria's - watered down. sangria 1
# WRONG!! expected:  negative result:  positive
# menu - uneventful, small. menu 2
# WRONG!! expected:  negative result:  positive
# great food but the service was dreadful! service 2
# WRONG!! expected:  positive result:  neutral
# desserts are almost incredible: my personal favorite is their tart of the day. desserts 1
# WRONG!! expected:  positive result:  neutral
# if you want good tasting, well seasoned latin food eat at cabana and you can't go wrong. latin food 1
# WRONG!! expected:  neutral result:  positive
# entrees include classics like lasagna, fettuccine alfredo and chicken parmigiana. entrees 2
# WRONG!! expected:  neutral result:  positive
# entrees include classics like lasagna, fettuccine alfredo and chicken parmigiana. lasagna 2
# WRONG!! expected:  neutral result:  positive
# entrees include classics like lasagna, fettuccine alfredo and chicken parmigiana. fettuccine alfredo 2
# WRONG!! expected:  neutral result:  positive
# entrees include classics like lasagna, fettuccine alfredo and chicken parmigiana. chicken parmigiana 2
# WRONG!! expected:  negative result:  positive
# this made it obvious that the food wasn't cooked fresh; it was obviously made before hand and then reheated. food 2
# WRONG!! expected:  negative result:  positive
# i was highly disappointed by their service and food. service 2
# WRONG!! expected:  negative result:  positive
# i was highly disappointed by their service and food. food 2
# WRONG!! expected:  negative result:  neutral
# i complained to the waiter and then to the manager, but the intensity of rudeness from them just went up. manager 1
# WRONG!! expected:  negative result:  positive
# one caveat: some of the curried casseroles can be a trifle harsh. curried casseroles 2
# WRONG!! expected:  conflict result:  positive
# a nice space, as long as it doesn't get too crowded and a singleminded devotion to its chosen cuisine make mare a great choice for seafood lovers. space 2
# WRONG!! expected:  positive result:  negative
# the steak melted in my mouth. steak 0
# WRONG!! expected:  neutral result:  positive
# the food did take a few extra minutes to come, but the cute waiters' jokes and friendliness made up for it. food 2
# WRONG!! expected:  negative result:  neutral
# i dont know what some people who rave about this hot dog are talking about. hot dog 1
# WRONG!! expected:  negative result:  positive
# the waiters always look angry and even ignore their high-tipping regulars. waiters 2
# WRONG!! expected:  positive result:  negative
# anywhere else, the prices would be 3x as high! prices 0
# WRONG!! expected:  negative result:  positive
# our waiter was friendly and it is a shame that he didnt have a supportive staff to work with. staff 2
# WRONG!! expected:  negative result:  positive
# the folding chair i was seated at was uncomfortable. folding chair 2
# WRONG!! expected:  negative result:  positive
# i know real indian food and this wasn't it. indian food 2
# WRONG!! expected:  positive result:  neutral
# even when the chef is not in the house, the food and service are right on target. food 1
# WRONG!! expected:  positive result:  neutral
# even when the chef is not in the house, the food and service are right on target. service 1
# WRONG!! expected:  positive result:  neutral
# everything from the eggs benedict to the mussels and even the hamburger were done well and very tasty. mussels 1
# WRONG!! expected:  positive result:  negative
# the falafal was rather over cooked and dried but the chicken was fine. chicken 0
# WRONG!! expected:  neutral result:  positive
# desserts include flan and sopaipillas. desserts 2
# WRONG!! expected:  neutral result:  positive
# desserts include flan and sopaipillas. flan 2
# WRONG!! expected:  neutral result:  positive
# desserts include flan and sopaipillas. sopaipillas 2
# WRONG!! expected:  negative result:  positive
# however, the food and service and dramatically lacking. food 2
# WRONG!! expected:  negative result:  positive
# however, the food and service and dramatically lacking. service 2
# WRONG!! expected:  negative result:  neutral
# the sushi is cut in blocks bigger than my cell phone. sushi 1
# WRONG!! expected:  neutral result:  positive
# the decor is designed in a contemporary japanese style restaurant. decor 2
# WRONG!! expected:  conflict result:  positive
# the atmosphere is attractive, but a little uncomfortable. atmosphere 2
# WRONG!! expected:  conflict result:  negative
# the sauce may not be for everyone, since it is distintive. sauce 0
# WRONG!! expected:  neutral result:  positive
# a beautiful atmosphere, perfect for drinks and/or appetizers. drinks 2
# WRONG!! expected:  neutral result:  positive
# a beautiful atmosphere, perfect for drinks and/or appetizers. appetizers 2
# WRONG!! expected:  negative result:  neutral
# frankly, the chinese food here is something i can make better at home. chinese food 1
# WRONG!! expected:  neutral result:  negative
# there was only one waiter for the whole restaurant upstairs. waiter 0
# WRONG!! expected:  neutral result:  positive
# we started with the scallops and asparagus and also had the soft shell crab as well as the cheese plate. soft shell crab 2
# WRONG!! expected:  neutral result:  positive
# we started with the scallops and asparagus and also had the soft shell crab as well as the cheese plate. cheese plate 2
# WRONG!! expected:  positive result:  neutral
# their dinner specials are fantastic. dinner specials 1
# WRONG!! expected:  negative result:  positive
# for the price you pay for the food here, you'd expect it to be at least on par with other japanese restaurants. price 2
# WRONG!! expected:  negative result:  positive
# for the price you pay for the food here, you'd expect it to be at least on par with other japanese restaurants. food 2
# WRONG!! expected:  positive result:  neutral
# my favs here are the tacos pastor and the tostada de tinga... tostada de tinga 1
# WRONG!! expected:  neutral result:  positive
# the food is all-around good, with the rolls usually excellent and the sushi/sashimi not quite on the same level. sushi/sashimi 2
# WRONG!! expected:  negative result:  positive
# (the sashimi is cut a little thinly. sashimi 2
# WRONG!! expected:  neutral result:  negative
# well, it happened because of a graceless manager and a rude bartender who had us waiting 20 minutes for drinks, and then tells us to chill out. drinks 0
# WRONG!! expected:  negative result:  neutral
# but the meals were terrible. meals 1
# WRONG!! expected:  negative result:  positive
# however, the service is absolutely horrible. service 2
# WRONG!! expected:  neutral result:  positive
# it's eaten with black vinegar and shredded ginger. black vinegar 2
# WRONG!! expected:  negative result:  positive
# when it came time to take the order the waiter gave us a hard time, walked away then came back with a paper and pen for us to write down what we wanted...excuse me but isn't that his job??? waiter 2
# WRONG!! expected:  positive result:  neutral
# dieters stick to salads or indulge in vegetarian platters. salads 1
# WRONG!! expected:  neutral result:  positive
# since i cook for a living, i'm very fussy about the food i eat in restaurants. food 2
# WRONG!! expected:  negative result:  neutral
# we were wondering why they were there to make our dining experience miserable? dining experience 1
# WRONG!! expected:  positive result:  neutral
# we were so happy with our food and were even more thrilled when we saw the bill. food 1
# WRONG!! expected:  positive result:  neutral
# we were so happy with our food and were even more thrilled when we saw the bill. bill 1
# WRONG!! expected:  negative result:  neutral
# i thought the food isn't cheap at all compared to chinatown. food 1
# WRONG!! expected:  positive result:  neutral
# first walking in the place seemed to have great ambience. place 1
# WRONG!! expected:  negative result:  positive
# the $72 delmonico steak had to be sent back because it was not cooked to order. delmonico steak 2
# WRONG!! expected:  negative result:  positive
# everytime i go there i can't pick anything to eat and not because the menu is filled with great things to eat. menu 2
# WRONG!! expected:  neutral result:  positive
# half a chicken with a mountain of rice and beans for $6.25. rice 2
# WRONG!! expected:  neutral result:  positive
# half a chicken with a mountain of rice and beans for $6.25. beans 2
# WRONG!! expected:  positive result:  negative
# go for the seafood paella for two. seafood paella for two 0
# WRONG!! expected:  positive result:  neutral
# the one positive thing i can say is that the service was prompt, we got seated right away and the server was very friendly. service 1
# WRONG!! expected:  positive result:  neutral
# service is usually pretty good. service 1
# WRONG!! expected:  negative result:  neutral
# host and hostess was quite rude. host 1
# WRONG!! expected:  negative result:  positive
# host and hostess was quite rude. hostess 2
# WRONG!! expected:  positive result:  neutral
# the wait staff is very friendly, if your not rude or picky.......our meal at leon last weekend was great -. meal 1
# WRONG!! expected:  neutral result:  positive
# the menu, which changes seasonally, shows both regional and international influences. menu 2
# WRONG!! expected:  positive result:  neutral
# their brunch menu had something for everyone. brunch menu 1
# WRONG!! expected:  neutral result:  positive
# the food is average: breakfast food, soups, salads, sandwiches, etc. food 2
# WRONG!! expected:  neutral result:  positive
# the food is average: breakfast food, soups, salads, sandwiches, etc. breakfast food 2
# WRONG!! expected:  neutral result:  positive
# the food is average: breakfast food, soups, salads, sandwiches, etc. soups 2
# WRONG!! expected:  neutral result:  positive
# the food is average: breakfast food, soups, salads, sandwiches, etc. salads 2
# WRONG!! expected:  neutral result:  positive
# the food is average: breakfast food, soups, salads, sandwiches, etc. sandwiches 2
# WRONG!! expected:  negative result:  positive
# i was highly disappointed by the food. food 2
# WRONG!! expected:  negative result:  positive
# the banana pudding they serve has never seen an oven,the crabcakes are way over salted and don't get me started on the very greasy mac and cheese. banana pudding 2
# WRONG!! expected:  negative result:  positive
# the banana pudding they serve has never seen an oven,the crabcakes are way over salted and don't get me started on the very greasy mac and cheese. crabcakes 2
# WRONG!! expected:  negative result:  positive
# the staff is arrogant, the prices are way high for brooklyn. staff 2
# WRONG!! expected:  negative result:  positive
# the staff is arrogant, the prices are way high for brooklyn. prices 2
# WRONG!! expected:  negative result:  neutral
# the food was definitely good, but when all was said and done, i just couldn't justify it for the price (including 2 drinks, $100/person)... price 1
# WRONG!! expected:  neutral result:  positive
# the food was definitely good, but when all was said and done, i just couldn't justify it for the price (including 2 drinks, $100/person)... drinks 2
# WRONG!! expected:  neutral result:  positive
# i've come here for casual lunches as well as for a friend's birthday and i always enjoy myself. casual lunches 2
# WRONG!! expected:  positive result:  neutral
# if you are a tequila fan you will not be disappointed. tequila 1
# WRONG!! expected:  negative result:  positive
# my vegetable risotto was burnt, and infused totally in a burnt flavor. vegetable risotto 2
# WRONG!! expected:  negative result:  positive
# my vegetable risotto was burnt, and infused totally in a burnt flavor. flavor 2
# WRONG!! expected:  positive result:  neutral
# but dinner here is never disappointing, even if the prices are a bit over the top. dinner 1
# WRONG!! expected:  positive result:  neutral
# best things to order are from the grill (churrasco and ribs). grill 1
# WRONG!! expected:  positive result:  negative
# best things to order are from the grill (churrasco and ribs). churrasco 0
# WRONG!! expected:  positive result:  neutral
# best things to order are from the grill (churrasco and ribs). ribs 1
# WRONG!! expected:  conflict result:  positive
# the ambiance was pretty cool, but not worth the hassle. ambiance 2
# WRONG!! expected:  neutral result:  negative
# the unfortunate lady next to us thought she had ordered a salad (including asking for salad dressing) and was instead given a quesedilla. salad 0
# WRONG!! expected:  neutral result:  negative
# the unfortunate lady next to us thought she had ordered a salad (including asking for salad dressing) and was instead given a quesedilla. salad dressing 0
# WRONG!! expected:  neutral result:  negative
# the unfortunate lady next to us thought she had ordered a salad (including asking for salad dressing) and was instead given a quesedilla. quesedilla 0
# WRONG!! expected:  negative result:  positive
# the service was pretty poor all around, the food was well below average relative to the cost, and outside there is a crazy bum who harasses every customer who leaves the place. food 2
# WRONG!! expected:  neutral result:  positive
# when she complained, the waitress said, sorry. waitress 2
# WRONG!! expected:  negative result:  positive
# the quality of the meat was on par with your local grocery store. quality of the meat 2
# WRONG!! expected:  neutral result:  negative
# the manager then told us we could order from whatever menu we wanted but by that time we were so annoyed with the waiter and the resturant that we let and went some place else. manager 0
# WRONG!! expected:  negative result:  neutral
# in mi burrito, here was nothing but dark chicken that had that cooked last week and just warmed up in a microwave taste. taste 1
# WRONG!! expected:  neutral result:  positive
# during busy hrs, i recommend that you make a reservation. reservation 2
# WRONG!! expected:  neutral result:  positive
# now called nikki sushi, sushi is ok. sushi 2
# WRONG!! expected:  neutral result:  positive
# there's candlelight and music. candlelight 2
# WRONG!! expected:  neutral result:  positive
# there's candlelight and music. music 2
# WRONG!! expected:  negative result:  neutral
# i've had better japanese food at a mall food court. japanese food 1
# WRONG!! expected:  negative result:  neutral
# the sashimi portion are big enough to appease most people, but i didn't like the fact they used artifical lobster meat. artifical lobster meat 1
# WRONG!! expected:  neutral result:  negative
# they have waiters on the sidewalk trying to pull you in which made us suspicious. waiters 0
# WRONG!! expected:  neutral result:  positive
# it was our only opportunity to visit and wanted an authentic italian meal. italian meal 2
# WRONG!! expected:  positive result:  neutral
# it took 100 years for parisi to get around to making pizza (at least i don't think they ever made it before this year)...but it was worth the wait. pizza 1
# WRONG!! expected:  negative result:  neutral
# probably my worst dining experience in new york, and i'm a former waiter so i know what i'm talking about. dining experience 1
# WRONG!! expected:  neutral result:  negative
# probably my worst dining experience in new york, and i'm a former waiter so i know what i'm talking about. waiter 0
# WRONG!! expected:  negative result:  positive
# unfortunately, unless you live in the neighborhood, it's not in a convenient location but is more like a hidden treasure. location 2
# WRONG!! expected:  negative result:  neutral
# didn't seem like any effort was made to the display and quality of the food. display and quality of the food 1
# WRONG!! expected:  positive result:  neutral
# at night the atmoshere changes turning into this hidden jewel that is waiting to be discovered. atmoshere 1
# WRONG!! expected:  neutral result:  positive
# the other times i've gone it's romantic date heaven, you can walk in get a booth by the windows, be treated like a vip in a not-crowded place, with great food and service. booth by the windows 2
# WRONG!! expected:  positive result:  negative
# the other times i've gone it's romantic date heaven, you can walk in get a booth by the windows, be treated like a vip in a not-crowded place, with great food and service. service 0
# WRONG!! expected:  negative result:  positive
# if your looking for nasty high priced food with a dash of ghetto scenery cheap bx a$$ this is the place to be!! scenery 2
# WRONG!! expected:  positive result:  neutral
# new hamburger with special sauce is ok - at least better than big mac! new hamburger with special sauce 1
# WRONG!! expected:  negative result:  neutral
# new hamburger with special sauce is ok - at least better than big mac! big mac 1
# WRONG!! expected:  neutral result:  positive
# perfectly al dente pasta, not drowned in sauce -- generous portions. sauce 2
# WRONG!! expected:  negative result:  positive
# i can understand the prices if it served better food, like some chinese restaurants in midtown/uptown area. prices 2
# WRONG!! expected:  negative result:  positive
# i can understand the prices if it served better food, like some chinese restaurants in midtown/uptown area. food 2
# WRONG!! expected:  positive result:  neutral
# have a mojito and sit in the back patio. mojito 1
# WRONG!! expected:  positive result:  negative
# you will not be dissapointed by any of the choices in the menu. menu 0
# WRONG!! expected:  positive result:  negative
# the french fries -- with the kalmata dip were terrific! french fries -- with the kalmata dip 0
# WRONG!! expected:  negative result:  neutral
# would you ever believe that when you complain about over an hour wait, when they tell you it will be 20-30 minutes, the manager tells the bartender to spill the drinks you just paid for? wait 1
# WRONG!! expected:  neutral result:  negative
# would you ever believe that when you complain about over an hour wait, when they tell you it will be 20-30 minutes, the manager tells the bartender to spill the drinks you just paid for? bartender 0
# WRONG!! expected:  neutral result:  positive
# the boutique selection of wines covers a wide variety without being imposeing. boutique selection of wines 2
# WRONG!! expected:  neutral result:  positive
# they also have a great assortment of wraps if your not in the mood for traditional mediterranean fare. traditional mediterranean fare 2
# WRONG!! expected:  negative result:  neutral
# disappointingly, their wonderful saketini has been taken off the bar menu. bar menu 1
# WRONG!! expected:  negative result:  positive
# in short the black sheep distinguishes itself from the midtown pub herd with a look that's a mix of sports-bar butch and ornate kitsch. look 2
# WRONG!! expected:  neutral result:  negative
# then she made a fuss about not being able to add 1 or 2 chairs on either end of the table for additional people. chairs 0
# WRONG!! expected:  neutral result:  negative
# then she made a fuss about not being able to add 1 or 2 chairs on either end of the table for additional people. table 0
# WRONG!! expected:  positive result:  negative
# the happy hour is so cheap, but that does not reflect the service or the atmosphere. service 0
# WRONG!! expected:  positive result:  negative
# the happy hour is so cheap, but that does not reflect the service or the atmosphere. atmosphere 0
# WRONG!! expected:  neutral result:  positive
# after waiting for almost an hour, the waiter brusquely told us he'd forgotten to give the kitchen our order. kitchen 2
# WRONG!! expected:  positive result:  negative
# with all the mundane or mediocre places on 8th avenue it is nice to have one that is a step above in quaility and atmosphere. quaility 0
# WRONG!! expected:  positive result:  negative
# with all the mundane or mediocre places on 8th avenue it is nice to have one that is a step above in quaility and atmosphere. atmosphere 0
# WRONG!! expected:  negative result:  positive
# a mix of students and area residents crowd into this narrow, barely there space for its quick, tasty treats at dirt-cheap prices. space 2
# WRONG!! expected:  neutral result:  positive
# give it a try, menu is typical french but varied. menu 2
# WRONG!! expected:  positive result:  negative
# the negative reviews on city search are probably from jealous competing restaurants who realize they can't compete with temple's entire positive attitude about the proper way to treat their customers and deliver top quality food. food 0
# WRONG!! expected:  positive result:  negative
# the negative reviews on city search are probably from jealous competing restaurants who realize they can't compete with temple's entire positive attitude about the proper way to treat their customers and deliver top quality food. attitude 0
# WRONG!! expected:  neutral result:  positive
# it was good, but none of the flavors wow. flavors 2
# WRONG!! expected:  positive result:  neutral
# for about eleven bucks you get a gigantic burrito (or tacos), margarita, and dessert. burrito 1
# WRONG!! expected:  neutral result:  positive
# for about eleven bucks you get a gigantic burrito (or tacos), margarita, and dessert. margarita 2
# WRONG!! expected:  neutral result:  positive
# for about eleven bucks you get a gigantic burrito (or tacos), margarita, and dessert. dessert 2
# WRONG!! expected:  neutral result:  positive
# the space is traditional in feel. space 2
# WRONG!! expected:  neutral result:  negative
# the restaurant was completely empty, but she gave me a dirty look and asked, no reservations? reservations 0
# WRONG!! expected:  negative result:  neutral
# the food was mediocre to be kind - the interior is small and average - the owners are a tag-team of unpleasantries - so rude and snotty i actually let out a hearty guffaw whilst dining. food 1
# WRONG!! expected:  neutral result:  positive
# the food was mediocre to be kind - the interior is small and average - the owners are a tag-team of unpleasantries - so rude and snotty i actually let out a hearty guffaw whilst dining. dining 2
# WRONG!! expected:  neutral result:  positive
# offerings like hot cakes and the egg mcmuffin sandwich are available for breakfast. egg mcmuffin sandwich 2
# WRONG!! expected:  neutral result:  positive
# offerings like hot cakes and the egg mcmuffin sandwich are available for breakfast. hot cakes 2
# WRONG!! expected:  neutral result:  positive
# offerings like hot cakes and the egg mcmuffin sandwich are available for breakfast. breakfast 2
# WRONG!! expected:  neutral result:  positive
# i have been going to this restaurant for years, in the past the service was average and the food inconsistant. service 2
# WRONG!! expected:  negative result:  neutral
# i have been going to this restaurant for years, in the past the service was average and the food inconsistant. food 1
# WRONG!! expected:  negative result:  neutral
# cuisine is billed as asian fusion - doesn't meet the bill. cuisine 1
# WRONG!! expected:  negative result:  positive
# cuisine is billed as asian fusion - doesn't meet the bill. bill 2
# WRONG!! expected:  neutral result:  positive
# cuisine is billed as asian fusion - doesn't meet the bill. asian fusion 2
# WRONG!! expected:  negative result:  positive
# cuisine is billed as asian fusion - doesn't meet the bill. billed 2
# WRONG!! expected:  neutral result:  positive
# creative dishes like king crab salad with passion fruit vinaigrette and fettuccine with grilled seafood in a rosemary-orange sauce are unexpected elements on an otherwise predictable bistro menu. bistro menu 2
# WRONG!! expected:  negative result:  neutral
# i came to fresh expecting a great meal, and all i got was marginally so-so food served in a restaurant that was just so freezing we couldn't enjoy eating. food 1
# WRONG!! expected:  negative result:  positive
# i came to fresh expecting a great meal, and all i got was marginally so-so food served in a restaurant that was just so freezing we couldn't enjoy eating. meal 2
# WRONG!! expected:  negative result:  neutral
# the lone argentine chorizo appetizer at $8.95 was a heavy fennel flavored italian sausage like the ones that sell for $2.99/lb at the store. argentine chorizo appetizer 1
# WRONG!! expected:  negative result:  neutral
# the lone argentine chorizo appetizer at $8.95 was a heavy fennel flavored italian sausage like the ones that sell for $2.99/lb at the store. fennel flavored italian sausage 1
# WRONG!! expected:  neutral result:  negative
# i went in one day asking for a table for a group and was greeted by a very rude hostess. table 0
# WRONG!! expected:  positive result:  neutral
# not only is the food authentic, but the staff here are practically off-the-boat, they are young and hip and know what they are doing when it comes to food and wine. wine 1
# WRONG!! expected:  positive result:  negative
# you can eat gourmet food at a fast food price. price 0
# WRONG!! expected:  positive result:  neutral
# we had a birthday party here recently and the food and service was amazing. food 1
# WRONG!! expected:  neutral result:  positive
# the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives. non-meat alternatives 2
# WRONG!! expected:  negative result:  positive
# this place has the strangest menu and the restaurants tries too hard to make fancy food. menu 2
# WRONG!! expected:  negative result:  positive
# this place has the strangest menu and the restaurants tries too hard to make fancy food. food 2
# WRONG!! expected:  neutral result:  positive
# the appetizers are ok, but the service is slow. appetizers 2
# WRONG!! expected:  negative result:  positive
# the appetizers are ok, but the service is slow. service 2
# WRONG!! expected:  negative result:  neutral
# the food - not worth the price. food 1
# WRONG!! expected:  neutral result:  negative
# what can you say about a place where the waitress brings out the wrong entree, then verbally assaults your 80 year old grandmother and gives her lip about sending it back (which she did politely, by the way). entree 0
# WRONG!! expected:  positive result:  neutral
# the prices are not terrible. prices 1
# WRONG!! expected:  negative result:  positive
# 15% gratuity automatically added to the bill. bill 2
# WRONG!! expected:  negative result:  positive
# 15% gratuity automatically added to the bill. gratuity 2
# WRONG!! expected:  neutral result:  positive
# the halibut cheek appetizer came with a generous portion of foie gras, but that's about the only positive thing i can say about the meal. halibut cheek appetizer 2
# WRONG!! expected:  conflict result:  neutral
# the halibut cheek appetizer came with a generous portion of foie gras, but that's about the only positive thing i can say about the meal. meal 1
# WRONG!! expected:  neutral result:  positive
# all-time favorites include the big mac, chicken mcnuggets, filet-o-fish sandwich and mcdonald's famous french fries; lighter options like entree-sized salads are also available. entree-sized salads 2
# WRONG!! expected:  conflict result:  positive
# although somewhat loud, the noise was minimally intrusive. noise 2
# WRONG!! expected:  positive result:  negative
# it's a basic pizza joint, not much to look at, but the pizza is what i go for. pizza 0
# WRONG!! expected:  positive result:  neutral
# dug the blue bar area too. blue bar area 1
# WRONG!! expected:  positive result:  negative
# the service was on point - what else you would expect from a ritz? service 0
# WRONG!! expected:  neutral result:  positive
# menus feature seasonal picks, like sweet corn-foie gras brulee. menus 2
# WRONG!! expected:  neutral result:  positive
# menus feature seasonal picks, like sweet corn-foie gras brulee. sweet corn-foie gras brulee 2
# WRONG!! expected:  positive result:  negative
# and these are not small, wimpy fast food type burgers - these are real, full sized patties. burgers 0
# WRONG!! expected:  neutral result:  negative
# there restaurant is very casual, but perfect for lunch, and their delivery service is always very fast. lunch 0
# WRONG!! expected:  neutral result:  negative
# i had to flag down a third staff person for a fork... so now it's goodbye little rude pie company. fork 0
# WRONG!! expected:  negative result:  positive
# go with the specials, and stay away from the salmon. salmon 2
# WRONG!! expected:  negative result:  neutral
# atmosphere is a bore. atmosphere 1
# WRONG!! expected:  positive result:  neutral
# the decor is what initially got me in the door. decor 1
# WRONG!! expected:  neutral result:  negative
# my date and i both ordered the branzini and both felt the fish was very average. branzini 0
# WRONG!! expected:  negative result:  positive
# my date and i both ordered the branzini and both felt the fish was very average. fish 2
# WRONG!! expected:  conflict result:  positive
# the atmosphere was nice but it was a little too dark. atmosphere 2
# WRONG!! expected:  conflict result:  positive
# the service is a quite slow, but friendly. service 2
# WRONG!! expected:  positive result:  negative
# i have never had a bad meal(or bad service )@ pigalle. meal 0
# WRONG!! expected:  positive result:  negative
# i have never had a bad meal(or bad service )@ pigalle. service 0
# WRONG!! expected:  negative result:  positive
# the food really isn't very good and the service is terrible. food 2
# WRONG!! expected:  negative result:  positive
# the food really isn't very good and the service is terrible. service 2
# WRONG!! expected:  positive result:  negative
# between my guest and i, we sampled at least 80% of the menu, and they were all hits. menu 0
# WRONG!! expected:  positive result:  neutral
# for someone who used to hate indian food, baluchi's has changed my mid. indian food 1
# WRONG!! expected:  positive result:  neutral
# finally a curry that i can eat, enjoy and not suffer from gastritis from 3 hours later. curry 1
# WRONG!! expected:  positive result:  neutral
# they bring a sauce cart up to your table and offer you up to 7 or 8 choices of sauces for your steak (i tried them all). choices of sauces 1
# WRONG!! expected:  neutral result:  positive
# not only was the sushi fresh, they also served other entrees allowed each guest something to choose from and we all left happy (try the duck! entrees 2
# WRONG!! expected:  negative result:  positive
# likewise if you like really thin crust or really big slices then nick and joe's may not be your favorite. thin crust 2
# WRONG!! expected:  negative result:  positive
# likewise if you like really thin crust or really big slices then nick and joe's may not be your favorite. slices 2
# WRONG!! expected:  neutral result:  negative
# no green beans, no egg, no anchovy dressing, no nicoise olives, no red onion. anchovy dressing 0
# WRONG!! expected:  neutral result:  positive
# build a meal with side orders like amazin' greens salads, buffalo chicken kickers and cinna stix. amazin' greens salads 2
# WRONG!! expected:  neutral result:  positive
# build a meal with side orders like amazin' greens salads, buffalo chicken kickers and cinna stix. buffalo chicken kickers 2
# WRONG!! expected:  neutral result:  positive
# build a meal with side orders like amazin' greens salads, buffalo chicken kickers and cinna stix. cinna stix 2
# WRONG!! expected:  neutral result:  positive
# thick fries, meaty chili and stuffed baked potatoes round out a menu that includes a cool, ultra-thick chocolate frosty. fries 2
# WRONG!! expected:  neutral result:  positive
# thick fries, meaty chili and stuffed baked potatoes round out a menu that includes a cool, ultra-thick chocolate frosty. meaty chili 2
# WRONG!! expected:  neutral result:  positive
# thick fries, meaty chili and stuffed baked potatoes round out a menu that includes a cool, ultra-thick chocolate frosty. stuffed baked potatoes 2
# WRONG!! expected:  neutral result:  negative
# i always find myself asking the waiter to make something bland and different than what is on the menu. waiter 0
# WRONG!! expected:  neutral result:  negative
# i always find myself asking the waiter to make something bland and different than what is on the menu. menu 0
# WRONG!! expected:  negative result:  positive
# good cake but: it was not the best cake i've ever had, and definately not worth standing outside on the sidewalk being herded like cattle by indifferent and overworked employees. cake 2
# WRONG!! expected:  conflict result:  positive
# good cake but: it was not the best cake i've ever had, and definately not worth standing outside on the sidewalk being herded like cattle by indifferent and overworked employees. cake 2
# WRONG!! expected:  negative result:  positive
# it doesn't look like much on the outside, but the minute you walk inside, it's a whole other atmosphere. outside 2
# WRONG!! expected:  negative result:  positive
# the service, however, is a peg or two below the quality of food (horrible bartenders), and the clientele, for the most part, are rowdy, loud-mouthed commuters (this could explain the bad attitudes from the staff) getting loaded for an ac/dc concert or a knicks game. service 2
# WRONG!! expected:  negative result:  positive
# the service, however, is a peg or two below the quality of food (horrible bartenders), and the clientele, for the most part, are rowdy, loud-mouthed commuters (this could explain the bad attitudes from the staff) getting loaded for an ac/dc concert or a knicks game. bartenders 2
# WRONG!! expected:  negative result:  positive
# the service, however, is a peg or two below the quality of food (horrible bartenders), and the clientele, for the most part, are rowdy, loud-mouthed commuters (this could explain the bad attitudes from the staff) getting loaded for an ac/dc concert or a knicks game. clientele 2
# WRONG!! expected:  negative result:  positive
# make more tables- perhaps a rooftop bar? tables 2
# WRONG!! expected:  neutral result:  negative
# make more tables- perhaps a rooftop bar? rooftop bar 0
# WRONG!! expected:  positive result:  negative
# the decoration was feeling like we was on the cairo, actually the street is part of that adventure. decoration 0
# WRONG!! expected:  neutral result:  positive
# stick to the items the place does best, brisket, ribs, wings, cajun shrimp is good, not great. cajun shrimp 2
# WRONG!! expected:  neutral result:  positive
# my chelsea's impressive and creative menu includes modern, westernized japanese dishes such as foie gras unagi napolean, jap style hamburger steak, spicy cod roe spaghetti, black cod with miso base, and rack of lamb in black truffle sauce, to name a few. foie gras unagi napolean 2
# WRONG!! expected:  neutral result:  positive
# my chelsea's impressive and creative menu includes modern, westernized japanese dishes such as foie gras unagi napolean, jap style hamburger steak, spicy cod roe spaghetti, black cod with miso base, and rack of lamb in black truffle sauce, to name a few. jap style hamburger steak 2
# WRONG!! expected:  neutral result:  positive
# my chelsea's impressive and creative menu includes modern, westernized japanese dishes such as foie gras unagi napolean, jap style hamburger steak, spicy cod roe spaghetti, black cod with miso base, and rack of lamb in black truffle sauce, to name a few. spicy cod roe spaghetti 2
# WRONG!! expected:  neutral result:  positive
# my chelsea's impressive and creative menu includes modern, westernized japanese dishes such as foie gras unagi napolean, jap style hamburger steak, spicy cod roe spaghetti, black cod with miso base, and rack of lamb in black truffle sauce, to name a few. black cod with miso base 2
# WRONG!! expected:  neutral result:  positive
# my chelsea's impressive and creative menu includes modern, westernized japanese dishes such as foie gras unagi napolean, jap style hamburger steak, spicy cod roe spaghetti, black cod with miso base, and rack of lamb in black truffle sauce, to name a few. rack of lamb in black truffle sauce 2
# WRONG!! expected:  positive result:  negative
# don't get me wrong - sushi was good, just not fantastic. sushi 0
# WRONG!! expected:  positive result:  neutral
# but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection). cocktail hour 1
# WRONG!! expected:  positive result:  neutral
# but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection). non-sushi selection 1
# WRONG!! expected:  positive result:  neutral
# but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection). appetizers 1
# WRONG!! expected:  negative result:  neutral
# it took about 2 1/2 hours to be served our 2 courses. served 1
# WRONG!! expected:  neutral result:  positive
# who said go when the place is quiet during the day? place 2
# WRONG!! expected:  positive result:  neutral
# good place to hang out during the day after shopping or to grab a simple soup or classic french dish over a glass of wine. place 1
# WRONG!! expected:  positive result:  negative
# however, there is just something so great about being outdoors, in great landscaping, enjoying a casual drink that makes going to this place worthwhile. place 0
# WRONG!! expected:  neutral result:  positive
# we were seated promptly in close proximity to the dance floor. dance floor 2
# WRONG!! expected:  neutral result:  positive
# if you are here as a pre-show meal, hop in a cab and take the extra 10 minutes to go to the uptown location. pre-show meal 2
# WRONG!! expected:  negative result:  neutral
# the comments about fried foods is correct (below) but the other dishes, including the lamb entree and many of the salads (avocado shrimp) were quite good. fried foods 1
# WRONG!! expected:  negative result:  positive
# slow service, but when you're hanging around with groups of 10 or 20, who really notices? service 2
# WRONG!! expected:  neutral result:  positive
# the sauce is excellent (very fresh) with dabs of real mozzarella. dabs of real mozzarella 2
# WRONG!! expected:  negative result:  positive
# the room is a little plain, but it's difficult to make such a small place exciting and i would not suggest that as a reason not to go. room 2
# WRONG!! expected:  negative result:  positive
# the room is a little plain, but it's difficult to make such a small place exciting and i would not suggest that as a reason not to go. place 2
# WRONG!! expected:  positive result:  negative
# prices even outside of restaurant week were great. prices 0
# WRONG!! expected:  positive result:  negative
# a small, outdoor eating area makes for a private, comfortable space to study alone or meet up with friends. space 0
# WRONG!! expected:  neutral result:  positive
# the best dessert, a chocolate and peanut butter tart, isn't particularly hawaiian, but it's a small world when it comes to sweets. sweets 2
# WRONG!! expected:  neutral result:  positive
# for an appetizer, their calamari is a winner. appetizer 2
# WRONG!! expected:  neutral result:  positive
# the room is a gorgeous, bi-level space and the long bar perfect for a drink. drink 2
# WRONG!! expected:  negative result:  neutral
# two complaints- their appetizer selection stinks, it would be nice to get some mozzarella sticks on the menu. appetizer selection 1
# WRONG!! expected:  negative result:  neutral
# two complaints- their appetizer selection stinks, it would be nice to get some mozzarella sticks on the menu. menu 1
# WRONG!! expected:  conflict result:  positive
# the service is great (maybe even borderline nagging but at least you get attention), the desserts are excellent and the coffee is so very good... service 2
# WRONG!! expected:  negative result:  positive
# while the smoothies are a little big for me, the fresh juices are the best i have ever had! smoothies 2
# WRONG!! expected:  conflict result:  neutral
# the food is just okay, and it's almost not worth going unless you're getting the pialla, which is the only dish that's really good. food 1
# WRONG!! expected:  conflict result:  positive
# the guac is fresh, yet lacking flavor, we like to add our fresh salsa into it. guac 2
# WRONG!! expected:  neutral result:  positive
# the guac is fresh, yet lacking flavor, we like to add our fresh salsa into it. fresh salsa 2
# WRONG!! expected:  negative result:  positive
# the guac is fresh, yet lacking flavor, we like to add our fresh salsa into it. flavor 2
# WRONG!! expected:  negative result:  positive
# the new menu has a few creative items,they were smart enough to keep some of the old favorites (but they raised the prices), the staff is friendly most of the time, but i must agree with the person that wrote about their favorite words: no, can't, sorry..., boy, they won't bend the rules for anyone. prices 2
# WRONG!! expected:  conflict result:  positive
# the new menu has a few creative items,they were smart enough to keep some of the old favorites (but they raised the prices), the staff is friendly most of the time, but i must agree with the person that wrote about their favorite words: no, can't, sorry..., boy, they won't bend the rules for anyone. staff 2
# WRONG!! expected:  positive result:  neutral
# if you like seafood and/or greek food you will love this place though it is not limited to just these things. seafood 1
# WRONG!! expected:  positive result:  neutral
# if you like seafood and/or greek food you will love this place though it is not limited to just these things. greek food 1
# WRONG!! expected:  neutral result:  positive
# " the menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians. burgers 2
# WRONG!! expected:  neutral result:  positive
# " the menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians. steaks 2
# WRONG!! expected:  neutral result:  positive
# " the menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians. shepherds pie 2
# WRONG!! expected:  neutral result:  positive
# " the menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians. portabella lasagna 2
# WRONG!! expected:  neutral result:  positive
# " the menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians. pub fare 2
# WRONG!! expected:  negative result:  neutral
# i have eaten here on a different occasion - the food is mediocre for the prices. prices 1
# WRONG!! expected:  neutral result:  negative
# i asked repeatedly what the status of the meal was and was pretty much grunted at by the unbelievably rude waiter. meal 0
# WRONG!! expected:  neutral result:  positive
# i stopped by for some brunch today and had the vegan cranberry pancakes and some rice milk. rice milk 2
# WRONG!! expected:  negative result:  positive
# its good to go there for drinks if you don't want to get drunk because you'll be lucky if you can get one drink an hour the service is so bad. service 2
# WRONG!! expected:  neutral result:  positive
# its good to go there for drinks if you don't want to get drunk because you'll be lucky if you can get one drink an hour the service is so bad. drink 2
# WRONG!! expected:  neutral result:  positive
# its good to go there for drinks if you don't want to get drunk because you'll be lucky if you can get one drink an hour the service is so bad. drinks 2
# WRONG!! expected:  negative result:  positive
# anyway, the owner was fake. owner 2
# WRONG!! expected:  negative result:  neutral
# i have never in my life sent back food before, but i simply had to, and the waiter argued with me over this. food 1
# WRONG!! expected:  negative result:  positive
# i have never in my life sent back food before, but i simply had to, and the waiter argued with me over this. waiter 2
# WRONG!! expected:  neutral result:  positive
# creamy appetizers--taramasalata, eggplant salad, and greek yogurt (with cuccumber, dill, and garlic) taste excellent when on warm pitas. warm pitas 2
# 284  out of  1134

# %%
import pandas as pd

# Create a DataFrame
df = pd.DataFrame(wrong_items)

# Adjusting display options to show all rows and columns
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_colwidth', None)


# Displaying the DataFrame
print(df)
# Out:
#                                                   text          aspect  \
# 0    i have to say they have one of the fastest del...  delivery times
# 1    certainly not the best sushi in new york, howe...           sushi
# 2                     try the rose roll (not on menu).            menu
# 3    in fact, this was not a nicoise salad and was ...   nicoise salad
# 4                        the sangria's - watered down.         sangria
# ..                                                 ...             ...
# 279  its good to go there for drinks if you don't w...          drinks
# 280                        anyway, the owner was fake.           owner
# 281  i have never in my life sent back food before,...            food
# 282  i have never in my life sent back food before,...          waiter
# 283  creamy appetizers--taramasalata, eggplant sala...      warm pitas
#
#      expected    result
# 0    positive  negative
# 1    conflict  negative
# 2     neutral  positive
# 3    negative   neutral
# 4    negative   neutral
# ..        ...       ...
# 279   neutral  positive
# 280  negative  positive
# 281  negative   neutral
# 282  negative  positive
# 283   neutral  positive
#
# [284 rows x 4 columns]

# %%
df
# Out:
#                                                   text          aspect  \
# 0    i have to say they have one of the fastest del...  delivery times
# 1    certainly not the best sushi in new york, howe...           sushi
# 2                     try the rose roll (not on menu).            menu
# 3    in fact, this was not a nicoise salad and was ...   nicoise salad
# 4                        the sangria's - watered down.         sangria
# ..                                                 ...             ...
# 279  its good to go there for drinks if you don't w...          drinks
# 280                        anyway, the owner was fake.           owner
# 281  i have never in my life sent back food before,...            food
# 282  i have never in my life sent back food before,...          waiter
# 283  creamy appetizers--taramasalata, eggplant sala...      warm pitas
#
#      expected    result
# 0    positive  negative
# 1    conflict  negative
# 2     neutral  positive
# 3    negative   neutral
# 4    negative   neutral
# ..        ...       ...
# 279   neutral  positive
# 280  negative  positive
# 281  negative   neutral
# 282  negative  positive
# 283   neutral  positive
#
# [284 rows x 4 columns]

# %%
import spacy
import networkx as nx
import numpy as np
from spacy.matcher import Matcher

nlp = spacy.load("en_core_web_sm")

def dependency_dist_func(text, aspect_term):
    document = nlp(text)
    edges = []
    potential_candidate_term = []
    patterns = [
        [{'DEP': "amod"}],
        [{'DEP': "advmod"}],
        [{'DEP': "attr"}],
        [{'DEP': "ccomp"}],
        [{'DEP': "acomp"}],
    ]

    matcher = Matcher(nlp.vocab)
    matcher.add("potentialOpinion", patterns)
    matches = matcher(document)
    for match_id, start, end, in matches:
        string_id = nlp.vocab.strings[match_id]
        span = document[start:end]
        potential_candidate_term.append(span)
        # print(string_id, span.text)

    for token in document:
        for child in token.children:
            edges.append((token.i, child.i))
    graph = nx.Graph(edges)

    text_lst = text.split()
    seq_len = len(text_lst)
    text_left, _, _ = text.partition(aspect_term)
    start = len(text_left.split())
    end = start + len(aspect_term.split())
    asp_idx = [i for i in range(start, end)]
    dist_matrix = seq_len*np.ones((seq_len, len(asp_idx))).astype('float32')
    for i, asp in enumerate(asp_idx):
        for j in range(seq_len):
            try:
                dist_matrix[j][i] = nx.shortest_path_length(graph, source=asp, target=j)
            except:
                dist_matrix[j][i] = seq_len/2
    dist_matrix = np.min(dist_matrix, axis=1)
    return dist_matrix, potential_candidate_term

def find_closest_words(sentence, aspect):
    print("context: ", sentence)
    print("aspect: ", aspect)
    result, potential_opinion_term_from_dependency_dist = dependency_dist_func(sentence, aspect)
    print("Distances:", result)

    try:

        closest_word_index = np.argsort(result)[1]  # Excluding the aspect term itself
        closest_word = sentence.split()[closest_word_index]
        closest_second_word = sentence.split()[closest_word_index+1]
        closest_third_word = sentence.split()[closest_word_index+2]
        closest_fourth_word = sentence.split()[closest_word_index+3]
        print("The closest word to '",aspect,"' is:", closest_word)
        print("The closest second word to '",aspect,"' is:", closest_second_word)
        print("The closest third word to '",aspect,"' is:", closest_third_word)
        print("The closest fourth word to '",aspect,"' is:", closest_fourth_word)
        

    except:
        pass
    
    print("While the potential opinion words are: ", potential_opinion_term_from_dependency_dist)
    print()

# %%
for item in wrong_items:
    print("expected: ", item['expected'])
    print("result: ", item['result'])
    find_closest_words(item['text'], item['aspect'])
# Out:
# expected:  positive
# result:  negative
# context:  i have to say they have one of the fastest delivery times in the city.
# aspect:  delivery times
# Distances: [6. 5. 5. 4. 4. 3. 2. 1. 1. 1. 0. 0. 1. 3. 2.]
# The closest word to ' delivery times ' is: times
# The closest second word to ' delivery times ' is: in
# The closest third word to ' delivery times ' is: the
# The closest fourth word to ' delivery times ' is: city.
# While the potential opinion words are:  [have, fastest]
#
# expected:  conflict
# result:  negative
# context:  certainly not the best sushi in new york, however, it is always fresh, and the place is very clean, sterile.
# aspect:  sushi
# Distances: [1. 1. 1. 1. 0. 1. 3. 2. 2. 2. 2. 2. 1. 2. 2. 2. 2. 4. 3. 2.]
# The closest word to ' sushi ' is: certainly
# The closest second word to ' sushi ' is: not
# The closest third word to ' sushi ' is: the
# The closest fourth word to ' sushi ' is: best
# While the potential opinion words are:  [certainly, best, however, always, fresh, very, clean]
#
# expected:  neutral
# result:  positive
# context:  try the rose roll (not on menu).
# aspect:  menu
# Distances: [2. 2. 2. 1. 2. 2. 0.]
# The closest word to ' menu ' is: roll
# The closest second word to ' menu ' is: (not
# The closest third word to ' menu ' is: on
# The closest fourth word to ' menu ' is: menu).
# While the potential opinion words are:  []
#
# expected:  negative
# result:  neutral
# context:  in fact, this was not a nicoise salad and was barely eatable.
# aspect:  nicoise salad
# Distances: [3. 4. 3. 3. 2. 3. 0. 0. 1. 3. 3. 5.]
# The closest word to ' nicoise salad ' is: salad
# The closest second word to ' nicoise salad ' is: and
# The closest third word to ' nicoise salad ' is: was
# The closest fourth word to ' nicoise salad ' is: barely
# While the potential opinion words are:  [salad, barely, eatable]
#
# expected:  negative
# result:  neutral
# context:  the sangria's - watered down.
# aspect:  sangria
# Distances: [1. 0. 1. 2. 1.]
# The closest word to ' sangria ' is: the
# The closest second word to ' sangria ' is: sangria's
# The closest third word to ' sangria ' is: -
# The closest fourth word to ' sangria ' is: watered
# While the potential opinion words are:  [watered]
#
# expected:  negative
# result:  positive
# context:  menu - uneventful, small.
# aspect:  menu
# Distances: [0. 2. 1. 3.]
# While the potential opinion words are:  [uneventful]
#
# expected:  negative
# result:  positive
# context:  great food but the service was dreadful!
# aspect:  service
# Distances: [3.5 3.5 3.5 1.  0.  1.  2. ]
# The closest word to ' service ' is: the
# The closest second word to ' service ' is: service
# The closest third word to ' service ' is: was
# The closest fourth word to ' service ' is: dreadful!
# While the potential opinion words are:  [great, dreadful]
#
# expected:  positive
# result:  neutral
# context:  desserts are almost incredible: my personal favorite is their tart of the day.
# aspect:  desserts
# Distances: [0. 1. 3. 2. 3. 4. 4. 3. 2. 4. 3. 4. 6.]
# The closest word to ' desserts ' is: are
# The closest second word to ' desserts ' is: almost
# The closest third word to ' desserts ' is: incredible:
# The closest fourth word to ' desserts ' is: my
# While the potential opinion words are:  [are, almost, incredible, personal, tart]
#
# expected:  positive
# result:  neutral
# context:  if you want good tasting, well seasoned latin food eat at cabana and you can't go wrong.
# aspect:  latin food
# Distances: [3.  3.  2.  4.  3.  2.  1.  0.  0.  1.  1.  2.  3.  8.5 8.5 8.5 8.5]
# The closest word to ' latin food ' is: latin
# The closest second word to ' latin food ' is: food
# The closest third word to ' latin food ' is: eat
# The closest fourth word to ' latin food ' is: at
# While the potential opinion words are:  [good, well, seasoned, latin, wrong]
#
# expected:  neutral
# result:  positive
# context:  entrees include classics like lasagna, fettuccine alfredo and chicken parmigiana.
# aspect:  entrees
# Distances: [0. 1. 2. 3. 4. 5. 6. 5. 6. 7.]
# The closest word to ' entrees ' is: include
# The closest second word to ' entrees ' is: classics
# The closest third word to ' entrees ' is: like
# The closest fourth word to ' entrees ' is: lasagna,
# While the potential opinion words are:  []
#
# expected:  neutral
# result:  positive
# context:  entrees include classics like lasagna, fettuccine alfredo and chicken parmigiana.
# aspect:  lasagna
# Distances: [4. 3. 2. 1. 0. 1. 2. 1. 2. 3.]
# The closest word to ' lasagna ' is: like
# The closest second word to ' lasagna ' is: lasagna,
# The closest third word to ' lasagna ' is: fettuccine
# The closest fourth word to ' lasagna ' is: alfredo
# While the potential opinion words are:  []
#
# expected:  neutral
# result:  positive
# context:  entrees include classics like lasagna, fettuccine alfredo and chicken parmigiana.
# aspect:  fettuccine alfredo
# Distances: [5. 4. 3. 2. 1. 0. 0. 1. 2. 3.]
# The closest word to ' fettuccine alfredo ' is: alfredo
# The closest second word to ' fettuccine alfredo ' is: and
# The closest third word to ' fettuccine alfredo ' is: chicken
# The closest fourth word to ' fettuccine alfredo ' is: parmigiana.
# While the potential opinion words are:  []
#
# expected:  neutral
# result:  positive
# context:  entrees include classics like lasagna, fettuccine alfredo and chicken parmigiana.
# aspect:  chicken parmigiana
# Distances: [6. 5. 4. 3. 2. 3. 2. 1. 0. 0.]
# While the potential opinion words are:  []
#
# expected:  negative
# result:  positive
# context:  this made it obvious that the food wasn't cooked fresh; it was obviously made before hand and then reheated.
# aspect:  food
# Distances: [4. 3. 3. 2. 2. 1. 0. 2. 2. 1. 2. 5. 5. 5. 5. 4. 5. 6. 5.]
# The closest word to ' food ' is: fresh;
# The closest second word to ' food ' is: it
# The closest third word to ' food ' is: was
# The closest fourth word to ' food ' is: obviously
# While the potential opinion words are:  [made, obvious, obviously, then]
#
# expected:  negative
# result:  positive
# context:  i was highly disappointed by their service and food.
# aspect:  service
# Distances: [4. 3. 3. 2. 1. 1. 0. 1. 1.]
# The closest word to ' service ' is: by
# The closest second word to ' service ' is: their
# The closest third word to ' service ' is: service
# The closest fourth word to ' service ' is: and
# While the potential opinion words are:  [highly, disappointed]
#
# expected:  negative
# result:  positive
# context:  i was highly disappointed by their service and food.
# aspect:  food
# Distances: [5. 4. 4. 3. 2. 2. 1. 2. 0.]
# While the potential opinion words are:  [highly, disappointed]
#
# expected:  negative
# result:  neutral
# context:  i complained to the waiter and then to the manager, but the intensity of rudeness from them just went up.
# aspect:  manager
# Distances: [3. 2. 3. 5. 4. 2. 2. 1. 1. 0. 3. 3. 5. 4. 5. 6. 7. 8. 4. 3.]
# The closest word to ' manager ' is: the
# The closest second word to ' manager ' is: manager,
# The closest third word to ' manager ' is: but
# The closest fourth word to ' manager ' is: the
# While the potential opinion words are:  [then, just]
#
# expected:  negative
# result:  positive
# context:  one caveat: some of the curried casseroles can be a trifle harsh.
# aspect:  curried casseroles
# Distances: [6. 6. 6. 3. 2. 0. 0. 1. 5. 4. 7. 6.]
# The closest word to ' curried casseroles ' is: casseroles
# The closest second word to ' curried casseroles ' is: can
# The closest third word to ' curried casseroles ' is: be
# The closest fourth word to ' curried casseroles ' is: a
# While the potential opinion words are:  [curried, harsh]
#
# expected:  conflict
# result:  positive
# context:  a nice space, as long as it doesn't get too crowded and a singleminded devotion to its chosen cuisine make mare a great choice for seafood lovers.
# aspect:  space
# Distances: [1. 1. 0. 2. 3. 2. 4. 4. 4. 4. 3. 5. 4. 4. 3. 3. 2. 3. 5. 5. 4. 1. 3. 3.
#  3. 2. 3.]
# The closest word to ' space ' is: a
# The closest second word to ' space ' is: nice
# The closest third word to ' space ' is: space,
# The closest fourth word to ' space ' is: as
# While the potential opinion words are:  [nice, as, long, too, crowded, singleminded, chosen, great, choice]
#
# expected:  positive
# result:  negative
# context:  the steak melted in my mouth.
# aspect:  steak
# Distances: [1. 0. 1. 2. 4. 3.]
# The closest word to ' steak ' is: the
# The closest second word to ' steak ' is: steak
# The closest third word to ' steak ' is: melted
# The closest fourth word to ' steak ' is: in
# While the potential opinion words are:  []
#
# expected:  neutral
# result:  positive
# context:  the food did take a few extra minutes to come, but the cute waiters' jokes and friendliness made up for it.
# aspect:  food
# Distances: [1. 0. 2. 1. 4. 3. 3. 2. 4. 3. 2. 2. 5. 5. 4. 5. 3. 4. 4. 2. 3.]
# The closest word to ' food ' is: the
# The closest second word to ' food ' is: food
# The closest third word to ' food ' is: did
# The closest fourth word to ' food ' is: take
# While the potential opinion words are:  [extra, cute]
#
# expected:  negative
# result:  neutral
# context:  i dont know what some people who rave about this hot dog are talking about.
# aspect:  hot dog
# Distances: [7. 7. 7. 6. 7. 5. 4. 4. 3. 2. 0. 0. 1. 6. 5.]
# The closest word to ' hot dog ' is: dog
# The closest second word to ' hot dog ' is: are
# The closest third word to ' hot dog ' is: talking
# The closest fourth word to ' hot dog ' is: about.
# While the potential opinion words are:  [hot, talking]
#
# expected:  negative
# result:  positive
# context:  the waiters always look angry and even ignore their high-tipping regulars.
# aspect:  waiters
# Distances: [1. 0. 2. 1. 2. 2. 3. 2. 4. 5. 5.]
# The closest word to ' waiters ' is: the
# The closest second word to ' waiters ' is: waiters
# The closest third word to ' waiters ' is: always
# The closest fourth word to ' waiters ' is: look
# While the potential opinion words are:  [always, angry, even, high, tipping]
#
# expected:  positive
# result:  negative
# context:  anywhere else, the prices would be 3x as high!
# aspect:  prices
# Distances: [4. 3. 3. 0. 1. 3. 2. 3. 4.]
# The closest word to ' prices ' is: would
# The closest second word to ' prices ' is: be
# The closest third word to ' prices ' is: 3x
# The closest fourth word to ' prices ' is: as
# While the potential opinion words are:  [anywhere, else, 3x, as, high]
#
# expected:  negative
# result:  positive
# context:  our waiter was friendly and it is a shame that he didnt have a supportive staff to work with.
# aspect:  staff
# Distances: [6. 5. 4. 5. 5. 4. 3. 5. 4. 3. 3. 3. 3. 2. 2. 0. 1. 3. 2.]
# While the potential opinion words are:  [friendly, shame, have, supportive]
#
# expected:  negative
# result:  positive
# context:  the folding chair i was seated at was uncomfortable.
# aspect:  folding chair
# Distances: [1. 0. 0. 2. 2. 1. 2. 1. 2.]
# The closest word to ' folding chair ' is: chair
# The closest second word to ' folding chair ' is: i
# The closest third word to ' folding chair ' is: was
# The closest fourth word to ' folding chair ' is: seated
# While the potential opinion words are:  [uncomfortable]
#
# expected:  negative
# result:  positive
# context:  i know real indian food and this wasn't it.
# aspect:  indian food
# Distances: [2. 1. 1. 0. 0. 2. 3. 2. 3.]
# The closest word to ' indian food ' is: food
# The closest second word to ' indian food ' is: and
# The closest third word to ' indian food ' is: this
# The closest fourth word to ' indian food ' is: wasn't
# While the potential opinion words are:  [real, indian, it]
#
# expected:  positive
# result:  neutral
# context:  even when the chef is not in the house, the food and service are right on target.
# aspect:  food
# Distances: [5. 4. 5. 4. 3. 4. 4. 6. 5. 3. 0. 1. 2. 2. 2. 4. 3.]
# The closest word to ' food ' is: and
# The closest second word to ' food ' is: service
# The closest third word to ' food ' is: are
# The closest fourth word to ' food ' is: right
# While the potential opinion words are:  [even, when, right]
#
# expected:  positive
# result:  neutral
# context:  even when the chef is not in the house, the food and service are right on target.
# aspect:  service
# Distances: [5. 4. 5. 4. 3. 4. 4. 6. 5. 3. 2. 1. 0. 2. 2. 4. 3.]
# The closest word to ' service ' is: and
# The closest second word to ' service ' is: service
# The closest third word to ' service ' is: are
# The closest fourth word to ' service ' is: right
# While the potential opinion words are:  [even, when, right]
#
# expected:  positive
# result:  neutral
# context:  everything from the eggs benedict to the mussels and even the hamburger were done well and very tasty.
# aspect:  mussels
# Distances: [4. 3. 3. 3. 2. 1. 1. 0. 3. 6. 6. 5. 6. 5. 6. 6. 7. 6.]
# The closest word to ' mussels ' is: to
# The closest second word to ' mussels ' is: the
# The closest third word to ' mussels ' is: mussels
# The closest fourth word to ' mussels ' is: and
# While the potential opinion words are:  [even, well, very]
#
# expected:  positive
# result:  negative
# context:  the falafal was rather over cooked and dried but the chicken was fine.
# aspect:  chicken
# Distances: [4. 3. 2. 4. 3. 3. 4. 4. 3. 1. 0. 1. 2.]
# The closest word to ' chicken ' is: the
# The closest second word to ' chicken ' is: chicken
# The closest third word to ' chicken ' is: was
# The closest fourth word to ' chicken ' is: fine.
# While the potential opinion words are:  [rather, cooked, fine]
#
# expected:  neutral
# result:  positive
# context:  desserts include flan and sopaipillas.
# aspect:  desserts
# Distances: [0. 1. 2. 3. 3.]
# The closest word to ' desserts ' is: include
# The closest second word to ' desserts ' is: flan
# The closest third word to ' desserts ' is: and
# The closest fourth word to ' desserts ' is: sopaipillas.
# While the potential opinion words are:  []
#
# expected:  neutral
# result:  positive
# context:  desserts include flan and sopaipillas.
# aspect:  flan
# Distances: [2. 1. 0. 1. 1.]
# The closest word to ' flan ' is: include
# The closest second word to ' flan ' is: flan
# The closest third word to ' flan ' is: and
# The closest fourth word to ' flan ' is: sopaipillas.
# While the potential opinion words are:  []
#
# expected:  neutral
# result:  positive
# context:  desserts include flan and sopaipillas.
# aspect:  sopaipillas
# Distances: [3. 2. 1. 2. 0.]
# While the potential opinion words are:  []
#
# expected:  negative
# result:  positive
# context:  however, the food and service and dramatically lacking.
# aspect:  food
# Distances: [3. 2. 0. 1. 2. 2. 2. 3.]
# The closest word to ' food ' is: and
# The closest second word to ' food ' is: service
# The closest third word to ' food ' is: and
# The closest fourth word to ' food ' is: dramatically
# While the potential opinion words are:  [dramatically]
#
# expected:  negative
# result:  positive
# context:  however, the food and service and dramatically lacking.
# aspect:  service
# Distances: [3. 2. 2. 1. 0. 2. 2. 3.]
# The closest word to ' service ' is: and
# The closest second word to ' service ' is: service
# The closest third word to ' service ' is: and
# The closest fourth word to ' service ' is: dramatically
# While the potential opinion words are:  [dramatically]
#
# expected:  negative
# result:  neutral
# context:  the sushi is cut in blocks bigger than my cell phone.
# aspect:  sushi
# Distances: [1. 0. 2. 1. 2. 3. 4. 5. 7. 7. 6.]
# The closest word to ' sushi ' is: the
# The closest second word to ' sushi ' is: sushi
# The closest third word to ' sushi ' is: is
# The closest fourth word to ' sushi ' is: cut
# While the potential opinion words are:  [bigger]
#
# expected:  neutral
# result:  positive
# context:  the decor is designed in a contemporary japanese style restaurant.
# aspect:  decor
# Distances: [1. 0. 2. 1. 2. 4. 4. 5. 4. 3.]
# The closest word to ' decor ' is: the
# The closest second word to ' decor ' is: decor
# The closest third word to ' decor ' is: is
# The closest fourth word to ' decor ' is: designed
# While the potential opinion words are:  [contemporary, japanese]
#
# expected:  conflict
# result:  positive
# context:  the atmosphere is attractive, but a little uncomfortable.
# aspect:  atmosphere
# Distances: [1. 0. 1. 2. 2. 2. 4. 3.]
# The closest word to ' atmosphere ' is: the
# The closest second word to ' atmosphere ' is: atmosphere
# The closest third word to ' atmosphere ' is: is
# The closest fourth word to ' atmosphere ' is: attractive,
# While the potential opinion words are:  [attractive]
#
# expected:  conflict
# result:  negative
# context:  the sauce may not be for everyone, since it is distintive.
# aspect:  sauce
# Distances: [1. 0. 2. 2. 1. 2. 3. 2. 3. 3. 2.]
# The closest word to ' sauce ' is: the
# The closest second word to ' sauce ' is: sauce
# The closest third word to ' sauce ' is: may
# The closest fourth word to ' sauce ' is: not
# While the potential opinion words are:  [distintive]
#
# expected:  neutral
# result:  positive
# context:  a beautiful atmosphere, perfect for drinks and/or appetizers.
# aspect:  drinks
# Distances: [3. 3. 2. 3. 1. 0. 1. 2.]
# The closest word to ' drinks ' is: for
# The closest second word to ' drinks ' is: drinks
# The closest third word to ' drinks ' is: and/or
# The closest fourth word to ' drinks ' is: appetizers.
# While the potential opinion words are:  [beautiful, perfect]
#
# expected:  neutral
# result:  positive
# context:  a beautiful atmosphere, perfect for drinks and/or appetizers.
# aspect:  appetizers
# Distances: [5. 5. 4. 5. 3. 2. 1. 0.]
# While the potential opinion words are:  [beautiful, perfect]
#
# expected:  negative
# result:  neutral
# context:  frankly, the chinese food here is something i can make better at home.
# aspect:  chinese food
# Distances: [3. 3. 0. 0. 1. 2. 2. 3. 5. 5. 4. 5. 5.]
# The closest word to ' chinese food ' is: food
# The closest second word to ' chinese food ' is: here
# The closest third word to ' chinese food ' is: is
# The closest fourth word to ' chinese food ' is: something
# While the potential opinion words are:  [frankly, chinese, here, something, better]
#
# expected:  neutral
# result:  negative
# context:  there was only one waiter for the whole restaurant upstairs.
# aspect:  waiter
# Distances: [2. 1. 2. 1. 0. 1. 3. 3. 2. 3.]
# The closest word to ' waiter ' is: was
# The closest second word to ' waiter ' is: only
# The closest third word to ' waiter ' is: one
# The closest fourth word to ' waiter ' is: waiter
# While the potential opinion words are:  [only, waiter, whole, upstairs]
#
# expected:  neutral
# result:  positive
# context:  we started with the scallops and asparagus and also had the soft shell crab as well as the cheese plate.
# aspect:  soft shell crab
# Distances: [3. 2. 3. 5. 4. 5. 5. 3. 2. 1. 1. 0. 0. 0. 2. 2. 1. 2. 2. 1.]
# The closest word to ' soft shell crab ' is: shell
# The closest second word to ' soft shell crab ' is: crab
# The closest third word to ' soft shell crab ' is: as
# The closest fourth word to ' soft shell crab ' is: well
# While the potential opinion words are:  [also, soft, as, well]
#
# expected:  neutral
# result:  positive
# context:  we started with the scallops and asparagus and also had the soft shell crab as well as the cheese plate.
# aspect:  cheese plate
# Distances: [4. 3. 4. 6. 5. 6. 6. 4. 3. 2. 2. 3. 2. 1. 3. 3. 2. 1. 0. 0.]
# While the potential opinion words are:  [also, soft, as, well]
#
# expected:  positive
# result:  neutral
# context:  their dinner specials are fantastic.
# aspect:  dinner specials
# Distances: [1. 0. 0. 1. 2.]
# While the potential opinion words are:  [fantastic]
#
# expected:  negative
# result:  positive
# context:  for the price you pay for the food here, you'd expect it to be at least on par with other japanese restaurants.
# aspect:  price
# Distances: [1. 1. 0. 2. 1. 2. 4. 3. 4. 3. 3. 3. 2. 4. 4. 3. 6. 5. 4. 5. 6. 8.]
# The closest word to ' price ' is: for
# The closest second word to ' price ' is: the
# The closest third word to ' price ' is: price
# The closest fourth word to ' price ' is: you
# While the potential opinion words are:  [here, be, at, least, other, japanese]
#
# expected:  negative
# result:  positive
# context:  for the price you pay for the food here, you'd expect it to be at least on par with other japanese restaurants.
# aspect:  food
# Distances: [ 4.  4.  3.  3.  2.  1.  1.  0.  1.  6.  6.  6.  5.  7.  7.  6.  9.  8.
#   7.  8.  9. 11.]
# The closest word to ' food ' is: for
# The closest second word to ' food ' is: the
# The closest third word to ' food ' is: food
# The closest fourth word to ' food ' is: here,
# While the potential opinion words are:  [here, be, at, least, other, japanese]
#
# expected:  positive
# result:  neutral
# context:  my favs here are the tacos pastor and the tostada de tinga...
# aspect:  tostada de tinga
# Distances: [4. 3. 4. 2. 2. 2. 1. 2. 1. 0. 0. 0.]
# While the potential opinion words are:  [here, pastor]
#
# expected:  neutral
# result:  positive
# context:  the food is all-around good, with the rolls usually excellent and the sushi/sashimi not quite on the same level.
# aspect:  sushi/sashimi
# Distances: [3. 2. 1. 4. 4. 3. 2. 2. 1. 2. 1. 1. 0. 1. 2. 1. 2. 2. 3.]
# The closest word to ' sushi/sashimi ' is: is
# The closest second word to ' sushi/sashimi ' is: all-around
# The closest third word to ' sushi/sashimi ' is: good,
# The closest fourth word to ' sushi/sashimi ' is: with
# While the potential opinion words are:  [all, around, good, usually, excellent, quite, same]
#
# expected:  negative
# result:  positive
# context:  (the sashimi is cut a little thinly.
# aspect:  sashimi
# Distances: [3. 0. 1. 3. 2. 4. 3.]
# The closest word to ' sashimi ' is: is
# The closest second word to ' sashimi ' is: cut
# The closest third word to ' sashimi ' is: a
# The closest fourth word to ' sashimi ' is: little
# While the potential opinion words are:  [thinly]
#
# expected:  neutral
# result:  negative
# context:  well, it happened because of a graceless manager and a rude bartender who had us waiting 20 minutes for drinks, and then tells us to chill out.
# aspect:  drinks
# Distances: [ 8.  8.  8.  7.  6.  7.  6.  6.  5.  6.  5.  5.  4.  4.  3.  3.  2.  2.
#   1.  0.  1.  8.  8.  9.  8.  9. 10.]
# The closest word to ' drinks ' is: and
# The closest second word to ' drinks ' is: then
# The closest third word to ' drinks ' is: tells
# The closest fourth word to ' drinks ' is: us
# While the potential opinion words are:  [graceless, rude, waiting, then]
#
# expected:  negative
# result:  neutral
# context:  but the meals were terrible.
# aspect:  meals
# Distances: [2. 1. 0. 1. 2.]
# The closest word to ' meals ' is: the
# The closest second word to ' meals ' is: meals
# The closest third word to ' meals ' is: were
# The closest fourth word to ' meals ' is: terrible.
# While the potential opinion words are:  [terrible]
#
# expected:  negative
# result:  positive
# context:  however, the service is absolutely horrible.
# aspect:  service
# Distances: [3. 3. 0. 1. 2. 4.]
# While the potential opinion words are:  [however, absolutely, horrible]
#
# expected:  neutral
# result:  positive
# context:  it's eaten with black vinegar and shredded ginger.
# aspect:  black vinegar
# Distances: [2. 2. 1. 0. 0. 1. 2. 3.]
# The closest word to ' black vinegar ' is: vinegar
# The closest second word to ' black vinegar ' is: and
# The closest third word to ' black vinegar ' is: shredded
# The closest fourth word to ' black vinegar ' is: ginger.
# While the potential opinion words are:  [black, shredded]
#
# expected:  negative
# result:  positive
# context:  when it came time to take the order the waiter gave us a hard time, walked away then came back with a paper and pen for us to write down what we wanted...excuse me but isn't that his job???
# aspect:  waiter
# Distances: [3. 3. 2. 3. 4. 3. 5. 4. 1. 0. 1. 2. 3. 3. 2. 3. 2. 3. 3. 2. 3. 3. 5. 4.
#  5. 5. 4. 4. 4. 3. 4. 5. 5. 4. 3. 2. 3. 3. 3.]
# The closest word to ' waiter ' is: the
# The closest second word to ' waiter ' is: waiter
# The closest third word to ' waiter ' is: gave
# The closest fourth word to ' waiter ' is: us
# While the potential opinion words are:  [when, hard, away, then, back, wanted, job]
#
# expected:  positive
# result:  neutral
# context:  dieters stick to salads or indulge in vegetarian platters.
# aspect:  salads
# Distances: [3. 2. 1. 0. 3. 3. 4. 6. 5.]
# The closest word to ' salads ' is: to
# The closest second word to ' salads ' is: salads
# The closest third word to ' salads ' is: or
# The closest fourth word to ' salads ' is: indulge
# While the potential opinion words are:  [vegetarian]
#
# expected:  neutral
# result:  positive
# context:  since i cook for a living, i'm very fussy about the food i eat in restaurants.
# aspect:  food
# Distances: [4. 4. 3. 4. 6. 5. 3. 3. 2. 2. 1. 0. 2. 1. 3. 2.]
# The closest word to ' food ' is: the
# The closest second word to ' food ' is: food
# The closest third word to ' food ' is: i
# The closest fourth word to ' food ' is: eat
# While the potential opinion words are:  [very, fussy]
#
# expected:  negative
# result:  neutral
# context:  we were wondering why they were there to make our dining experience miserable?
# aspect:  dining experience
# Distances: [5. 5. 4. 4. 4. 3. 4. 3. 2. 1. 0. 0. 1.]
# While the potential opinion words are:  [why, were, there, miserable]
#
# expected:  positive
# result:  neutral
# context:  we were so happy with our food and were even more thrilled when we saw the bill.
# aspect:  food
# Distances: [4. 3. 3. 2. 1. 1. 0. 4. 4. 7. 6. 5. 6. 6. 5. 7. 6.]
# The closest word to ' food ' is: with
# The closest second word to ' food ' is: our
# The closest third word to ' food ' is: food
# The closest fourth word to ' food ' is: and
# While the potential opinion words are:  [so, happy, even, more, thrilled, when]
#
# expected:  positive
# result:  neutral
# context:  we were so happy with our food and were even more thrilled when we saw the bill.
# aspect:  bill
# Distances: [4. 3. 5. 4. 5. 7. 6. 4. 2. 5. 4. 3. 2. 2. 1. 1. 0.]
# While the potential opinion words are:  [so, happy, even, more, thrilled, when]
#
# expected:  negative
# result:  neutral
# context:  i thought the food isn't cheap at all compared to chinatown.
# aspect:  food
# Distances: [3. 2. 1. 0. 1. 2. 2. 3. 2. 2. 3.]
# The closest word to ' food ' is: the
# The closest second word to ' food ' is: food
# The closest third word to ' food ' is: isn't
# The closest fourth word to ' food ' is: cheap
# While the potential opinion words are:  [is, cheap, at, all]
#
# expected:  positive
# result:  neutral
# context:  first walking in the place seemed to have great ambience.
# aspect:  place
# Distances: [3. 2. 1. 1. 0. 3. 5. 4. 6. 5.]
# The closest word to ' place ' is: in
# The closest second word to ' place ' is: the
# The closest third word to ' place ' is: place
# The closest fourth word to ' place ' is: seemed
# While the potential opinion words are:  [first, great]
#
# expected:  negative
# result:  positive
# context:  the $72 delmonico steak had to be sent back because it was not cooked to order.
# aspect:  delmonico steak
# Distances: [2. 1. 0. 0. 1. 2. 4. 4. 3. 4. 4. 4. 4. 4. 3. 4.]
# The closest word to ' delmonico steak ' is: steak
# The closest second word to ' delmonico steak ' is: had
# The closest third word to ' delmonico steak ' is: to
# The closest fourth word to ' delmonico steak ' is: be
# While the potential opinion words are:  [back]
#
# expected:  negative
# result:  positive
# context:  everytime i go there i can't pick anything to eat and not because the menu is filled with great things to eat.
# aspect:  menu
# Distances: [11. 11. 11. 11.  5.  5.  5.  4.  5.  7.  6.  5.  3.  3.  0.  1.  3.  2.
#   3.  5.  4.  6.]
# The closest word to ' menu ' is: is
# The closest second word to ' menu ' is: filled
# The closest third word to ' menu ' is: with
# The closest fourth word to ' menu ' is: great
# While the potential opinion words are:  [everytime, there, great]
#
# expected:  neutral
# result:  positive
# context:  half a chicken with a mountain of rice and beans for $6.25.
# aspect:  rice
# Distances: [5. 5. 4. 3. 3. 2. 1. 0. 1. 1. 5. 7.]
# The closest word to ' rice ' is: of
# The closest second word to ' rice ' is: rice
# The closest third word to ' rice ' is: and
# The closest fourth word to ' rice ' is: beans
# While the potential opinion words are:  []
#
# expected:  neutral
# result:  positive
# context:  half a chicken with a mountain of rice and beans for $6.25.
# aspect:  beans
# Distances: [6. 6. 5. 4. 4. 3. 2. 1. 2. 0. 6. 8.]
# The closest word to ' beans ' is: rice
# The closest second word to ' beans ' is: and
# The closest third word to ' beans ' is: beans
# The closest fourth word to ' beans ' is: for
# While the potential opinion words are:  []
#
# expected:  positive
# result:  negative
# context:  go for the seafood paella for two.
# aspect:  seafood paella for two
# Distances: [1. 1. 1. 0. 0. 0. 0.]
# While the potential opinion words are:  []
#
# expected:  positive
# result:  neutral
# context:  the one positive thing i can say is that the service was prompt, we got seated right away and the server was very friendly.
# aspect:  service
# Distances: [5. 5. 5. 4. 6. 6. 5. 3. 2. 1. 0. 1. 2. 3. 3. 3. 2. 4. 3. 3. 5. 4. 3. 5.]
# The closest word to ' service ' is: was
# The closest second word to ' service ' is: prompt,
# The closest third word to ' service ' is: we
# The closest fourth word to ' service ' is: got
# While the potential opinion words are:  [positive, prompt, seated, right, away, very, friendly]
#
# expected:  positive
# result:  neutral
# context:  service is usually pretty good.
# aspect:  service
# Distances: [0. 1. 2. 3. 2.]
# The closest word to ' service ' is: is
# The closest second word to ' service ' is: usually
# The closest third word to ' service ' is: pretty
# The closest fourth word to ' service ' is: good.
# While the potential opinion words are:  [usually, pretty, good]
#
# expected:  negative
# result:  neutral
# context:  host and hostess was quite rude.
# aspect:  host
# Distances: [0. 1. 1. 1. 3. 2.]
# The closest word to ' host ' is: and
# The closest second word to ' host ' is: hostess
# The closest third word to ' host ' is: was
# The closest fourth word to ' host ' is: quite
# While the potential opinion words are:  [quite, rude]
#
# expected:  negative
# result:  positive
# context:  host and hostess was quite rude.
# aspect:  hostess
# Distances: [1. 2. 0. 2. 4. 3.]
# The closest word to ' hostess ' is: host
# The closest second word to ' hostess ' is: and
# The closest third word to ' hostess ' is: hostess
# The closest fourth word to ' hostess ' is: was
# While the potential opinion words are:  [quite, rude]
#
# expected:  positive
# result:  neutral
# context:  the wait staff is very friendly, if your not rude or picky.......our meal at leon last weekend was great -.
# aspect:  meal
# Distances: [ 4.  4.  3.  2.  4.  3.  3.  2.  2.  2.  1.  2.  0.  3. 10. 10. 10. 10.
#  10. 10.]
# The closest word to ' meal ' is: or
# The closest second word to ' meal ' is: picky.......our
# The closest third word to ' meal ' is: meal
# The closest fourth word to ' meal ' is: at
# While the potential opinion words are:  [very, friendly, last, great]
#
# expected:  neutral
# result:  positive
# context:  the menu, which changes seasonally, shows both regional and international influences.
# aspect:  menu
# Distances: [1. 0. 1. 2. 1. 2. 1. 1. 4. 3. 4.]
# The closest word to ' menu ' is: the
# The closest second word to ' menu ' is: menu,
# The closest third word to ' menu ' is: which
# The closest fourth word to ' menu ' is: changes
# While the potential opinion words are:  [seasonally, regional]
#
# expected:  positive
# result:  neutral
# context:  their brunch menu had something for everyone.
# aspect:  brunch menu
# Distances: [1. 0. 0. 1. 2. 2. 3.]
# The closest word to ' brunch menu ' is: menu
# The closest second word to ' brunch menu ' is: had
# The closest third word to ' brunch menu ' is: something
# The closest fourth word to ' brunch menu ' is: for
# While the potential opinion words are:  []
#
# expected:  neutral
# result:  positive
# context:  the food is average: breakfast food, soups, salads, sandwiches, etc.
# aspect:  food
# Distances: [1. 0. 1. 2. 2. 2. 1. 2. 2. 3.]
# The closest word to ' food ' is: the
# The closest second word to ' food ' is: food
# The closest third word to ' food ' is: is
# The closest fourth word to ' food ' is: average:
# While the potential opinion words are:  [average]
#
# expected:  neutral
# result:  positive
# context:  the food is average: breakfast food, soups, salads, sandwiches, etc.
# aspect:  breakfast food
# Distances: [3. 2. 1. 2. 0. 0. 1. 2. 2. 3.]
# The closest word to ' breakfast food ' is: food,
# The closest second word to ' breakfast food ' is: soups,
# The closest third word to ' breakfast food ' is: salads,
# The closest fourth word to ' breakfast food ' is: sandwiches,
# While the potential opinion words are:  [average]
#
# expected:  neutral
# result:  positive
# context:  the food is average: breakfast food, soups, salads, sandwiches, etc.
# aspect:  soups
# Distances: [2. 1. 2. 3. 3. 1. 0. 1. 1. 2.]
# The closest word to ' soups ' is: food
# The closest second word to ' soups ' is: is
# The closest third word to ' soups ' is: average:
# The closest fourth word to ' soups ' is: breakfast
# While the potential opinion words are:  [average]
#
# expected:  neutral
# result:  positive
# context:  the food is average: breakfast food, soups, salads, sandwiches, etc.
# aspect:  salads
# Distances: [3. 2. 3. 4. 4. 2. 1. 0. 2. 3.]
# The closest word to ' salads ' is: soups,
# The closest second word to ' salads ' is: salads,
# The closest third word to ' salads ' is: sandwiches,
# The closest fourth word to ' salads ' is: etc.
# While the potential opinion words are:  [average]
#
# expected:  neutral
# result:  positive
# context:  the food is average: breakfast food, soups, salads, sandwiches, etc.
# aspect:  sandwiches
# Distances: [3. 2. 3. 4. 4. 2. 1. 2. 0. 1.]
# The closest word to ' sandwiches ' is: soups,
# The closest second word to ' sandwiches ' is: salads,
# The closest third word to ' sandwiches ' is: sandwiches,
# The closest fourth word to ' sandwiches ' is: etc.
# While the potential opinion words are:  [average]
#
# expected:  negative
# result:  positive
# context:  i was highly disappointed by the food.
# aspect:  food
# Distances: [4. 3. 3. 2. 1. 1. 0.]
# While the potential opinion words are:  [highly, disappointed]
#
# expected:  negative
# result:  positive
# context:  the banana pudding they serve has never seen an oven,the crabcakes are way over salted and don't get me started on the very greasy mac and cheese.
# aspect:  banana pudding
# Distances: [1. 0. 0. 2. 1. 2. 2. 1. 3. 2. 3. 4. 3. 2. 5. 4. 3. 3. 4. 4. 3. 5. 4. 5.
#  7. 8. 7.]
# The closest word to ' banana pudding ' is: pudding
# The closest second word to ' banana pudding ' is: they
# The closest third word to ' banana pudding ' is: serve
# The closest fourth word to ' banana pudding ' is: has
# While the potential opinion words are:  [seen, way, over, salted, started, very]
#
# expected:  negative
# result:  positive
# context:  the banana pudding they serve has never seen an oven,the crabcakes are way over salted and don't get me started on the very greasy mac and cheese.
# aspect:  crabcakes
# Distances: [4. 4. 3. 5. 4. 3. 3. 2. 4. 3. 0. 3. 2. 1. 4. 3. 2. 2. 3. 3. 2. 4. 3. 4.
#  6. 7. 6.]
# The closest word to ' crabcakes ' is: over
# The closest second word to ' crabcakes ' is: salted
# The closest third word to ' crabcakes ' is: and
# The closest fourth word to ' crabcakes ' is: don't
# While the potential opinion words are:  [seen, way, over, salted, started, very]
#
# expected:  negative
# result:  positive
# context:  the staff is arrogant, the prices are way high for brooklyn.
# aspect:  staff
# Distances: [1. 0. 1. 2. 3. 4. 3. 2. 4. 3. 4.]
# The closest word to ' staff ' is: the
# The closest second word to ' staff ' is: staff
# The closest third word to ' staff ' is: is
# The closest fourth word to ' staff ' is: arrogant,
# While the potential opinion words are:  [arrogant, way, high]
#
# expected:  negative
# result:  positive
# context:  the staff is arrogant, the prices are way high for brooklyn.
# aspect:  prices
# Distances: [5. 4. 3. 4. 3. 0. 1. 2. 4. 3. 4.]
# The closest word to ' prices ' is: are
# The closest second word to ' prices ' is: way
# The closest third word to ' prices ' is: high
# The closest fourth word to ' prices ' is: for
# While the potential opinion words are:  [arrogant, way, high]
#
# expected:  negative
# result:  neutral
# context:  the food was definitely good, but when all was said and done, i just couldn't justify it for the price (including 2 drinks, $100/person)...
# aspect:  price
# Distances: [4. 3. 2. 3. 3. 3. 3. 3. 3. 3. 2. 3. 3. 2. 2. 2. 2. 2. 1. 0. 2. 4. 3. 4.]
# The closest word to ' price ' is: the
# The closest second word to ' price ' is: price
# The closest third word to ' price ' is: (including
# The closest fourth word to ' price ' is: 2
# While the potential opinion words are:  [definitely, good, when, just]
#
# expected:  neutral
# result:  positive
# context:  the food was definitely good, but when all was said and done, i just couldn't justify it for the price (including 2 drinks, $100/person)...
# aspect:  drinks
# Distances: [5. 4. 3. 4. 4. 4. 4. 4. 4. 4. 3. 4. 4. 3. 3. 3. 3. 3. 2. 3. 1. 1. 0. 1.]
# While the potential opinion words are:  [definitely, good, when, just]
#
# expected:  neutral
# result:  positive
# context:  i've come here for casual lunches as well as for a friend's birthday and i always enjoy myself.
# aspect:  casual lunches
# Distances: [2. 2. 1. 2. 0. 0. 1. 2. 2. 1. 1. 4. 3. 4. 2. 9. 9. 9.]
# The closest word to ' casual lunches ' is: lunches
# The closest second word to ' casual lunches ' is: as
# The closest third word to ' casual lunches ' is: well
# The closest fourth word to ' casual lunches ' is: as
# While the potential opinion words are:  [here, casual, as, well, always]
#
# expected:  positive
# result:  neutral
# context:  if you are a tequila fan you will not be disappointed.
# aspect:  tequila
# Distances: [3. 3. 2. 2. 0. 1. 4. 4. 4. 4. 3.]
# The closest word to ' tequila ' is: fan
# The closest second word to ' tequila ' is: you
# The closest third word to ' tequila ' is: will
# The closest fourth word to ' tequila ' is: not
# While the potential opinion words are:  [tequila, fan]
#
# expected:  negative
# result:  positive
# context:  my vegetable risotto was burnt, and infused totally in a burnt flavor.
# aspect:  vegetable risotto
# Distances: [1. 0. 0. 2. 1. 2. 2. 2. 3. 3. 5. 5.]
# The closest word to ' vegetable risotto ' is: risotto
# The closest second word to ' vegetable risotto ' is: was
# The closest third word to ' vegetable risotto ' is: burnt,
# The closest fourth word to ' vegetable risotto ' is: and
# While the potential opinion words are:  [totally, burnt]
#
# expected:  negative
# result:  positive
# context:  my vegetable risotto was burnt, and infused totally in a burnt flavor.
# aspect:  flavor
# Distances: [6. 6. 5. 5. 4. 5. 5. 3. 4. 2. 2. 0.]
# While the potential opinion words are:  [totally, burnt]
#
# expected:  positive
# result:  neutral
# context:  but dinner here is never disappointing, even if the prices are a bit over the top.
# aspect:  dinner
# Distances: [2. 0. 1. 1. 3. 2. 2. 3. 3. 4. 3. 2. 5. 4. 3. 5.]
# The closest word to ' dinner ' is: here
# The closest second word to ' dinner ' is: is
# The closest third word to ' dinner ' is: never
# The closest fourth word to ' dinner ' is: disappointing,
# While the potential opinion words are:  [here, disappointing, even]
#
# expected:  positive
# result:  neutral
# context:  best things to order are from the grill (churrasco and ribs).
# aspect:  grill
# Distances: [4. 3. 5. 4. 2. 1. 1. 0. 1. 1. 2.]
# The closest word to ' grill ' is: from
# The closest second word to ' grill ' is: the
# The closest third word to ' grill ' is: grill
# The closest fourth word to ' grill ' is: (churrasco
# While the potential opinion words are:  [best]
#
# expected:  positive
# result:  negative
# context:  best things to order are from the grill (churrasco and ribs).
# aspect:  churrasco
# Distances: [5. 4. 6. 5. 3. 2. 2. 1. 2. 0. 1.]
# The closest word to ' churrasco ' is: grill
# The closest second word to ' churrasco ' is: (churrasco
# The closest third word to ' churrasco ' is: and
# The closest fourth word to ' churrasco ' is: ribs).
# While the potential opinion words are:  [best]
#
# expected:  positive
# result:  neutral
# context:  best things to order are from the grill (churrasco and ribs).
# aspect:  ribs
# Distances: [6. 5. 7. 6. 4. 3. 3. 2. 3. 1. 0.]
# While the potential opinion words are:  [best]
#
# expected:  conflict
# result:  positive
# context:  the ambiance was pretty cool, but not worth the hassle.
# aspect:  ambiance
# Distances: [1. 0. 1. 3. 2. 2. 2. 3. 2. 4.]
# The closest word to ' ambiance ' is: the
# The closest second word to ' ambiance ' is: ambiance
# The closest third word to ' ambiance ' is: was
# The closest fourth word to ' ambiance ' is: pretty
# While the potential opinion words are:  [pretty, cool]
#
# expected:  neutral
# result:  negative
# context:  the unfortunate lady next to us thought she had ordered a salad (including asking for salad dressing) and was instead given a quesedilla.
# aspect:  salad
# Distances: [4. 4. 3. 4. 5. 6. 2. 2. 2. 1. 1. 0. 1. 1. 2. 3. 5. 4. 1. 2. 3. 3. 2.]
# The closest word to ' salad ' is: was
# The closest second word to ' salad ' is: instead
# The closest third word to ' salad ' is: given
# The closest fourth word to ' salad ' is: a
# While the potential opinion words are:  [unfortunate, next, ordered, instead]
#
# expected:  neutral
# result:  negative
# context:  the unfortunate lady next to us thought she had ordered a salad (including asking for salad dressing) and was instead given a quesedilla.
# aspect:  salad dressing
# Distances: [7. 7. 6. 7. 8. 9. 5. 5. 5. 4. 4. 3. 4. 2. 1. 0. 0. 1. 4. 5. 6. 6. 5.]
# The closest word to ' salad dressing ' is: salad
# The closest second word to ' salad dressing ' is: dressing)
# The closest third word to ' salad dressing ' is: and
# The closest fourth word to ' salad dressing ' is: was
# While the potential opinion words are:  [unfortunate, next, ordered, instead]
#
# expected:  neutral
# result:  negative
# context:  the unfortunate lady next to us thought she had ordered a salad (including asking for salad dressing) and was instead given a quesedilla.
# aspect:  quesedilla
# Distances: [4. 4. 3. 4. 5. 6. 2. 2. 2. 1. 3. 2. 3. 3. 4. 5. 7. 6. 3. 2. 1. 1. 0.]
# While the potential opinion words are:  [unfortunate, next, ordered, instead]
#
# expected:  negative
# result:  positive
# context:  the service was pretty poor all around, the food was well below average relative to the cost, and outside there is a crazy bum who harasses every customer who leaves the place.
# aspect:  food
# Distances: [5. 4. 3. 5. 4. 5. 4. 3. 0. 1. 2. 4. 3. 5. 4. 5. 7. 6. 3. 3. 4. 4. 3. 5.
#  5. 4. 6. 5. 7. 6. 8. 7.]
# The closest word to ' food ' is: was
# The closest second word to ' food ' is: well
# The closest third word to ' food ' is: below
# The closest fourth word to ' food ' is: average
# While the potential opinion words are:  [was, pretty, poor, all, around, well, average, crazy, bum]
#
# expected:  neutral
# result:  positive
# context:  when she complained, the waitress said, sorry.
# aspect:  waitress
# Distances: [4. 4. 3. 3. 0. 1. 2.]
# While the potential opinion words are:  [when, sorry]
#
# expected:  negative
# result:  positive
# context:  the quality of the meat was on par with your local grocery store.
# aspect:  quality of the meat
# Distances: [1. 0. 0. 0. 0. 1. 2. 3. 4. 6. 6. 6. 5.]
# The closest word to ' quality of the meat ' is: of
# The closest second word to ' quality of the meat ' is: the
# The closest third word to ' quality of the meat ' is: meat
# The closest fourth word to ' quality of the meat ' is: was
# While the potential opinion words are:  [local]
#
# expected:  neutral
# result:  negative
# context:  the manager then told us we could order from whatever menu we wanted but by that time we were so annoyed with the waiter and the resturant that we let and went some place else.
# aspect:  manager
# Distances: [1. 0. 2. 1. 2. 3. 3. 2. 3. 6. 5. 5. 4. 4. 5. 7. 6. 5. 4. 6. 5. 6. 8. 7.
#  8. 9. 8. 7. 7. 6. 7. 7. 9. 8. 9.]
# The closest word to ' manager ' is: the
# The closest second word to ' manager ' is: manager
# The closest third word to ' manager ' is: then
# The closest fourth word to ' manager ' is: told
# While the potential opinion words are:  [then, order, so, annoyed, let, else]
#
# expected:  negative
# result:  neutral
# context:  in mi burrito, here was nothing but dark chicken that had that cooked last week and just warmed up in a microwave taste.
# aspect:  taste
# Distances: [7. 9. 8. 7. 7. 6. 5. 6. 8. 7. 6. 5. 5. 4. 6. 5. 5. 4. 3. 4. 2. 2. 0.]
# While the potential opinion words are:  [here, nothing, dark, last, just]
#
# expected:  neutral
# result:  positive
# context:  during busy hrs, i recommend that you make a reservation.
# aspect:  reservation
# Distances: [4. 6. 5. 4. 4. 3. 3. 3. 2. 0.]
# While the potential opinion words are:  [busy, make]
#
# expected:  neutral
# result:  positive
# context:  now called nikki sushi, sushi is ok.
# aspect:  sushi
# Distances: [2. 1. 1. 0. 3. 3. 2.]
# The closest word to ' sushi ' is: called
# The closest second word to ' sushi ' is: nikki
# The closest third word to ' sushi ' is: sushi,
# The closest fourth word to ' sushi ' is: sushi
# While the potential opinion words are:  [now, ok]
#
# expected:  neutral
# result:  positive
# context:  there's candlelight and music.
# aspect:  candlelight
# Distances: [1. 0. 1. 2.]
# The closest word to ' candlelight ' is: there's
# The closest second word to ' candlelight ' is: candlelight
# The closest third word to ' candlelight ' is: and
# The closest fourth word to ' candlelight ' is: music.
# While the potential opinion words are:  [candlelight]
#
# expected:  neutral
# result:  positive
# context:  there's candlelight and music.
# aspect:  music
# Distances: [3. 2. 1. 0.]
# While the potential opinion words are:  [candlelight]
#
# expected:  negative
# result:  neutral
# context:  i've had better japanese food at a mall food court.
# aspect:  japanese food
# Distances: [3. 3. 2. 0. 0. 1. 3. 5. 5. 5.]
# The closest word to ' japanese food ' is: food
# The closest second word to ' japanese food ' is: at
# The closest third word to ' japanese food ' is: a
# The closest fourth word to ' japanese food ' is: mall
# While the potential opinion words are:  [better, japanese]
#
# expected:  negative
# result:  neutral
# context:  the sashimi portion are big enough to appease most people, but i didn't like the fact they used artifical lobster meat.
# aspect:  artifical lobster meat
# Distances: [5. 5. 4. 3. 4. 5. 6. 5. 7. 6. 4. 4. 3. 3. 3. 2. 2. 1. 0. 0. 0.]
# While the potential opinion words are:  [big, enough, most, artifical]
#
# expected:  neutral
# result:  negative
# context:  they have waiters on the sidewalk trying to pull you in which made us suspicious.
# aspect:  waiters
# Distances: [3. 2. 0. 1. 3. 2. 1. 3. 2. 3. 3. 4. 1. 3. 2.]
# The closest word to ' waiters ' is: on
# The closest second word to ' waiters ' is: the
# The closest third word to ' waiters ' is: sidewalk
# The closest fourth word to ' waiters ' is: trying
# While the potential opinion words are:  [made, suspicious]
#
# expected:  neutral
# result:  positive
# context:  it was our only opportunity to visit and wanted an authentic italian meal.
# aspect:  italian meal
# Distances: [5. 4. 4. 4. 3. 3. 2. 3. 1. 1. 1. 0. 0.]
# While the potential opinion words are:  [only, opportunity, authentic, italian]
#
# expected:  positive
# result:  neutral
# context:  it took 100 years for parisi to get around to making pizza (at least i don't think they ever made it before this year)...but it was worth the wait.
# aspect:  pizza
# Distances: [ 5.   4.   6.   5.   5.   6.   4.   3.   4.   2.   1.   0.   6.   7.
#   6.   6.   6.   6.   5.   7.   7.   6.   7.   7.  14.5 14.5 14.5 14.5
#  14.5]
# The closest word to ' pizza ' is: making
# The closest second word to ' pizza ' is: pizza
# The closest third word to ' pizza ' is: (at
# The closest fourth word to ' pizza ' is: least
# While the potential opinion words are:  [around, at, least, ever, made, worth]
#
# expected:  negative
# result:  neutral
# context:  probably my worst dining experience in new york, and i'm a former waiter so i know what i'm talking about.
# aspect:  dining experience
# Distances: [ 1.  1.  1.  0.  0.  1.  3.  2.  1.  1.  2.  1.  3.  3.  2. 10. 10. 10.
#  10. 10.]
# The closest word to ' dining experience ' is: experience
# The closest second word to ' dining experience ' is: in
# The closest third word to ' dining experience ' is: new
# The closest fourth word to ' dining experience ' is: york,
# While the potential opinion words are:  [probably, worst, former, waiter, so, talking]
#
# expected:  neutral
# result:  negative
# context:  probably my worst dining experience in new york, and i'm a former waiter so i know what i'm talking about.
# aspect:  waiter
# Distances: [ 4.  4.  4.  4.  3.  4.  6.  5.  4.  4.  3.  2.  0.  2.  1. 10. 10. 10.
#  10. 10.]
# The closest word to ' waiter ' is: i
# The closest second word to ' waiter ' is: know
# The closest third word to ' waiter ' is: what
# The closest fourth word to ' waiter ' is: i'm
# While the potential opinion words are:  [probably, worst, former, waiter, so, talking]
#
# expected:  negative
# result:  positive
# ...
#
# expected:  negative
# result:  positive
# context:  the room is a little plain, but it's difficult to make such a small place exciting and i would not suggest that as a reason not to go.
# aspect:  place
# Distances: [ 7.  6.  5.  8.  7.  6.  6.  6.  5.  4.  5.  4.  3.  2.  0.  2.  1.  2.
#  14. 14. 14. 14. 14. 14. 14. 14. 14. 14.]
# The closest word to ' place ' is: and
# The closest second word to ' place ' is: i
# The closest third word to ' place ' is: would
# The closest fourth word to ' place ' is: not
# While the potential opinion words are:  [little, plain, difficult, small, exciting]
#
# expected:  positive
# result:  negative
# context:  prices even outside of restaurant week were great.
# aspect:  prices
# Distances: [0. 2. 1. 2. 4. 3. 1. 2.]
# The closest word to ' prices ' is: outside
# The closest second word to ' prices ' is: of
# The closest third word to ' prices ' is: restaurant
# The closest fourth word to ' prices ' is: week
# While the potential opinion words are:  [even, outside, great]
#
# expected:  positive
# result:  negative
# context:  a small, outdoor eating area makes for a private, comfortable space to study alone or meet up with friends.
# aspect:  space
# Distances: [5. 5. 5. 5. 5. 4. 3. 2. 2. 2. 0. 2. 1. 5. 4. 5. 5. 5. 6.]
# The closest word to ' space ' is: study
# The closest second word to ' space ' is: alone
# The closest third word to ' space ' is: or
# The closest fourth word to ' space ' is: meet
# While the potential opinion words are:  [small, outdoor, eating, private, comfortable, alone]
#
# expected:  neutral
# result:  positive
# context:  the best dessert, a chocolate and peanut butter tart, isn't particularly hawaiian, but it's a small world when it comes to sweets.
# aspect:  sweets
# Distances: [4. 4. 3. 4. 5. 4. 5. 6. 6. 5. 4. 2. 3. 4. 3. 3. 3. 2. 1. 1. 1. 0.]
# While the potential opinion words are:  [best, particularly, hawaiian, small, world, when]
#
# expected:  neutral
# result:  positive
# context:  for an appetizer, their calamari is a winner.
# aspect:  appetizer
# Distances: [1. 1. 0. 3. 4. 3. 2. 4.]
# The closest word to ' appetizer ' is: for
# The closest second word to ' appetizer ' is: an
# The closest third word to ' appetizer ' is: appetizer,
# The closest fourth word to ' appetizer ' is: their
# While the potential opinion words are:  [winner]
#
# expected:  neutral
# result:  positive
# context:  the room is a gorgeous, bi-level space and the long bar perfect for a drink.
# aspect:  drink
# Distances: [5. 4. 3. 3. 3. 3. 4. 4. 3. 2. 3. 2. 2. 1. 0.]
# While the potential opinion words are:  [gorgeous, space, long, perfect]
#
# expected:  negative
# result:  neutral
# context:  two complaints- their appetizer selection stinks, it would be nice to get some mozzarella sticks on the menu.
# aspect:  appetizer selection
# Distances: [3. 2. 1. 0. 0. 1. 4. 4. 4. 3. 4. 5. 4. 6. 6. 5. 5. 7.]
# The closest word to ' appetizer selection ' is: selection
# The closest second word to ' appetizer selection ' is: stinks,
# The closest third word to ' appetizer selection ' is: it
# The closest fourth word to ' appetizer selection ' is: would
# While the potential opinion words are:  [nice]
#
# expected:  negative
# result:  neutral
# context:  two complaints- their appetizer selection stinks, it would be nice to get some mozzarella sticks on the menu.
# aspect:  menu
# Distances: [6. 5. 8. 8. 7. 6. 5. 5. 5. 4. 5. 4. 3. 5. 5. 4. 2. 0.]
# While the potential opinion words are:  [nice]
#
# expected:  conflict
# result:  positive
# context:  the service is great (maybe even borderline nagging but at least you get attention), the desserts are excellent and the coffee is so very good...
# aspect:  service
# Distances: [ 1.   0.   1.   2.   4.   4.   4.   3.   2.  12.5 12.5 12.5 12.5 12.5
#  12.5 12.5 12.5 12.5 12.5 12.5 12.5 12.5 12.5 12.5 12.5]
# The closest word to ' service ' is: the
# The closest second word to ' service ' is: service
# The closest third word to ' service ' is: is
# The closest fourth word to ' service ' is: great
# While the potential opinion words are:  [great, maybe, even, nagging, at, least, get, excellent, so, very, good]
#
# expected:  negative
# result:  positive
# context:  while the smoothies are a little big for me, the fresh juices are the best i have ever had!
# aspect:  smoothies
# Distances: [2. 1. 0. 1. 4. 3. 2. 3. 4. 3. 4. 4. 3. 2. 4. 3. 5. 5. 5.]
# The closest word to ' smoothies ' is: the
# The closest second word to ' smoothies ' is: smoothies
# The closest third word to ' smoothies ' is: are
# The closest fourth word to ' smoothies ' is: a
# While the potential opinion words are:  [little, big, fresh, best, ever]
#
# expected:  conflict
# result:  neutral
# context:  the food is just okay, and it's almost not worth going unless you're getting the pialla, which is the only dish that's really good.
# aspect:  food
# Distances: [1. 0. 1. 3. 2. 2. 2. 3. 2. 3. 3. 3. 4. 4. 4. 4. 3. 5. 4. 5. 6. 5. 7. 7.]
# The closest word to ' food ' is: the
# The closest second word to ' food ' is: food
# The closest third word to ' food ' is: is
# The closest fourth word to ' food ' is: just
# While the potential opinion words are:  [just, okay, almost, worth, only, dish, really, good]
#
# expected:  conflict
# result:  positive
# context:  the guac is fresh, yet lacking flavor, we like to add our fresh salsa into it.
# aspect:  guac
# Distances: [1. 0. 1. 2. 2. 2. 2. 3. 3. 3. 2. 4. 3. 5. 5. 4.]
# The closest word to ' guac ' is: the
# The closest second word to ' guac ' is: guac
# The closest third word to ' guac ' is: is
# The closest fourth word to ' guac ' is: fresh,
# While the potential opinion words are:  [is, fresh, fresh]
#
# expected:  neutral
# result:  positive
# context:  the guac is fresh, yet lacking flavor, we like to add our fresh salsa into it.
# aspect:  fresh salsa
# Distances: [4. 3. 2. 3. 3. 3. 3. 4. 2. 2. 1. 1. 0. 0. 2. 1.]
# While the potential opinion words are:  [is, fresh, fresh]
#
# expected:  negative
# result:  positive
# context:  the guac is fresh, yet lacking flavor, we like to add our fresh salsa into it.
# aspect:  flavor
# Distances: [3. 2. 1. 2. 2. 2. 0. 1. 3. 3. 2. 4. 3. 5. 5. 4.]
# The closest word to ' flavor ' is: is
# The closest second word to ' flavor ' is: fresh,
# The closest third word to ' flavor ' is: yet
# The closest fourth word to ' flavor ' is: lacking
# While the potential opinion words are:  [is, fresh, fresh]
#
# expected:  negative
# result:  positive
# context:  the new menu has a few creative items,they were smart enough to keep some of the old favorites (but they raised the prices), the staff is friendly most of the time, but i must agree with the person that wrote about their favorite words: no, can't, sorry..., boy, they won't bend the rules for anyone.
# aspect:  prices
# Distances: [ 5.  5.  4.  3.  5.  5.  5.  4.  3.  3.  2.  3.  4.  5.  4.  5.  6.  8.
#   8.  7.  3.  3.  0.  1.  3.  2.  2.  4.  5.  4.  3.  4.  4.  5.  7.  6.
#   4.  4.  5.  5.  4.  5.  7.  6.  8.  7.  8. 10. 10.  9.  5.  7.  7.  6.
#   7.]
# The closest word to ' prices ' is: the
# The closest second word to ' prices ' is: staff
# The closest third word to ' prices ' is: is
# The closest fourth word to ' prices ' is: friendly
# While the potential opinion words are:  [new, has, few, creative, smart, enough, old, friendly, most, favorite]
#
# expected:  conflict
# result:  positive
# context:  the new menu has a few creative items,they were smart enough to keep some of the old favorites (but they raised the prices), the staff is friendly most of the time, but i must agree with the person that wrote about their favorite words: no, can't, sorry..., boy, they won't bend the rules for anyone.
# aspect:  staff
# Distances: [ 6.  6.  5.  4.  6.  6.  6.  5.  4.  4.  3.  4.  5.  6.  5.  6.  7.  9.
#   9.  8.  4.  4.  3.  2.  0.  1.  3.  5.  6.  5.  4.  5.  5.  6.  8.  7.
#   5.  5.  6.  6.  5.  6.  8.  7.  9.  8.  9. 11. 11. 10.  6.  8.  8.  7.
#   8.]
# The closest word to ' staff ' is: is
# The closest second word to ' staff ' is: friendly
# The closest third word to ' staff ' is: most
# The closest fourth word to ' staff ' is: of
# While the potential opinion words are:  [new, has, few, creative, smart, enough, old, friendly, most, favorite]
#
# expected:  positive
# result:  neutral
# context:  if you like seafood and/or greek food you will love this place though it is not limited to just these things.
# aspect:  seafood
# Distances: [2. 2. 1. 0. 2. 2. 3. 3. 3. 2. 4. 3. 4. 4. 3. 4. 4. 5. 7. 7. 6.]
# The closest word to ' seafood ' is: like
# The closest second word to ' seafood ' is: seafood
# The closest third word to ' seafood ' is: and/or
# The closest fourth word to ' seafood ' is: greek
# While the potential opinion words are:  [limited, just]
#
# expected:  positive
# result:  neutral
# context:  if you like seafood and/or greek food you will love this place though it is not limited to just these things.
# aspect:  greek food
# Distances: [2. 2. 1. 2. 2. 0. 0. 3. 3. 2. 4. 3. 4. 4. 3. 4. 4. 5. 7. 7. 6.]
# The closest word to ' greek food ' is: food
# The closest second word to ' greek food ' is: you
# The closest third word to ' greek food ' is: will
# The closest fourth word to ' greek food ' is: love
# While the potential opinion words are:  [limited, just]
#
# expected:  neutral
# result:  positive
# context:  " the menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians.
# aspect:  burgers
# Distances: [3. 4. 3. 2. 2. 1. 0. 2. 3. 3. 4. 5. 4. 2. 2. 3. 3. 3. 2. 3. 5.]
# The closest word to ' burgers ' is: fare--burgers,
# The closest second word to ' burgers ' is: steaks
# The closest third word to ' burgers ' is: and
# The closest fourth word to ' burgers ' is: shepherds
# While the potential opinion words are:  [even, black]
#
# expected:  neutral
# result:  positive
# context:  " the menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians.
# aspect:  steaks
# Distances: [3. 4. 3. 2. 2. 1. 0. 2. 3. 3. 4. 5. 4. 2. 2. 3. 3. 3. 2. 3. 5.]
# The closest word to ' steaks ' is: fare--burgers,
# The closest second word to ' steaks ' is: steaks
# The closest third word to ' steaks ' is: and
# The closest fourth word to ' steaks ' is: shepherds
# While the potential opinion words are:  [even, black]
#
# expected:  neutral
# result:  positive
# context:  " the menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians.
# aspect:  shepherds pie
# Distances: [4. 5. 4. 3. 3. 2. 3. 1. 0. 0. 1. 2. 1. 3. 3. 4. 4. 4. 3. 4. 6.]
# The closest word to ' shepherds pie ' is: pie--and
# The closest second word to ' shepherds pie ' is: even
# The closest third word to ' shepherds pie ' is: a
# The closest fourth word to ' shepherds pie ' is: portabella
# While the potential opinion words are:  [even, black]
#
# expected:  neutral
# result:  positive
# context:  " the menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians.
# aspect:  portabella lasagna
# Distances: [3. 4. 3. 2. 2. 1. 2. 2. 3. 1. 2. 1. 0. 0. 2. 3. 3. 3. 2. 3. 5.]
# The closest word to ' portabella lasagna ' is: lasagna
# The closest second word to ' portabella lasagna ' is: for
# The closest third word to ' portabella lasagna ' is: those
# The closest fourth word to ' portabella lasagna ' is: black
# While the potential opinion words are:  [even, black]
#
# expected:  neutral
# result:  positive
# context:  " the menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians.
# aspect:  pub fare
# Distances: [2. 3. 2. 1. 0. 0. 1. 1. 2. 2. 3. 4. 3. 1. 1. 2. 2. 2. 1. 2. 4.]
# The closest word to ' pub fare ' is: fare--burgers,
# The closest second word to ' pub fare ' is: steaks
# The closest third word to ' pub fare ' is: and
# The closest fourth word to ' pub fare ' is: shepherds
# While the potential opinion words are:  [even, black]
#
# expected:  negative
# result:  neutral
# context:  i have eaten here on a different occasion - the food is mediocre for the prices.
# aspect:  prices
# Distances: [5. 5. 4. 5. 5. 7. 7. 6. 4. 5. 4. 3. 2. 1. 1. 0.]
# While the potential opinion words are:  [eaten, here, different, mediocre]
#
# expected:  neutral
# result:  negative
# context:  i asked repeatedly what the status of the meal was and was pretty much grunted at by the unbelievably rude waiter.
# aspect:  meal
# Distances: [5. 4. 5. 4. 3. 2. 1. 1. 0. 3. 4. 5. 6. 5. 4. 5. 5. 7. 8. 7. 6.]
# The closest word to ' meal ' is: of
# The closest second word to ' meal ' is: the
# The closest third word to ' meal ' is: meal
# The closest fourth word to ' meal ' is: was
# While the potential opinion words are:  [repeatedly, what, was, pretty, much, unbelievably, rude]
#
# expected:  neutral
# result:  positive
# context:  i stopped by for some brunch today and had the vegan cranberry pancakes and some rice milk.
# aspect:  rice milk
# Distances: [4. 3. 4. 4. 6. 5. 4. 4. 2. 2. 2. 2. 1. 2. 1. 0. 0.]
# While the potential opinion words are:  []
#
# expected:  negative
# result:  positive
# context:  its good to go there for drinks if you don't want to get drunk because you'll be lucky if you can get one drink an hour the service is so bad.
# aspect:  service
# Distances: [5. 4. 6. 5. 6. 6. 7. 7. 7. 7. 7. 6. 8. 7. 8. 4. 4. 4. 3. 4. 3. 3. 3. 2.
#  2. 1. 1. 0. 7. 6. 5.]
# The closest word to ' service ' is: the
# The closest second word to ' service ' is: service
# The closest third word to ' service ' is: is
# The closest fourth word to ' service ' is: so
# While the potential opinion words are:  [there, drunk, lucky, so, bad]
#
# expected:  neutral
# result:  positive
# context:  its good to go there for drinks if you don't want to get drunk because you'll be lucky if you can get one drink an hour the service is so bad.
# aspect:  drink
# Distances: [4. 3. 3. 2. 3. 1. 0. 4. 4. 4. 4. 3. 5. 4. 5. 5. 5. 5. 4. 5. 6. 6. 6. 5.
#  7. 6. 8. 7. 6. 5. 4.]
# The closest word to ' drink ' is: for
# The closest second word to ' drink ' is: drinks
# The closest third word to ' drink ' is: if
# The closest fourth word to ' drink ' is: you
# While the potential opinion words are:  [there, drunk, lucky, so, bad]
#
# expected:  neutral
# result:  positive
# context:  its good to go there for drinks if you don't want to get drunk because you'll be lucky if you can get one drink an hour the service is so bad.
# aspect:  drinks
# Distances: [4. 3. 3. 2. 3. 1. 0. 4. 4. 4. 4. 3. 5. 4. 5. 5. 5. 5. 4. 5. 6. 6. 6. 5.
#  7. 6. 8. 7. 6. 5. 4.]
# The closest word to ' drinks ' is: for
# The closest second word to ' drinks ' is: drinks
# The closest third word to ' drinks ' is: if
# The closest fourth word to ' drinks ' is: you
# While the potential opinion words are:  [there, drunk, lucky, so, bad]
#
# expected:  negative
# result:  positive
# context:  anyway, the owner was fake.
# aspect:  owner
# Distances: [3. 3. 0. 1. 2.]
# While the potential opinion words are:  [anyway, fake]
#
# expected:  negative
# result:  neutral
# context:  i have never in my life sent back food before, but i simply had to, and the waiter argued with me over this.
# aspect:  food
# Distances: [2. 2. 3. 2. 4. 3. 1. 2. 0. 2. 2. 2. 3. 3. 2. 3. 3. 3. 5. 4. 3. 4. 5.]
# The closest word to ' food ' is: sent
# The closest second word to ' food ' is: back
# The closest third word to ' food ' is: food
# The closest fourth word to ' food ' is: before,
# While the potential opinion words are:  [back, before, simply]
#
# expected:  negative
# result:  positive
# context:  i have never in my life sent back food before, but i simply had to, and the waiter argued with me over this.
# aspect:  waiter
# Distances: [3. 3. 4. 3. 5. 4. 2. 3. 3. 3. 3. 3. 2. 2. 1. 2. 2. 0. 4. 3. 2. 3. 4.]
# The closest word to ' waiter ' is: to,
# The closest second word to ' waiter ' is: and
# The closest third word to ' waiter ' is: the
# The closest fourth word to ' waiter ' is: waiter
# While the potential opinion words are:  [back, before, simply]
#
# expected:  neutral
# result:  positive
# context:  creamy appetizers--taramasalata, eggplant salad, and greek yogurt (with cuccumber, dill, and garlic) taste excellent when on warm pitas.
# aspect:  warm pitas
# Distances: [8. 7. 8. 6. 7. 6. 5. 6. 6. 5. 4. 5. 3. 2. 3. 1. 0. 0.]
# While the potential opinion words are:  [eggplant, greek, excellent, when, warm]
