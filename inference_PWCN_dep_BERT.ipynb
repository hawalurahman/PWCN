# %%
# !git clone https://github.com/hawalurahman/PWCN
# Out:
# Cloning into 'PWCN'...
# remote: Enumerating objects: 201, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 201 (delta 0), reused 1 (delta 0), pack-reused 197
# Receiving objects: 100% (201/201), 87.44 MiB | 14.79 MiB/s, done.
# Resolving deltas: 100% (92/92), done.
# Updating files: 100% (71/71), done.

# %%
# %cd  /content/PWCN
# Out:
# /content/PWCN

# %%
from layers.dynamic_rnn import DynamicLSTM
import numpy as np
import math
import torch
import torch.nn as nn
import torch.nn.functional as F

class DependencyProximity(nn.Module):
    def __init__(self, opt):
        self.opt = opt
        super(DependencyProximity, self).__init__()

    def forward(self, x, aspect_double_idx, text_len, aspect_len, dependency_dist):
        batch_size, seq_len = x.shape[0], x.shape[1]
        # print(type(aspect_double_idx), type(text_len), type(aspect_len), type(dependency_dist), type(batch_size), type(seq_len))
        weight = self.weight_matrix(aspect_double_idx, text_len, aspect_len, dependency_dist, batch_size, seq_len).to(torch.device('cpu'))
        x = weight.unsqueeze(2)*x
        return x

    def weight_matrix(self, aspect_double_idx, text_len, aspect_len, dependency_dist, batch_size, seq_len):
        aspect_double_idx = aspect_double_idx.cpu().numpy()
        text_len = text_len.cpu().numpy()
        aspect_len = aspect_len.cpu().numpy()
        dependency_dist = dependency_dist.cpu().numpy()
        weight = [[] for i in range(batch_size)]
        for i in range(batch_size):
            context_len = text_len[i] - aspect_len[i]
            for j in range(aspect_double_idx[i,0]):
                weight[i].append(1-dependency_dist[i,j]/context_len)
            for j in range(aspect_double_idx[i,0], aspect_double_idx[i,1]+1):
                weight[i].append(0)
            for j in range(aspect_double_idx[i,1]+1, text_len[i]):
                weight[i].append(1-dependency_dist[i,j]/context_len)
            for j in range(text_len[i], seq_len):
                weight[i].append(0)
        return torch.tensor(weight)

class PWCN_DEP_modified(nn.Module):
    def __init__(self, embedding_matrix, opt):
        super(PWCN_DEP_modified, self).__init__()
        self.opt = opt
        # self.embed = nn.Embedding.from_pretrained(torch.tensor(embedding_matrix, dtype=torch.float))
        # self.embed_dropout = nn.Dropout(0.3)
        self.txt_lstm = DynamicLSTM(768, 768, num_layers=1, batch_first=True, bidirectional=True)
        self.proximity = DependencyProximity(opt)
        self.convs3 = nn.Conv1d(2*768, 2*768, 3, padding=1).double()
        self.fc = nn.Linear(2*768, 3).double()

    def forward(self, inputs):
        text_indices, aspect_indices, left_indices, dependency_dist, bert_embedding = inputs
        # print(bert_embedding.shape)

        txt_len = torch.sum(text_indices != 0, dim=1)
        asp_len = torch.sum(aspect_indices != 0, dim=1)
        left_len = torch.sum(left_indices != 0, dim=-1)
        aspect_double_idx = torch.cat([left_len.unsqueeze(-1), (left_len+asp_len-1).unsqueeze(-1)], dim=-1)
        txt_out = bert_embedding
        # print(txt_out.shape, txt_len.shape)
        txt_out, (_, _) = self.txt_lstm(txt_out, txt_len)
        z = F.relu(self.convs3(
            self.proximity(txt_out, aspect_double_idx, txt_len, asp_len, dependency_dist).transpose(1, 2)))  # [(N,Co,L), ...]*len(Ks)
        z = F.max_pool1d(z, z.size(2)).squeeze(2)
        out = self.fc(z)
        return out

# %%
# -*- coding: utf-8 -*-


import os
import pickle
import torch
import torch.nn.functional as F
import argparse

from data_utils import ABSADatesetReader, ABSADataset, Tokenizer, build_embedding_matrix
from bucket_iterator import BucketIterator
from models import LSTM, PWCN_POS, PWCN_DEP
from dependency_dist import dependency_dist_func
from transformers import BertTokenizer, BertModel

class Inferer:
    """A simple inference example"""
    def __init__(self, opt):
        self.opt = opt
        print("loading {0} tokenizer...".format(opt.dataset))
        with open(opt.dataset+'_word2idx.pkl', 'rb') as f:
            word2idx = pickle.load(f)
            self.tokenizer = Tokenizer(word2idx=word2idx)
        embedding_matrix = build_embedding_matrix(self.tokenizer.word2idx, opt.embed_dim, opt.dataset)
        self.model = opt.model_class(embedding_matrix, opt)
        print('loading model {0} ...'.format(opt.model_name))
        self.model.load_state_dict(torch.load(opt.state_dict_path, map_location=lambda storage, loc: storage))
        # switch model to evaluation mode
        self.model.eval()
        torch.autograd.set_grad_enabled(False)

    def evaluate(self, raw_text, aspect):
        text_seqs = [self.tokenizer.text_to_sequence(raw_text.lower().strip())]
        aspect_seqs = [self.tokenizer.text_to_sequence(aspect.lower())]
        left_seqs = [self.tokenizer.text_to_sequence(raw_text.lower().split(aspect.lower())[0])]
        text_indices = torch.tensor(text_seqs, dtype=torch.int64)
        aspect_indices = torch.tensor(aspect_seqs, dtype=torch.int64)
        left_indices = torch.tensor(left_seqs, dtype=torch.int64)
        dependency_dist = torch.tensor([(dependency_dist_func(raw_text, aspect))])

        tokenizer_bert = BertTokenizer.from_pretrained("bert-base-uncased")
        bert_model = BertModel.from_pretrained("bert-base-uncased")

        inputs = tokenizer_bert.encode_plus(raw_text, return_tensors="pt")
        outputs = bert_model(**inputs)

        last_hidden_states = outputs[0]

        data = {
            'text_indices':text_indices,
            'aspect_indices':aspect_indices,
            'left_indices':left_indices,
            'dependency_dist':dependency_dist,
            'bert_embedding': last_hidden_states,
        }
        t_inputs = [data[col] for col in self.opt.inputs_cols]
        t_outputs = self.model(t_inputs)

        t_probs = F.softmax(t_outputs, dim=-1).cpu().numpy()
        return t_probs

if __name__ == '__main__':
    model_classes = {
        'lstm': LSTM,
        'pwcn_pos': PWCN_POS,
        'pwcn_dep': PWCN_DEP,
        'pwcn_dep_BERT': PWCN_DEP_modified,
    }
    dataset = 'restaurant'
    # set your trained models here
    model_state_dict_paths = {
        'lstm': 'state_dict/lstm_'+dataset+'.pkl',
        'pwcn_pos': 'state_dict/pwcn_pos_'+dataset+'.pkl',
        'pwcn_dep': 'state_dict/pwcn_dep_'+dataset+'.pkl',
        'pwcn_dep_BERT': '/content/pwcn_dep_restaurant_BERT_FINAL.pkl'
    }
    input_colses = {
        'lstm': ['text_indices'],
        'pwcn_pos': ['text_indices', 'aspect_indices', 'left_indices'],
        'pwcn_dep': ['text_indices', 'aspect_indices', 'left_indices', 'dependency_dist'],
        'pwcn_dep_BERT': ['text_indices', 'aspect_indices', 'left_indices', 'dependency_dist', 'bert_embedding'],
    }
    class Option(object): pass
    opt = Option()
    opt.model_name = 'pwcn_dep_BERT'
    opt.model_class = model_classes[opt.model_name]
    opt.inputs_cols = input_colses[opt.model_name]
    opt.dataset = dataset
    opt.state_dict_path = model_state_dict_paths[opt.model_name]
    opt.embed_dim = 768
    opt.hidden_dim = 768
    opt.polarities_dim = 3
    opt.device = torch.device('cpu')

    inf = Inferer(opt)
    t_probs = inf.evaluate("The falafal was rather over cooked and dried but \
                        the chicken was fine.", 'falafal')

    print(t_probs)
    print(t_probs.argmax(axis=-1))
# Out:
# loading restaurant tokenizer...
# loading embedding_matrix: 768_restaurant_embedding_matrix.pkl
# loading model pwcn_dep_BERT ...
# [[0.74217903 0.08726472 0.17055625]]
# [0]

# %%
# !pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %%
import xmltodict

# Import spaCy and load a language model
import spacy
nlp = spacy.load("en_core_web_sm")

data = 'ABSA14_Restaurants_Test_Gold.xml'

with open(data) as fd:
    xml_source = xmltodict.parse(fd.read())

# %%
# Extracting text, term, and polarity values
sentences = xml_source['sentences']['sentence']
extracted_info = []

for sentence in sentences:
    text = sentence['text']

    # Check if 'aspectTerms' exist in the sentence
    aspect_terms = sentence.get('aspectTerms')

    if aspect_terms:
        aspect_term = aspect_terms['aspectTerm']

        # If there are multiple aspectTerms in a sentence
        if isinstance(aspect_term, list):
            for term in aspect_term:
                term_value = term['@term']
                polarity = term['@polarity']
                extracted_info.append({'text': text, 'term': term_value, 'polarity': polarity})
        else:  # Only one aspectTerm in a sentence
            term_value = aspect_term['@term']
            polarity = aspect_term['@polarity']
            extracted_info.append({'text': text, 'term': term_value, 'polarity': polarity})

# %%
inf = Inferer(opt)

wrong_count = 0
wrong_items = []
for item in extracted_info:
    sentence = item['text'].lower()
    aspect = item['term'].lower()
    polarity = item['polarity']
    t_probs = inf.evaluate(sentence, aspect)
    result_polarity = t_probs.argmax(axis=-1)

    if result_polarity[0] == 2:
        sentiment_result = "positive"
    elif result_polarity[0] == 1:
        sentiment_result = "neutral"
    else:
        sentiment_result = "negative"

    # print(sentiment_result, polarity)

    if sentiment_result != polarity:
        print('WRONG!!', 'expected: ', polarity, 'result: ', sentiment_result)
        print(sentence, aspect, result_polarity[0])
        wrong_count = wrong_count+1
        wrong_items.append({'text': sentence, 'aspect': aspect, 'expected': polarity, 'result': sentiment_result})


print(wrong_count, ' out of ', len(extracted_info))
# Out:
# loading restaurant tokenizer...
# loading embedding_matrix: 768_restaurant_embedding_matrix.pkl
# loading model pwcn_dep_BERT ...
# WRONG!! expected:  positive result:  neutral
# did i mention that the coffee is outstanding? coffee 1
# WRONG!! expected:  conflict result:  negative
# certainly not the best sushi in new york, however, it is always fresh, and the place is very clean, sterile. sushi 0
# WRONG!! expected:  neutral result:  positive
# try the rose roll (not on menu). menu 2
# WRONG!! expected:  neutral result:  negative
# while there's a decent menu, it shouldn't take ten minutes to get your drinks and 45 for a dessert pizza. drinks 0
# WRONG!! expected:  negative result:  positive
# the sangria's - watered down. sangria 2
# WRONG!! expected:  positive result:  neutral
# we enjoyed ourselves thoroughly and will be going back for the desserts .... desserts 1
# WRONG!! expected:  negative result:  neutral
# two wasted steaks -- what a crime! steaks 1
# WRONG!! expected:  negative result:  positive
# the staff should be a bit more friendly. staff 2
# WRONG!! expected:  neutral result:  positive
# entrees include classics like lasagna, fettuccine alfredo and chicken parmigiana. entrees 2
# WRONG!! expected:  neutral result:  positive
# entrees include classics like lasagna, fettuccine alfredo and chicken parmigiana. lasagna 2
# WRONG!! expected:  neutral result:  positive
# entrees include classics like lasagna, fettuccine alfredo and chicken parmigiana. fettuccine alfredo 2
# WRONG!! expected:  neutral result:  positive
# entrees include classics like lasagna, fettuccine alfredo and chicken parmigiana. chicken parmigiana 2
# WRONG!! expected:  negative result:  positive
# meal was very expensive for what you get. meal 2
# WRONG!! expected:  negative result:  positive
# one caveat: some of the curried casseroles can be a trifle harsh. curried casseroles 2
# WRONG!! expected:  conflict result:  positive
# a nice space, as long as it doesn't get too crowded and a singleminded devotion to its chosen cuisine make mare a great choice for seafood lovers. space 2
# WRONG!! expected:  positive result:  negative
# the steak melted in my mouth. steak 0
# WRONG!! expected:  neutral result:  positive
# the food did take a few extra minutes to come, but the cute waiters' jokes and friendliness made up for it. food 2
# WRONG!! expected:  positive result:  negative
# most importantly, it is reasonably priced. priced 0
# WRONG!! expected:  positive result:  neutral
# the selection of food is excellent (i'm not used to having much choice at restaurants), and the atmosphere is great. atmosphere 1
# WRONG!! expected:  positive result:  neutral
# food was decent, but not great. food 1
# WRONG!! expected:  negative result:  neutral
# i dont know what some people who rave about this hot dog are talking about. hot dog 1
# WRONG!! expected:  positive result:  negative
# anywhere else, the prices would be 3x as high! prices 0
# WRONG!! expected:  negative result:  positive
# our waiter was friendly and it is a shame that he didnt have a supportive staff to work with. staff 2
# WRONG!! expected:  negative result:  neutral
# i know real indian food and this wasn't it. indian food 1
# WRONG!! expected:  neutral result:  positive
# even when the chef is not in the house, the food and service are right on target. chef 2
# WRONG!! expected:  positive result:  negative
# the falafal was rather over cooked and dried but the chicken was fine. chicken 0
# WRONG!! expected:  neutral result:  positive
# desserts include flan and sopaipillas. desserts 2
# WRONG!! expected:  neutral result:  positive
# desserts include flan and sopaipillas. flan 2
# WRONG!! expected:  neutral result:  positive
# desserts include flan and sopaipillas. sopaipillas 2
# WRONG!! expected:  positive result:  neutral
# i had a delicious shrimp creole. shrimp creole 1
# WRONG!! expected:  positive result:  neutral
# service is known for bending over backwards to make everyone happy. service 1
# WRONG!! expected:  conflict result:  positive
# the atmosphere is attractive, but a little uncomfortable. atmosphere 2
# WRONG!! expected:  conflict result:  negative
# the sauce may not be for everyone, since it is distintive. sauce 0
# WRONG!! expected:  neutral result:  positive
# a beautiful atmosphere, perfect for drinks and/or appetizers. drinks 2
# WRONG!! expected:  neutral result:  positive
# a beautiful atmosphere, perfect for drinks and/or appetizers. appetizers 2
# WRONG!! expected:  negative result:  positive
# frankly, the chinese food here is something i can make better at home. chinese food 2
# WRONG!! expected:  neutral result:  negative
# there was only one waiter for the whole restaurant upstairs. waiter 0
# WRONG!! expected:  neutral result:  positive
# we started with the scallops and asparagus and also had the soft shell crab as well as the cheese plate. soft shell crab 2
# WRONG!! expected:  positive result:  neutral
# the food was great - sushi was good, but the cooked food amazed us. sushi 1
# WRONG!! expected:  negative result:  positive
# for the price you pay for the food here, you'd expect it to be at least on par with other japanese restaurants. price 2
# WRONG!! expected:  negative result:  positive
# for the price you pay for the food here, you'd expect it to be at least on par with other japanese restaurants. food 2
# WRONG!! expected:  neutral result:  positive
# the food is all-around good, with the rolls usually excellent and the sushi/sashimi not quite on the same level. sushi/sashimi 2
# WRONG!! expected:  negative result:  neutral
# (the sashimi is cut a little thinly. sashimi 1
# WRONG!! expected:  negative result:  neutral
# could have had better for 1/3 the price in chinatown. price 1
# WRONG!! expected:  neutral result:  negative
# the absolute worst service i've ever experienced and the food was below average (when they actually gave people the meals they ordered). meals 0
# WRONG!! expected:  positive result:  neutral
# dessert was also to die for! dessert 1
# WRONG!! expected:  neutral result:  positive
# it's eaten with black vinegar and shredded ginger. black vinegar 2
# WRONG!! expected:  neutral result:  positive
# it's eaten with black vinegar and shredded ginger. shredded ginger 2
# WRONG!! expected:  positive result:  neutral
# dieters stick to salads or indulge in vegetarian platters. salads 1
# WRONG!! expected:  positive result:  neutral
# dieters stick to salads or indulge in vegetarian platters. vegetarian platters 1
# WRONG!! expected:  negative result:  neutral
# we were wondering why they were there to make our dining experience miserable? dining experience 1
# WRONG!! expected:  neutral result:  positive
# my friend had a burger and i had these wonderful blueberry pancakes. burger 2
# WRONG!! expected:  positive result:  neutral
# we were so happy with our food and were even more thrilled when we saw the bill. bill 1
# WRONG!! expected:  negative result:  neutral
# i thought the food isn't cheap at all compared to chinatown. food 1
# WRONG!! expected:  negative result:  positive
# coffee is a better deal than overpriced cosi sandwiches. cosi sandwiches 2
# WRONG!! expected:  negative result:  positive
# the food is so good and so popular that waiting can really be a nightmare. waiting 2
# WRONG!! expected:  positive result:  neutral
# it's just good food, nothing more and that's all we want! food 1
# WRONG!! expected:  negative result:  neutral
# everytime i go there i can't pick anything to eat and not because the menu is filled with great things to eat. menu 1
# WRONG!! expected:  positive result:  neutral
# service is usually pretty good. service 1
# WRONG!! expected:  neutral result:  positive
# the menu, which changes seasonally, shows both regional and international influences. menu 2
# WRONG!! expected:  positive result:  neutral
# their brunch menu had something for everyone. brunch menu 1
# WRONG!! expected:  neutral result:  negative
# the food was definitely good, but when all was said and done, i just couldn't justify it for the price (including 2 drinks, $100/person)... drinks 0
# WRONG!! expected:  positive result:  neutral
# if you are a tequila fan you will not be disappointed. tequila 1
# WRONG!! expected:  negative result:  positive
# not to sound too negative but be wary of the delivary. delivary 2
# WRONG!! expected:  positive result:  negative
# i found the food to be just as good as its owner, da silvano, just much less expensive. food 0
# WRONG!! expected:  positive result:  negative
# i found the food to be just as good as its owner, da silvano, just much less expensive. owner 0
# WRONG!! expected:  positive result:  neutral
# they have homemade pastas of all kinds -- i recommend the gnocchi -- yum! gnocchi 1
# WRONG!! expected:  negative result:  positive
# how can hope to stay in business with service like this? service 2
# WRONG!! expected:  positive result:  neutral
# best things to order are from the grill (churrasco and ribs). grill 1
# WRONG!! expected:  neutral result:  negative
# our waitress had apparently never tried any of the food, and there was no one to recommend any wine. wine 0
# WRONG!! expected:  conflict result:  positive
# the ambiance was pretty cool, but not worth the hassle. ambiance 2
# WRONG!! expected:  neutral result:  negative
# the unfortunate lady next to us thought she had ordered a salad (including asking for salad dressing) and was instead given a quesedilla. salad 0
# WRONG!! expected:  neutral result:  negative
# the unfortunate lady next to us thought she had ordered a salad (including asking for salad dressing) and was instead given a quesedilla. salad dressing 0
# WRONG!! expected:  neutral result:  negative
# the unfortunate lady next to us thought she had ordered a salad (including asking for salad dressing) and was instead given a quesedilla. quesedilla 0
# WRONG!! expected:  neutral result:  negative
# when she complained, the waitress said, sorry. waitress 0
# WRONG!! expected:  negative result:  positive
# the quality of the meat was on par with your local grocery store. quality of the meat 2
# WRONG!! expected:  positive result:  neutral
# they specialize in smoothies and fresh juices. fresh juices 1
# WRONG!! expected:  neutral result:  negative
# the manager then told us we could order from whatever menu we wanted but by that time we were so annoyed with the waiter and the resturant that we let and went some place else. manager 0
# WRONG!! expected:  negative result:  positive
# in mi burrito, here was nothing but dark chicken that had that cooked last week and just warmed up in a microwave taste. taste 2
# WRONG!! expected:  negative result:  positive
# in mi burrito, here was nothing but dark chicken that had that cooked last week and just warmed up in a microwave taste. chicken 2
# WRONG!! expected:  neutral result:  positive
# there's candlelight and music. candlelight 2
# WRONG!! expected:  neutral result:  positive
# there's candlelight and music. music 2
# WRONG!! expected:  negative result:  neutral
# i've had better japanese food at a mall food court. japanese food 1
# WRONG!! expected:  positive result:  negative
# cool atmosphere but such a let down. atmosphere 0
# WRONG!! expected:  positive result:  negative
# the sashimi portion are big enough to appease most people, but i didn't like the fact they used artifical lobster meat. sashimi portion 0
# WRONG!! expected:  negative result:  neutral
# the sashimi portion are big enough to appease most people, but i didn't like the fact they used artifical lobster meat. artifical lobster meat 1
# WRONG!! expected:  positive result:  neutral
# they have wheat crusted pizza made with really fresh and yummy ingredients. ingredients 1
# WRONG!! expected:  positive result:  negative
# the icing made this cake, it was fluffy, not ultra sweet, creamy and light. cake 0
# WRONG!! expected:  negative result:  neutral
# finally let into the store 5 at a time, to buy expensive slices from a harried staff. staff 1
# WRONG!! expected:  negative result:  neutral
# finally let into the store 5 at a time, to buy expensive slices from a harried staff. slices 1
# WRONG!! expected:  neutral result:  negative
# they have waiters on the sidewalk trying to pull you in which made us suspicious. waiters 0
# WRONG!! expected:  neutral result:  positive
# it was our only opportunity to visit and wanted an authentic italian meal. italian meal 2
# WRONG!! expected:  positive result:  neutral
# it took 100 years for parisi to get around to making pizza (at least i don't think they ever made it before this year)...but it was worth the wait. pizza 1
# WRONG!! expected:  neutral result:  negative
# probably my worst dining experience in new york, and i'm a former waiter so i know what i'm talking about. waiter 0
# WRONG!! expected:  positive result:  neutral
# ask for the round corner table next to the large window. round corner table next to the large window 1
# WRONG!! expected:  positive result:  neutral
# the food--though mostly deep-fried--is simple and satisfying. food 1
# WRONG!! expected:  positive result:  negative
# at night the atmoshere changes turning into this hidden jewel that is waiting to be discovered. atmoshere 0
# WRONG!! expected:  neutral result:  positive
# the other times i've gone it's romantic date heaven, you can walk in get a booth by the windows, be treated like a vip in a not-crowded place, with great food and service. booth by the windows 2
# WRONG!! expected:  positive result:  neutral
# i would only go for the coffee which is way better than starbucks or the like. coffee 1
# WRONG!! expected:  negative result:  positive
# if your looking for nasty high priced food with a dash of ghetto scenery cheap bx a$$ this is the place to be!! priced 2
# WRONG!! expected:  negative result:  positive
# if your looking for nasty high priced food with a dash of ghetto scenery cheap bx a$$ this is the place to be!! food 2
# WRONG!! expected:  negative result:  positive
# new hamburger with special sauce is ok - at least better than big mac! big mac 2
# WRONG!! expected:  neutral result:  positive
# perfectly al dente pasta, not drowned in sauce -- generous portions. sauce 2
# WRONG!! expected:  negative result:  neutral
# i can understand the prices if it served better food, like some chinese restaurants in midtown/uptown area. food 1
# WRONG!! expected:  positive result:  neutral
# have a mojito and sit in the back patio. mojito 1
# WRONG!! expected:  negative result:  neutral
# so we sat at the bar, the bartender didn't seem like he wanted to be there. bartender 1
# WRONG!! expected:  positive result:  neutral
# i reccomend the fried pork dumplings, the orange chicken/beef, and the fried rice. fried pork dumplings 1
# WRONG!! expected:  positive result:  neutral
# i reccomend the fried pork dumplings, the orange chicken/beef, and the fried rice. orange chicken/beef 1
# WRONG!! expected:  positive result:  neutral
# i reccomend the fried pork dumplings, the orange chicken/beef, and the fried rice. fried rice 1
# WRONG!! expected:  positive result:  neutral
# you will not be dissapointed by any of the choices in the menu. menu 1
# WRONG!! expected:  negative result:  neutral
# would you ever believe that when you complain about over an hour wait, when they tell you it will be 20-30 minutes, the manager tells the bartender to spill the drinks you just paid for? manager 1
# WRONG!! expected:  neutral result:  negative
# would you ever believe that when you complain about over an hour wait, when they tell you it will be 20-30 minutes, the manager tells the bartender to spill the drinks you just paid for? bartender 0
# WRONG!! expected:  neutral result:  positive
# the boutique selection of wines covers a wide variety without being imposeing. boutique selection of wines 2
# WRONG!! expected:  positive result:  negative
# disappointingly, their wonderful saketini has been taken off the bar menu. saketini 0
# WRONG!! expected:  negative result:  positive
# disappointingly, their wonderful saketini has been taken off the bar menu. bar menu 2
# WRONG!! expected:  negative result:  positive
# in short the black sheep distinguishes itself from the midtown pub herd with a look that's a mix of sports-bar butch and ornate kitsch. look 2
# WRONG!! expected:  neutral result:  negative
# then she made a fuss about not being able to add 1 or 2 chairs on either end of the table for additional people. chairs 0
# WRONG!! expected:  positive result:  negative
# the happy hour is so cheap, but that does not reflect the service or the atmosphere. service 0
# WRONG!! expected:  positive result:  negative
# the happy hour is so cheap, but that does not reflect the service or the atmosphere. atmosphere 0
# WRONG!! expected:  neutral result:  negative
# after waiting for almost an hour, the waiter brusquely told us he'd forgotten to give the kitchen our order. kitchen 0
# WRONG!! expected:  neutral result:  positive
# give it a try, menu is typical french but varied. menu 2
# WRONG!! expected:  positive result:  negative
# the negative reviews on city search are probably from jealous competing restaurants who realize they can't compete with temple's entire positive attitude about the proper way to treat their customers and deliver top quality food. food 0
# WRONG!! expected:  positive result:  negative
# the negative reviews on city search are probably from jealous competing restaurants who realize they can't compete with temple's entire positive attitude about the proper way to treat their customers and deliver top quality food. attitude 0
# WRONG!! expected:  neutral result:  negative
# it was good, but none of the flavors wow. flavors 0
# WRONG!! expected:  positive result:  neutral
# for about eleven bucks you get a gigantic burrito (or tacos), margarita, and dessert. tacos 1
# WRONG!! expected:  neutral result:  negative
# the food was mediocre to be kind - the interior is small and average - the owners are a tag-team of unpleasantries - so rude and snotty i actually let out a hearty guffaw whilst dining. dining 0
# WRONG!! expected:  neutral result:  positive
# offerings like hot cakes and the egg mcmuffin sandwich are available for breakfast. egg mcmuffin sandwich 2
# WRONG!! expected:  neutral result:  positive
# offerings like hot cakes and the egg mcmuffin sandwich are available for breakfast. hot cakes 2
# WRONG!! expected:  neutral result:  positive
# offerings like hot cakes and the egg mcmuffin sandwich are available for breakfast. breakfast 2
# WRONG!! expected:  neutral result:  negative
# i have been going to this restaurant for years, in the past the service was average and the food inconsistant. service 0
# WRONG!! expected:  neutral result:  negative
# cuisine is billed as asian fusion - doesn't meet the bill. asian fusion 0
# WRONG!! expected:  neutral result:  positive
# creative dishes like king crab salad with passion fruit vinaigrette and fettuccine with grilled seafood in a rosemary-orange sauce are unexpected elements on an otherwise predictable bistro menu. bistro menu 2
# WRONG!! expected:  neutral result:  positive
# dishes denoted as "roy's classics" (marked on the menu with asterisks) are tried-and-true recipes, such as macadamia-crusted mahi mahi, or subtly sweet honey-mustard beef short ribs. menu 2
# WRONG!! expected:  positive result:  negative
# dishes denoted as "roy's classics" (marked on the menu with asterisks) are tried-and-true recipes, such as macadamia-crusted mahi mahi, or subtly sweet honey-mustard beef short ribs. recipes 0
# WRONG!! expected:  positive result:  negative
# dishes denoted as "roy's classics" (marked on the menu with asterisks) are tried-and-true recipes, such as macadamia-crusted mahi mahi, or subtly sweet honey-mustard beef short ribs. sweet honey-mustard beef short ribs 0
# WRONG!! expected:  negative result:  neutral
# i came to fresh expecting a great meal, and all i got was marginally so-so food served in a restaurant that was just so freezing we couldn't enjoy eating. meal 1
# WRONG!! expected:  neutral result:  negative
# i came to fresh expecting a great meal, and all i got was marginally so-so food served in a restaurant that was just so freezing we couldn't enjoy eating. served 0
# WRONG!! expected:  negative result:  positive
# the lone argentine chorizo appetizer at $8.95 was a heavy fennel flavored italian sausage like the ones that sell for $2.99/lb at the store. argentine chorizo appetizer 2
# WRONG!! expected:  negative result:  positive
# the lone argentine chorizo appetizer at $8.95 was a heavy fennel flavored italian sausage like the ones that sell for $2.99/lb at the store. fennel flavored italian sausage 2
# WRONG!! expected:  positive result:  neutral
# i went to swiftys with some friends of the family and we had a very nice dinner, but nothing amazing. dinner 1
# WRONG!! expected:  positive result:  neutral
# most of the sandwiches are made with soy mayonaise which is actually pretty good. sandwiches 1
# WRONG!! expected:  negative result:  positive
# waiting three hours before getting our entrees was a treat as well. waiting 2
# WRONG!! expected:  positive result:  neutral
# you can eat gourmet food at a fast food price. price 1
# WRONG!! expected:  positive result:  neutral
# you can eat gourmet food at a fast food price. food 1
# WRONG!! expected:  neutral result:  positive
# the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives. non-meat alternatives 2
# WRONG!! expected:  negative result:  positive
# the appetizers are ok, but the service is slow. service 2
# WRONG!! expected:  neutral result:  negative
# what can you say about a place where the waitress brings out the wrong entree, then verbally assaults your 80 year old grandmother and gives her lip about sending it back (which she did politely, by the way). entree 0
# WRONG!! expected:  positive result:  neutral
# the prices are not terrible. prices 1
# WRONG!! expected:  negative result:  positive
# 15% gratuity automatically added to the bill. bill 2
# WRONG!! expected:  negative result:  positive
# 15% gratuity automatically added to the bill. gratuity 2
# WRONG!! expected:  neutral result:  negative
# the halibut cheek appetizer came with a generous portion of foie gras, but that's about the only positive thing i can say about the meal. halibut cheek appetizer 0
# WRONG!! expected:  positive result:  neutral
# the halibut cheek appetizer came with a generous portion of foie gras, but that's about the only positive thing i can say about the meal. portion of foie gras 1
# WRONG!! expected:  conflict result:  negative
# the halibut cheek appetizer came with a generous portion of foie gras, but that's about the only positive thing i can say about the meal. meal 0
# WRONG!! expected:  neutral result:  positive
# all-time favorites include the big mac, chicken mcnuggets, filet-o-fish sandwich and mcdonald's famous french fries; lighter options like entree-sized salads are also available. entree-sized salads 2
# WRONG!! expected:  conflict result:  negative
# although somewhat loud, the noise was minimally intrusive. noise 0
# WRONG!! expected:  positive result:  neutral
# it's a basic pizza joint, not much to look at, but the pizza is what i go for. pizza 1
# WRONG!! expected:  positive result:  neutral
# dug the blue bar area too. blue bar area 1
# WRONG!! expected:  positive result:  neutral
# and these are not small, wimpy fast food type burgers - these are real, full sized patties. burgers 1
# WRONG!! expected:  positive result:  neutral
# and these are not small, wimpy fast food type burgers - these are real, full sized patties. patties 1
# WRONG!! expected:  negative result:  neutral
# go with the specials, and stay away from the salmon. salmon 1
# WRONG!! expected:  positive result:  negative
# the decor is what initially got me in the door. decor 0
# WRONG!! expected:  negative result:  neutral
# my date and i both ordered the branzini and both felt the fish was very average. fish 1
# WRONG!! expected:  conflict result:  negative
# the atmosphere was nice but it was a little too dark. atmosphere 0
# WRONG!! expected:  positive result:  neutral
# i recomend the chicken milanese. chicken milanese 1
# WRONG!! expected:  conflict result:  positive
# the service is a quite slow, but friendly. service 2
# WRONG!! expected:  positive result:  negative
# i have never had a bad meal(or bad service )@ pigalle. meal 0
# WRONG!! expected:  positive result:  negative
# i have never had a bad meal(or bad service )@ pigalle. service 0
# WRONG!! expected:  positive result:  neutral
# between my guest and i, we sampled at least 80% of the menu, and they were all hits. menu 1
# WRONG!! expected:  positive result:  neutral
# for someone who used to hate indian food, baluchi's has changed my mid. indian food 1
# WRONG!! expected:  positive result:  neutral
# finally a curry that i can eat, enjoy and not suffer from gastritis from 3 hours later. curry 1
# WRONG!! expected:  neutral result:  positive
# not only was the sushi fresh, they also served other entrees allowed each guest something to choose from and we all left happy (try the duck! entrees 2
# WRONG!! expected:  neutral result:  negative
# after i paid for my purchase, i noticed they had not given me utensils so i could eat my pie. utensils 0
# WRONG!! expected:  negative result:  neutral
# likewise if you like really thin crust or really big slices then nick and joe's may not be your favorite. thin crust 1
# WRONG!! expected:  negative result:  neutral
# likewise if you like really thin crust or really big slices then nick and joe's may not be your favorite. slices 1
# WRONG!! expected:  neutral result:  negative
# no green beans, no egg, no anchovy dressing, no nicoise olives, no red onion. green beans 0
# WRONG!! expected:  neutral result:  negative
# no green beans, no egg, no anchovy dressing, no nicoise olives, no red onion. egg 0
# WRONG!! expected:  neutral result:  negative
# no green beans, no egg, no anchovy dressing, no nicoise olives, no red onion. anchovy dressing 0
# WRONG!! expected:  neutral result:  negative
# no green beans, no egg, no anchovy dressing, no nicoise olives, no red onion. nicoise olives 0
# WRONG!! expected:  neutral result:  positive
# build a meal with side orders like amazin' greens salads, buffalo chicken kickers and cinna stix. amazin' greens salads 2
# WRONG!! expected:  neutral result:  positive
# build a meal with side orders like amazin' greens salads, buffalo chicken kickers and cinna stix. buffalo chicken kickers 2
# WRONG!! expected:  neutral result:  positive
# build a meal with side orders like amazin' greens salads, buffalo chicken kickers and cinna stix. cinna stix 2
# WRONG!! expected:  neutral result:  positive
# build a meal with side orders like amazin' greens salads, buffalo chicken kickers and cinna stix. side orders 2
# WRONG!! expected:  neutral result:  positive
# thick fries, meaty chili and stuffed baked potatoes round out a menu that includes a cool, ultra-thick chocolate frosty. fries 2
# WRONG!! expected:  neutral result:  positive
# thick fries, meaty chili and stuffed baked potatoes round out a menu that includes a cool, ultra-thick chocolate frosty. meaty chili 2
# WRONG!! expected:  neutral result:  positive
# thick fries, meaty chili and stuffed baked potatoes round out a menu that includes a cool, ultra-thick chocolate frosty. stuffed baked potatoes 2
# WRONG!! expected:  neutral result:  positive
# thick fries, meaty chili and stuffed baked potatoes round out a menu that includes a cool, ultra-thick chocolate frosty. menu 2
# WRONG!! expected:  conflict result:  negative
# good cake but: it was not the best cake i've ever had, and definately not worth standing outside on the sidewalk being herded like cattle by indifferent and overworked employees. cake 0
# WRONG!! expected:  positive result:  negative
# it doesn't look like much on the outside, but the minute you walk inside, it's a whole other atmosphere. atmosphere 0
# WRONG!! expected:  negative result:  positive
# the ground chickpea soup we sampled as a starter tasted somewhat thin. ground chickpea soup 2
# WRONG!! expected:  negative result:  neutral
# we requested they re-slice the sushi, and it was returned to us in small cheese-like cubes. sushi 1
# WRONG!! expected:  positive result:  negative
# the service, however, is a peg or two below the quality of food (horrible bartenders), and the clientele, for the most part, are rowdy, loud-mouthed commuters (this could explain the bad attitudes from the staff) getting loaded for an ac/dc concert or a knicks game. quality of food 0
# WRONG!! expected:  positive result:  neutral
# if you're in the neighborhood, definitely stop by for a great meal. meal 1
# WRONG!! expected:  neutral result:  negative
# unfortunately, with our show tickets, we didn't have time to sample any desserts. desserts 0
# WRONG!! expected:  negative result:  neutral
# make more tables- perhaps a rooftop bar? tables 1
# WRONG!! expected:  positive result:  negative
# the decoration was feeling like we was on the cairo, actually the street is part of that adventure. decoration 0
# WRONG!! expected:  neutral result:  positive
# stick to the items the place does best, brisket, ribs, wings, cajun shrimp is good, not great. cajun shrimp 2
# WRONG!! expected:  neutral result:  positive
# young neighborhood trendies graze at the counter during the day, while chic, art-house drinkers with heavy doses of the munchies pile in late at night. counter 2
# WRONG!! expected:  neutral result:  positive
# bring your date and a bottle of wine! bottle of wine 2
# WRONG!! expected:  neutral result:  positive
# my chelsea's impressive and creative menu includes modern, westernized japanese dishes such as foie gras unagi napolean, jap style hamburger steak, spicy cod roe spaghetti, black cod with miso base, and rack of lamb in black truffle sauce, to name a few. japanese dishes 2
# WRONG!! expected:  neutral result:  positive
# my chelsea's impressive and creative menu includes modern, westernized japanese dishes such as foie gras unagi napolean, jap style hamburger steak, spicy cod roe spaghetti, black cod with miso base, and rack of lamb in black truffle sauce, to name a few. foie gras unagi napolean 2
# WRONG!! expected:  neutral result:  positive
# my chelsea's impressive and creative menu includes modern, westernized japanese dishes such as foie gras unagi napolean, jap style hamburger steak, spicy cod roe spaghetti, black cod with miso base, and rack of lamb in black truffle sauce, to name a few. jap style hamburger steak 2
# WRONG!! expected:  neutral result:  positive
# my chelsea's impressive and creative menu includes modern, westernized japanese dishes such as foie gras unagi napolean, jap style hamburger steak, spicy cod roe spaghetti, black cod with miso base, and rack of lamb in black truffle sauce, to name a few. spicy cod roe spaghetti 2
# WRONG!! expected:  neutral result:  positive
# my chelsea's impressive and creative menu includes modern, westernized japanese dishes such as foie gras unagi napolean, jap style hamburger steak, spicy cod roe spaghetti, black cod with miso base, and rack of lamb in black truffle sauce, to name a few. black cod with miso base 2
# WRONG!! expected:  neutral result:  positive
# my chelsea's impressive and creative menu includes modern, westernized japanese dishes such as foie gras unagi napolean, jap style hamburger steak, spicy cod roe spaghetti, black cod with miso base, and rack of lamb in black truffle sauce, to name a few. rack of lamb in black truffle sauce 2
# WRONG!! expected:  positive result:  neutral
# his food is excellent (and not expensive by nyc standards- no entrees over $30, most appetizers $12 to 14). appetizers 1
# WRONG!! expected:  positive result:  neutral
# don't get me wrong - sushi was good, just not fantastic. sushi 1
# WRONG!! expected:  positive result:  neutral
# been to the one in brooklyn for over 25 years, now i dont have to go over the bridge for the best pizza ....hanx pizza 1
# WRONG!! expected:  positive result:  neutral
# highly recommended...  as stated, i haven't dined *in* the restaurant but stopped by there to pick up takeout and it seems a very relaxing place; also, the bar looks nice. place 1
# WRONG!! expected:  positive result:  neutral
# highly recommended...  as stated, i haven't dined *in* the restaurant but stopped by there to pick up takeout and it seems a very relaxing place; also, the bar looks nice. bar 1
# WRONG!! expected:  positive result:  negative
# but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection). cocktail hour 0
# WRONG!! expected:  positive result:  negative
# but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection). non-sushi selection 0
# WRONG!! expected:  positive result:  negative
# but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection). appetizers 0
# WRONG!! expected:  negative result:  neutral
# it took about 2 1/2 hours to be served our 2 courses. served 1
# WRONG!! expected:  neutral result:  positive
# who said go when the place is quiet during the day? place 2
# WRONG!! expected:  neutral result:  positive
# good place to hang out during the day after shopping or to grab a simple soup or classic french dish over a glass of wine. soup 2
# WRONG!! expected:  neutral result:  positive
# good place to hang out during the day after shopping or to grab a simple soup or classic french dish over a glass of wine. french dish 2
# WRONG!! expected:  neutral result:  positive
# good place to hang out during the day after shopping or to grab a simple soup or classic french dish over a glass of wine. glass of wine 2
# WRONG!! expected:  neutral result:  positive
# we were seated promptly in close proximity to the dance floor. dance floor 2
# WRONG!! expected:  negative result:  positive
# slow service, but when you're hanging around with groups of 10 or 20, who really notices? service 2
# WRONG!! expected:  neutral result:  positive
# the sauce is excellent (very fresh) with dabs of real mozzarella. dabs of real mozzarella 2
# WRONG!! expected:  negative result:  positive
# don't ever bother - the drinks were awful, but it was the people who work there that really made this the worst experience at dining. people 2
# WRONG!! expected:  neutral result:  positive
# the best dessert, a chocolate and peanut butter tart, isn't particularly hawaiian, but it's a small world when it comes to sweets. sweets 2
# WRONG!! expected:  positive result:  neutral
# for an appetizer, their calamari is a winner. calamari 1
# WRONG!! expected:  neutral result:  positive
# the room is a gorgeous, bi-level space and the long bar perfect for a drink. drink 2
# WRONG!! expected:  neutral result:  positive
# two complaints- their appetizer selection stinks, it would be nice to get some mozzarella sticks on the menu. mozzarella sticks 2
# WRONG!! expected:  negative result:  positive
# two complaints- their appetizer selection stinks, it would be nice to get some mozzarella sticks on the menu. menu 2
# WRONG!! expected:  conflict result:  positive
# the service is great (maybe even borderline nagging but at least you get attention), the desserts are excellent and the coffee is so very good... service 2
# WRONG!! expected:  neutral result:  positive
# they are served on focacchia bread and are to die for. served 2
# WRONG!! expected:  neutral result:  positive
# they are served on focacchia bread and are to die for. focacchia bread 2
# WRONG!! expected:  negative result:  positive
# while the smoothies are a little big for me, the fresh juices are the best i have ever had! smoothies 2
# WRONG!! expected:  conflict result:  positive
# the food is just okay, and it's almost not worth going unless you're getting the pialla, which is the only dish that's really good. food 2
# WRONG!! expected:  positive result:  negative
# the food is just okay, and it's almost not worth going unless you're getting the pialla, which is the only dish that's really good. pialla 0
# WRONG!! expected:  conflict result:  positive
# the guac is fresh, yet lacking flavor, we like to add our fresh salsa into it. guac 2
# WRONG!! expected:  neutral result:  positive
# the guac is fresh, yet lacking flavor, we like to add our fresh salsa into it. fresh salsa 2
# WRONG!! expected:  negative result:  positive
# the guac is fresh, yet lacking flavor, we like to add our fresh salsa into it. flavor 2
# WRONG!! expected:  conflict result:  negative
# the new menu has a few creative items,they were smart enough to keep some of the old favorites (but they raised the prices), the staff is friendly most of the time, but i must agree with the person that wrote about their favorite words: no, can't, sorry..., boy, they won't bend the rules for anyone. staff 0
# WRONG!! expected:  positive result:  negative
# the new menu has a few creative items,they were smart enough to keep some of the old favorites (but they raised the prices), the staff is friendly most of the time, but i must agree with the person that wrote about their favorite words: no, can't, sorry..., boy, they won't bend the rules for anyone. new menu 0
# WRONG!! expected:  neutral result:  positive
# " the menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians. portabella lasagna 2
# WRONG!! expected:  neutral result:  negative
# how can they survive serving mediocre food at exorbitant prices?! food 0
# WRONG!! expected:  neutral result:  negative
# the food was mediocre and the service was severely slow. food 0
# WRONG!! expected:  negative result:  neutral
# its good to go there for drinks if you don't want to get drunk because you'll be lucky if you can get one drink an hour the service is so bad. service 1
# WRONG!! expected:  neutral result:  positive
# its good to go there for drinks if you don't want to get drunk because you'll be lucky if you can get one drink an hour the service is so bad. drink 2
# WRONG!! expected:  neutral result:  positive
# its good to go there for drinks if you don't want to get drunk because you'll be lucky if you can get one drink an hour the service is so bad. drinks 2
# WRONG!! expected:  negative result:  neutral
# i have never in my life sent back food before, but i simply had to, and the waiter argued with me over this. food 1
# WRONG!! expected:  negative result:  neutral
# i have never in my life sent back food before, but i simply had to, and the waiter argued with me over this. waiter 1
# WRONG!! expected:  negative result:  neutral
# although the restaurant itself is nice, i prefer not to go for the food. food 1
# WRONG!! expected:  neutral result:  positive
# creamy appetizers--taramasalata, eggplant salad, and greek yogurt (with cuccumber, dill, and garlic) taste excellent when on warm pitas. warm pitas 2
# 247  out of  1134
